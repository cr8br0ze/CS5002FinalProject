# %% [markdown]
# ## Imports

# %%
import pandas as pd
import math
import tqdm
import string

# %% [markdown]
# ## Readin Dataset

# %%
dataSet = pd.read_csv("SMSSpamCollection", sep='\t',index_col=False, names = ["type", "text"], header=None)

# %%
dataSet
# Out:
#       type                                               text
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %% [markdown]
# ## Splitting Dataset

# %%
total = dataSet.count()[0]
numTraining = math.floor(total*0.7)

# %%
trainingSet = dataSet[:numTraining]
validationSet = dataSet[numTraining:]

# %%
trainingSet
# Out:
#       type                                               text
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 3895  spam  Dear Dave this is your final notice to collect...
# 3896   ham                                Yes. Last  practice
# 3897  spam  tells u 2 call 09066358152 to claim £5000 priz...
# 3898   ham               No. Thank you. You've been wonderful
# 3899   ham           Otherwise had part time job na-tuition..
#
# [3900 rows x 2 columns]

# %%
validationSet
# Out:
#       type                                               text
# 3900   ham  Ü mean it's confirmed... I tot they juz say on...
# 3901   ham                                               Okie
# 3902   ham  That depends. How would you like to be treated...
# 3903   ham                       Right on brah, see you later
# 3904   ham  Waiting in e car 4 my mum lor. U leh? Reach ho...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [1672 rows x 2 columns]

# %% [markdown]
# ## Convert the Trainingset to Dictionary and Tokenizing

# %%
dicSet = trainingSet.to_dict(orient="records")
for i in dicSet:
    i["text"] = i["text"].translate(str.maketrans('', '', string.punctuation)).split()

# %%
dicSet
# Out:
# [{'type': 'ham',
#   'text': ['Go',
#    'until',
#    'jurong',
#    'point',
#    'crazy',
#    'Available',
#    'only',
#    'in',
#    'bugis',
#    'n',
#    'great',
#    'world',
#    'la',
#    'e',
#    'buffet',
#    'Cine',
#    'there',
#    'got',
#    'amore',
#    'wat']},
#  {'type': 'ham', 'text': ['Ok', 'lar', 'Joking', 'wif', 'u', 'oni']},
#  {'type': 'spam',
#   'text': ['Free',
#    'entry',
#    'in',
#    '2',
#    'a',
#    'wkly',
#    'comp',
#    'to',
#    'win',
#    'FA',
#    'Cup',
#    'final',
#    'tkts',
#    '21st',
#    'May',
#    '2005',
#    'Text',
#    'FA',
#    'to',
#    '87121',
#    'to',
#    'receive',
#    'entry',
#    'questionstd',
#    'txt',
#    'rateTCs',
#    'apply',
#    '08452810075over18s']},
#  {'type': 'ham',
#   'text': ['U',
#    'dun',
#    'say',
#    'so',
#    'early',
#    'hor',
#    'U',
#    'c',
#    'already',
#    'then',
#    'say']},
#  {'type': 'ham',
#   'text': ['Nah',
#    'I',
#    'dont',
#    'think',
#    'he',
#    'goes',
#    'to',
#    'usf',
#    'he',
#    'lives',
#    'around',
#    'here',
#    'though']},
#  {'type': 'spam',
#   'text': ['FreeMsg',
#    'Hey',
#    'there',
#    'darling',
#    'its',
#    'been',
#    '3',
#    'weeks',
#    'now',
#    'and',
#    'no',
#    'word',
#    'back',
#    'Id',
#    'like',
#    'some',
#    'fun',
#    'you',
#    'up',
#    'for',
#    'it',
#    'still',
#    'Tb',
#    'ok',
#    'XxX',
#    'std',
#    'chgs',
#    'to',
#    'send',
#    '£150',
#    'to',
#    'rcv']},
#  {'type': 'ham',
#   'text': ['Even',
#    'my',
#    'brother',
#    'is',
#    'not',
#    'like',
#    'to',
#    'speak',
#    'with',
#    'me',
#    'They',
#    'treat',
#    'me',
#    'like',
#    'aids',
#    'patent']},
#  {'type': 'ham',
#   'text': ['As',
#    'per',
#    'your',
#    'request',
#    'Melle',
#    'Melle',
#    'Oru',
#    'Minnaminunginte',
#    'Nurungu',
#    'Vettam',
#    'has',
#    'been',
#    'set',
#    'as',
#    'your',
#    'callertune',
#    'for',
#    'all',
#    'Callers',
#    'Press',
#    '9',
#    'to',
#    'copy',
#    'your',
#    'friends',
#    'Callertune']},
#  {'type': 'spam',
#   'text': ['WINNER',
#    'As',
#    'a',
#    'valued',
#    'network',
#    'customer',
#    'you',
#    'have',
#    'been',
#    'selected',
#    'to',
#    'receivea',
#    '£900',
#    'prize',
#    'reward',
#    'To',
#    'claim',
#    'call',
#    '09061701461',
#    'Claim',
#    'code',
#    'KL341',
#    'Valid',
#    '12',
#    'hours',
#    'only']},
#  {'type': 'spam',
#   'text': ['Had',
#    'your',
#    'mobile',
#    '11',
#    'months',
#    'or',
#    'more',
#    'U',
#    'R',
#    'entitled',
#    'to',
#    'Update',
#    'to',
#    'the',
#    'latest',
#    'colour',
#    'mobiles',
#    'with',
#    'camera',
#    'for',
#    'Free',
#    'Call',
#    'The',
#    'Mobile',
#    'Update',
#    'Co',
#    'FREE',
#    'on',
#    '08002986030']},
#  {'type': 'ham',
#   'text': ['Im',
#    'gonna',
#    'be',
#    'home',
#    'soon',
#    'and',
#    'i',
#    'dont',
#    'want',
#    'to',
#    'talk',
#    'about',
#    'this',
#    'stuff',
#    'anymore',
#    'tonight',
#    'k',
#    'Ive',
#    'cried',
#    'enough',
#    'today']},
#  {'type': 'spam',
#   'text': ['SIX',
#    'chances',
#    'to',
#    'win',
#    'CASH',
#    'From',
#    '100',
#    'to',
#    '20000',
#    'pounds',
#    'txt',
#    'CSH11',
#    'and',
#    'send',
#    'to',
#    '87575',
#    'Cost',
#    '150pday',
#    '6days',
#    '16',
#    'TsandCs',
#    'apply',
#    'Reply',
#    'HL',
#    '4',
#    'info']},
#  {'type': 'spam',
#   'text': ['URGENT',
#    'You',
#    'have',
#    'won',
#    'a',
#    '1',
#    'week',
#    'FREE',
#    'membership',
#    'in',
#    'our',
#    '£100000',
#    'Prize',
#    'Jackpot',
#    'Txt',
#    'the',
#    'word',
#    'CLAIM',
#    'to',
#    'No',
#    '81010',
#    'TC',
#    'wwwdbuknet',
#    'LCCLTD',
#    'POBOX',
#    '4403LDNW1A7RW18']},
#  {'type': 'ham',
#   'text': ['Ive',
#    'been',
#    'searching',
#    'for',
#    'the',
#    'right',
#    'words',
#    'to',
#    'thank',
#    'you',
#    'for',
#    'this',
#    'breather',
#    'I',
#    'promise',
#    'i',
#    'wont',
#    'take',
#    'your',
#    'help',
#    'for',
#    'granted',
#    'and',
#    'will',
#    'fulfil',
#    'my',
#    'promise',
#    'You',
#    'have',
#    'been',
#    'wonderful',
#    'and',
#    'a',
#    'blessing',
#    'at',
#    'all',
#    'times']},
#  {'type': 'ham',
#   'text': ['I', 'HAVE', 'A', 'DATE', 'ON', 'SUNDAY', 'WITH', 'WILL']},
#  {'type': 'spam',
#   'text': ['XXXMobileMovieClub',
#    'To',
#    'use',
#    'your',
#    'credit',
#    'click',
#    'the',
#    'WAP',
#    'link',
#    'in',
#    'the',
#    'next',
#    'txt',
#    'message',
#    'or',
#    'click',
#    'here',
#    'httpwap',
#    'xxxmobilemovieclubcomnQJKGIGHJJGCBL']},
#  {'type': 'ham', 'text': ['Oh', 'kim', 'watching', 'here']},
#  {'type': 'ham',
#   'text': ['Eh',
#    'u',
#    'remember',
#    'how',
#    '2',
#    'spell',
#    'his',
#    'name',
#    'Yes',
#    'i',
#    'did',
#    'He',
#    'v',
#    'naughty',
#    'make',
#    'until',
#    'i',
#    'v',
#    'wet']},
#  {'type': 'ham',
#   'text': ['Fine',
#    'if',
#    'that\x92s',
#    'the',
#    'way',
#    'u',
#    'feel',
#    'That\x92s',
#    'the',
#    'way',
#    'its',
#    'gota',
#    'b']},
#  {'type': 'spam',
#   'text': ['England',
#    'v',
#    'Macedonia',
#    'dont',
#    'miss',
#    'the',
#    'goalsteam',
#    'news',
#    'Txt',
#    'ur',
#    'national',
#    'team',
#    'to',
#    '87077',
#    'eg',
#    'ENGLAND',
#    'to',
#    '87077',
#    'TryWALES',
#    'SCOTLAND',
#    '4txtú120',
#    'POBOXox36504W45WQ',
#    '16']},
#  {'type': 'ham',
#   'text': ['Is', 'that', 'seriously', 'how', 'you', 'spell', 'his', 'name']},
#  {'type': 'ham',
#   'text': ['I‘m',
#    'going',
#    'to',
#    'try',
#    'for',
#    '2',
#    'months',
#    'ha',
#    'ha',
#    'only',
#    'joking']},
#  {'type': 'ham',
#   'text': ['So',
#    'ü',
#    'pay',
#    'first',
#    'lar',
#    'Then',
#    'when',
#    'is',
#    'da',
#    'stock',
#    'comin']},
#  {'type': 'ham',
#   'text': ['Aft',
#    'i',
#    'finish',
#    'my',
#    'lunch',
#    'then',
#    'i',
#    'go',
#    'str',
#    'down',
#    'lor',
#    'Ard',
#    '3',
#    'smth',
#    'lor',
#    'U',
#    'finish',
#    'ur',
#    'lunch',
#    'already']},
#  {'type': 'ham',
#   'text': ['Ffffffffff',
#    'Alright',
#    'no',
#    'way',
#    'I',
#    'can',
#    'meet',
#    'up',
#    'with',
#    'you',
#    'sooner']},
#  {'type': 'ham',
#   'text': ['Just',
#    'forced',
#    'myself',
#    'to',
#    'eat',
#    'a',
#    'slice',
#    'Im',
#    'really',
#    'not',
#    'hungry',
#    'tho',
#    'This',
#    'sucks',
#    'Mark',
#    'is',
#    'getting',
#    'worried',
#    'He',
#    'knows',
#    'Im',
#    'sick',
#    'when',
#    'I',
#    'turn',
#    'down',
#    'pizza',
#    'Lol']},
#  {'type': 'ham', 'text': ['Lol', 'your', 'always', 'so', 'convincing']},
#  {'type': 'ham',
#   'text': ['Did',
#    'you',
#    'catch',
#    'the',
#    'bus',
#    'Are',
#    'you',
#    'frying',
#    'an',
#    'egg',
#    'Did',
#    'you',
#    'make',
#    'a',
#    'tea',
#    'Are',
#    'you',
#    'eating',
#    'your',
#    'moms',
#    'left',
#    'over',
#    'dinner',
#    'Do',
#    'you',
#    'feel',
#    'my',
#    'Love']},
#  {'type': 'ham',
#   'text': ['Im',
#    'back',
#    'amp',
#    'were',
#    'packing',
#    'the',
#    'car',
#    'now',
#    'Ill',
#    'let',
#    'you',
#    'know',
#    'if',
#    'theres',
#    'room']},
#  {'type': 'ham',
#   'text': ['Ahhh',
#    'Work',
#    'I',
#    'vaguely',
#    'remember',
#    'that',
#    'What',
#    'does',
#    'it',
#    'feel',
#    'like',
#    'Lol']},
#  {'type': 'ham',
#   'text': ['Wait',
#    'thats',
#    'still',
#    'not',
#    'all',
#    'that',
#    'clear',
#    'were',
#    'you',
#    'not',
#    'sure',
#    'about',
#    'me',
#    'being',
#    'sarcastic',
#    'or',
#    'that',
#    'thats',
#    'why',
#    'x',
#    'doesnt',
#    'want',
#    'to',
#    'live',
#    'with',
#    'us']},
#  {'type': 'ham',
#   'text': ['Yeah',
#    'he',
#    'got',
#    'in',
#    'at',
#    '2',
#    'and',
#    'was',
#    'v',
#    'apologetic',
#    'n',
#    'had',
#    'fallen',
#    'out',
#    'and',
#    'she',
#    'was',
#    'actin',
#    'like',
#    'spoilt',
#    'child',
#    'and',
#    'he',
#    'got',
#    'caught',
#    'up',
#    'in',
#    'that',
#    'Till',
#    '2',
#    'But',
#    'we',
#    'wont',
#    'go',
#    'there',
#    'Not',
#    'doing',
#    'too',
#    'badly',
#    'cheers',
#    'You']},
#  {'type': 'ham', 'text': ['K', 'tell', 'me', 'anything', 'about', 'you']},
#  {'type': 'ham',
#   'text': ['For',
#    'fear',
#    'of',
#    'fainting',
#    'with',
#    'the',
#    'of',
#    'all',
#    'that',
#    'housework',
#    'you',
#    'just',
#    'did',
#    'Quick',
#    'have',
#    'a',
#    'cuppa']},
#  {'type': 'spam',
#   'text': ['Thanks',
#    'for',
#    'your',
#    'subscription',
#    'to',
#    'Ringtone',
#    'UK',
#    'your',
#    'mobile',
#    'will',
#    'be',
#    'charged',
#    '£5month',
#    'Please',
#    'confirm',
#    'by',
#    'replying',
#    'YES',
#    'or',
#    'NO',
#    'If',
#    'you',
#    'reply',
#    'NO',
#    'you',
#    'will',
#    'not',
#    'be',
#    'charged']},
#  {'type': 'ham',
#   'text': ['Yup',
#    'Ok',
#    'i',
#    'go',
#    'home',
#    'look',
#    'at',
#    'the',
#    'timings',
#    'then',
#    'i',
#    'msg',
#    'ü',
#    'again',
#    'Xuhui',
#    'going',
#    'to',
#    'learn',
#    'on',
#    '2nd',
#    'may',
#    'too',
#    'but',
#    'her',
#    'lesson',
#    'is',
#    'at',
#    '8am']},
#  {'type': 'ham',
#   'text': ['Oops',
#    'Ill',
#    'let',
#    'you',
#    'know',
#    'when',
#    'my',
#    'roommates',
#    'done']},
#  {'type': 'ham',
#   'text': ['I', 'see', 'the', 'letter', 'B', 'on', 'my', 'car']},
#  {'type': 'ham', 'text': ['Anything', 'lor', 'U', 'decide']},
#  {'type': 'ham',
#   'text': ['Hello',
#    'Hows',
#    'you',
#    'and',
#    'how',
#    'did',
#    'saturday',
#    'go',
#    'I',
#    'was',
#    'just',
#    'texting',
#    'to',
#    'see',
#    'if',
#    'youd',
#    'decided',
#    'to',
#    'do',
#    'anything',
#    'tomo',
#    'Not',
#    'that',
#    'im',
#    'trying',
#    'to',
#    'invite',
#    'myself',
#    'or',
#    'anything']},
#  {'type': 'ham',
#   'text': ['Pls',
#    'go',
#    'ahead',
#    'with',
#    'watts',
#    'I',
#    'just',
#    'wanted',
#    'to',
#    'be',
#    'sure',
#    'Do',
#    'have',
#    'a',
#    'great',
#    'weekend',
#    'Abiola']},
#  {'type': 'ham',
#   'text': ['Did',
#    'I',
#    'forget',
#    'to',
#    'tell',
#    'you',
#    'I',
#    'want',
#    'you',
#    'I',
#    'need',
#    'you',
#    'I',
#    'crave',
#    'you',
#    'But',
#    'most',
#    'of',
#    'all',
#    'I',
#    'love',
#    'you',
#    'my',
#    'sweet',
#    'Arabian',
#    'steed',
#    'Mmmmmm',
#    'Yummy']},
#  {'type': 'spam',
#   'text': ['07732584351',
#    'Rodger',
#    'Burns',
#    'MSG',
#    'We',
#    'tried',
#    'to',
#    'call',
#    'you',
#    're',
#    'your',
#    'reply',
#    'to',
#    'our',
#    'sms',
#    'for',
#    'a',
#    'free',
#    'nokia',
#    'mobile',
#    'free',
#    'camcorder',
#    'Please',
#    'call',
#    'now',
#    '08000930705',
#    'for',
#    'delivery',
#    'tomorrow']},
#  {'type': 'ham', 'text': ['WHO', 'ARE', 'YOU', 'SEEING']},
#  {'type': 'ham',
#   'text': ['Great',
#    'I',
#    'hope',
#    'you',
#    'like',
#    'your',
#    'man',
#    'well',
#    'endowed',
#    'I',
#    'am',
#    'ltgt',
#    'inches']},
#  {'type': 'ham', 'text': ['No', 'callsmessagesmissed', 'calls']},
#  {'type': 'ham',
#   'text': ['Didnt',
#    'you',
#    'get',
#    'hep',
#    'b',
#    'immunisation',
#    'in',
#    'nigeria']},
#  {'type': 'ham', 'text': ['Fair', 'enough', 'anything', 'going', 'on']},
#  {'type': 'ham',
#   'text': ['Yeah',
#    'hopefully',
#    'if',
#    'tyler',
#    'cant',
#    'do',
#    'it',
#    'I',
#    'could',
#    'maybe',
#    'ask',
#    'around',
#    'a',
#    'bit']},
#  {'type': 'ham',
#   'text': ['U',
#    'dont',
#    'know',
#    'how',
#    'stubborn',
#    'I',
#    'am',
#    'I',
#    'didnt',
#    'even',
#    'want',
#    'to',
#    'go',
#    'to',
#    'the',
#    'hospital',
#    'I',
#    'kept',
#    'telling',
#    'Mark',
#    'Im',
#    'not',
#    'a',
#    'weak',
#    'sucker',
#    'Hospitals',
#    'are',
#    'for',
#    'weak',
#    'suckers']},
#  {'type': 'ham',
#   'text': ['What',
#    'you',
#    'thinked',
#    'about',
#    'me',
#    'First',
#    'time',
#    'you',
#    'saw',
#    'me',
#    'in',
#    'class']},
#  {'type': 'ham',
#   'text': ['A',
#    'gram',
#    'usually',
#    'runs',
#    'like',
#    'ltgt',
#    'a',
#    'half',
#    'eighth',
#    'is',
#    'smarter',
#    'though',
#    'and',
#    'gets',
#    'you',
#    'almost',
#    'a',
#    'whole',
#    'second',
#    'gram',
#    'for',
#    'ltgt']},
#  {'type': 'ham',
#   'text': ['K',
#    'fyi',
#    'x',
#    'has',
#    'a',
#    'ride',
#    'early',
#    'tomorrow',
#    'morning',
#    'but',
#    'hes',
#    'crashing',
#    'at',
#    'our',
#    'place',
#    'tonight']},
#  {'type': 'ham',
#   'text': ['Wow',
#    'I',
#    'never',
#    'realized',
#    'that',
#    'you',
#    'were',
#    'so',
#    'embarassed',
#    'by',
#    'your',
#    'accomodations',
#    'I',
#    'thought',
#    'you',
#    'liked',
#    'it',
#    'since',
#    'i',
#    'was',
#    'doing',
#    'the',
#    'best',
#    'i',
#    'could',
#    'and',
#    'you',
#    'always',
#    'seemed',
#    'so',
#    'happy',
#    'about',
#    'the',
#    'cave',
#    'Im',
#    'sorry',
#    'I',
#    'didnt',
#    'and',
#    'dont',
#    'have',
#    'more',
#    'to',
#    'give',
#    'Im',
#    'sorry',
#    'i',
#    'offered',
#    'Im',
#    'sorry',
#    'your',
#    'room',
#    'was',
#    'so',
#    'embarassing']},
#  {'type': 'spam',
#   'text': ['SMS',
#    'ac',
#    'Sptv',
#    'The',
#    'New',
#    'Jersey',
#    'Devils',
#    'and',
#    'the',
#    'Detroit',
#    'Red',
#    'Wings',
#    'play',
#    'Ice',
#    'Hockey',
#    'Correct',
#    'or',
#    'Incorrect',
#    'End',
#    'Reply',
#    'END',
#    'SPTV']},
#  {'type': 'ham',
#   'text': ['Do',
#    'you',
#    'know',
#    'what',
#    'Mallika',
#    'Sherawat',
#    'did',
#    'yesterday',
#    'Find',
#    'out',
#    'now',
#    'ltURLgt']},
#  {'type': 'spam',
#   'text': ['Congrats',
#    '1',
#    'year',
#    'special',
#    'cinema',
#    'pass',
#    'for',
#    '2',
#    'is',
#    'yours',
#    'call',
#    '09061209465',
#    'now',
#    'C',
#    'Suprman',
#    'V',
#    'Matrix3',
#    'StarWars3',
#    'etc',
#    'all',
#    '4',
#    'FREE',
#    'bx420ip45we',
#    '150pm',
#    'Dont',
#    'miss',
#    'out']},
#  {'type': 'ham', 'text': ['Sorry', 'Ill', 'call', 'later', 'in', 'meeting']},
#  {'type': 'ham', 'text': ['Tell', 'where', 'you', 'reached']},
#  {'type': 'ham',
#   'text': ['Yesgauti', 'and', 'sehwag', 'out', 'of', 'odi', 'series']},
#  {'type': 'ham',
#   'text': ['Your',
#    'gonna',
#    'have',
#    'to',
#    'pick',
#    'up',
#    'a',
#    '1',
#    'burger',
#    'for',
#    'yourself',
#    'on',
#    'your',
#    'way',
#    'home',
#    'I',
#    'cant',
#    'even',
#    'move',
#    'Pain',
#    'is',
#    'killing',
#    'me']},
#  {'type': 'ham',
#   'text': ['Ha',
#    'ha',
#    'ha',
#    'good',
#    'joke',
#    'Girls',
#    'are',
#    'situation',
#    'seekers']},
#  {'type': 'ham', 'text': ['Its', 'a', 'part', 'of', 'checking', 'IQ']},
#  {'type': 'ham',
#   'text': ['Sorry',
#    'my',
#    'roommates',
#    'took',
#    'forever',
#    'it',
#    'ok',
#    'if',
#    'I',
#    'come',
#    'by',
#    'now']},
#  {'type': 'ham',
#   'text': ['Ok',
#    'lar',
#    'i',
#    'double',
#    'check',
#    'wif',
#    'da',
#    'hair',
#    'dresser',
#    'already',
#    'he',
#    'said',
#    'wun',
#    'cut',
#    'v',
#    'short',
#    'He',
#    'said',
#    'will',
#    'cut',
#    'until',
#    'i',
#    'look',
#    'nice']},
#  {'type': 'spam',
#   'text': ['As',
#    'a',
#    'valued',
#    'customer',
#    'I',
#    'am',
#    'pleased',
#    'to',
#    'advise',
#    'you',
#    'that',
#    'following',
#    'recent',
#    'review',
#    'of',
#    'your',
#    'Mob',
#    'No',
#    'you',
#    'are',
#    'awarded',
#    'with',
#    'a',
#    '£1500',
#    'Bonus',
#    'Prize',
#    'call',
#    '09066364589']},
#  {'type': 'ham',
#   'text': ['Today',
#    'is',
#    'song',
#    'dedicated',
#    'day',
#    'Which',
#    'song',
#    'will',
#    'u',
#    'dedicate',
#    'for',
#    'me',
#    'Send',
#    'this',
#    'to',
#    'all',
#    'ur',
#    'valuable',
#    'frnds',
#    'but',
#    'first',
#    'rply',
#    'me']},
#  {'type': 'spam',
#   'text': ['Urgent',
#    'UR',
#    'awarded',
#    'a',
#    'complimentary',
#    'trip',
#    'to',
#    'EuroDisinc',
#    'Trav',
#    'AcoEntry41',
#    'Or',
#    '£1000',
#    'To',
#    'claim',
#    'txt',
#    'DIS',
#    'to',
#    '87121',
#    '186£150moreFrmMob',
#    'ShrAcomOrSglSuplt10',
#    'LS1',
#    '3AJ']},
#  {'type': 'spam',
#   'text': ['Did',
#    'you',
#    'hear',
#    'about',
#    'the',
#    'new',
#    'Divorce',
#    'Barbie',
#    'It',
#    'comes',
#    'with',
#    'all',
#    'of',
#    'Kens',
#    'stuff']},
#  {'type': 'ham',
#   'text': ['I', 'plane', 'to', 'give', 'on', 'this', 'month', 'end']},
#  {'type': 'ham',
#   'text': ['Wah', 'lucky', 'man', 'Then', 'can', 'save', 'money', 'Hee']},
#  {'type': 'ham', 'text': ['Finished', 'class', 'where', 'are', 'you']},
#  {'type': 'ham',
#   'text': ['HI',
#    'BABE',
#    'IM',
#    'AT',
#    'HOME',
#    'NOW',
#    'WANNA',
#    'DO',
#    'SOMETHING',
#    'XX']},
#  {'type': 'ham',
#   'text': ['Kkwhere', 'are', 'youhow', 'did', 'you', 'performed']},
#  {'type': 'ham', 'text': ['U', 'can', 'call', 'me', 'now']},
#  {'type': 'ham',
#   'text': ['I',
#    'am',
#    'waiting',
#    'machan',
#    'Call',
#    'me',
#    'once',
#    'you',
#    'free']},
#  {'type': 'ham',
#   'text': ['Thats',
#    'cool',
#    'i',
#    'am',
#    'a',
#    'gentleman',
#    'and',
#    'will',
#    'treat',
#    'you',
#    'with',
#    'dignity',
#    'and',
#    'respect']},
#  {'type': 'ham',
#   'text': ['I',
#    'like',
#    'you',
#    'peoples',
#    'very',
#    'much',
#    'but',
#    'am',
#    'very',
#    'shy',
#    'pa']},
#  {'type': 'ham',
#   'text': ['Does', 'not', 'operate', 'after', 'ltgt', 'or', 'what']},
#  {'type': 'ham',
#   'text': ['Its',
#    'not',
#    'the',
#    'same',
#    'here',
#    'Still',
#    'looking',
#    'for',
#    'a',
#    'job',
#    'How',
#    'much',
#    'do',
#    'Tas',
#    'earn',
#    'there']},
#  {'type': 'ham', 'text': ['Sorry', 'Ill', 'call', 'later']},
#  {'type': 'ham',
#   'text': ['K', 'Did', 'you', 'call', 'me', 'just', 'now', 'ah']},
#  {'type': 'ham',
#   'text': ['Ok', 'i', 'am', 'on', 'the', 'way', 'to', 'home', 'hi', 'hi']},
#  {'type': 'ham',
#   'text': ['You', 'will', 'be', 'in', 'the', 'place', 'of', 'that', 'man']},
#  {'type': 'ham', 'text': ['Yup', 'next', 'stop']},
#  {'type': 'ham',
#   'text': ['I',
#    'call',
#    'you',
#    'later',
#    'dont',
#    'have',
#    'network',
#    'If',
#    'urgnt',
#    'sms',
#    'me']},
#  {'type': 'ham',
#   'text': ['For',
#    'real',
#    'when',
#    'u',
#    'getting',
#    'on',
#    'yo',
#    'I',
#    'only',
#    'need',
#    '2',
#    'more',
#    'tickets',
#    'and',
#    'one',
#    'more',
#    'jacket',
#    'and',
#    'Im',
#    'done',
#    'I',
#    'already',
#    'used',
#    'all',
#    'my',
#    'multis']},
#  {'type': 'ham',
#   'text': ['Yes',
#    'I',
#    'started',
#    'to',
#    'send',
#    'requests',
#    'to',
#    'make',
#    'it',
#    'but',
#    'pain',
#    'came',
#    'back',
#    'so',
#    'Im',
#    'back',
#    'in',
#    'bed',
#    'Double',
#    'coins',
#    'at',
#    'the',
#    'factory',
#    'too',
#    'I',
#    'gotta',
#    'cash',
#    'in',
#    'all',
#    'my',
#    'nitros']},
#  {'type': 'ham',
#   'text': ['Im',
#    'really',
#    'not',
#    'up',
#    'to',
#    'it',
#    'still',
#    'tonight',
#    'babe']},
#  {'type': 'ham',
#   'text': ['Ela', 'kanoil', 'download', 'come', 'wen', 'ur', 'free']},
#  {'type': 'ham',
#   'text': ['Yeah',
#    'do',
#    'Don‘t',
#    'stand',
#    'to',
#    'close',
#    'tho',
#    'you‘ll',
#    'catch',
#    'something']},
#  {'type': 'ham',
#   'text': ['Sorry',
#    'to',
#    'be',
#    'a',
#    'pain',
#    'Is',
#    'it',
#    'ok',
#    'if',
#    'we',
#    'meet',
#    'another',
#    'night',
#    'I',
#    'spent',
#    'late',
#    'afternoon',
#    'in',
#    'casualty',
#    'and',
#    'that',
#    'means',
#    'i',
#    'havent',
#    'done',
#    'any',
#    'of',
#    'y',
#    'stuff42moro',
#    'and',
#    'that',
#    'includes',
#    'all',
#    'my',
#    'time',
#    'sheets',
#    'and',
#    'that',
#    'Sorry']},
#  {'type': 'ham',
#   'text': ['Smile',
#    'in',
#    'Pleasure',
#    'Smile',
#    'in',
#    'Pain',
#    'Smile',
#    'when',
#    'trouble',
#    'pours',
#    'like',
#    'Rain',
#    'Smile',
#    'when',
#    'sum1',
#    'Hurts',
#    'U',
#    'Smile',
#    'becoz',
#    'SOMEONE',
#    'still',
#    'Loves',
#    'to',
#    'see',
#    'u',
#    'Smiling']},
#  {'type': 'spam',
#   'text': ['Please',
#    'call',
#    'our',
#    'customer',
#    'service',
#    'representative',
#    'on',
#    '0800',
#    '169',
#    '6031',
#    'between',
#    '10am9pm',
#    'as',
#    'you',
#    'have',
#    'WON',
#    'a',
#    'guaranteed',
#    '£1000',
#    'cash',
#    'or',
#    '£5000',
#    'prize']},
#  {'type': 'ham',
#   'text': ['Havent',
#    'planning',
#    'to',
#    'buy',
#    'later',
#    'I',
#    'check',
#    'already',
#    'lido',
#    'only',
#    'got',
#    '530',
#    'show',
#    'in',
#    'e',
#    'afternoon',
#    'U',
#    'finish',
#    'work',
#    'already']},
#  {'type': 'spam',
#   'text': ['Your',
#    'free',
#    'ringtone',
#    'is',
#    'waiting',
#    'to',
#    'be',
#    'collected',
#    'Simply',
#    'text',
#    'the',
#    'password',
#    'MIX',
#    'to',
#    '85069',
#    'to',
#    'verify',
#    'Get',
#    'Usher',
#    'and',
#    'Britney',
#    'FML',
#    'PO',
#    'Box',
#    '5249',
#    'MK17',
#    '92H',
#    '450Ppw',
#    '16']},
#  {'type': 'ham', 'text': ['Watching', 'telugu', 'moviewat', 'abt', 'u']},
#  {'type': 'ham',
#   'text': ['i',
#    'see',
#    'When',
#    'we',
#    'finish',
#    'we',
#    'have',
#    'loads',
#    'of',
#    'loans',
#    'to',
#    'pay']},
#  {'type': 'ham',
#   'text': ['Hi',
#    'Wk',
#    'been',
#    'ok',
#    'on',
#    'hols',
#    'now',
#    'Yes',
#    'on',
#    'for',
#    'a',
#    'bit',
#    'of',
#    'a',
#    'run',
#    'Forgot',
#    'that',
#    'i',
#    'have',
#    'hairdressers',
#    'appointment',
#    'at',
#    'four',
#    'so',
#    'need',
#    'to',
#    'get',
#    'home',
#    'n',
#    'shower',
#    'beforehand',
#    'Does',
#    'that',
#    'cause',
#    'prob',
#    'for',
#    'u']},
#  {'type': 'ham',
#   'text': ['I', 'see', 'a', 'cup', 'of', 'coffee', 'animation']},
#  {'type': 'ham',
#   'text': ['Please',
#    'dont',
#    'text',
#    'me',
#    'anymore',
#    'I',
#    'have',
#    'nothing',
#    'else',
#    'to',
#    'say']},
#  {'type': 'ham',
#   'text': ['Okay',
#    'name',
#    'ur',
#    'price',
#    'as',
#    'long',
#    'as',
#    'its',
#    'legal',
#    'Wen',
#    'can',
#    'I',
#    'pick',
#    'them',
#    'up',
#    'Y',
#    'u',
#    'ave',
#    'x',
#    'ams',
#    'xx']},
#  {'type': 'ham',
#   'text': ['Im',
#    'still',
#    'looking',
#    'for',
#    'a',
#    'car',
#    'to',
#    'buy',
#    'And',
#    'have',
#    'not',
#    'gone',
#    '4the',
#    'driving',
#    'test',
#    'yet']},
#  {'type': 'ham',
#   'text': ['As',
#    'per',
#    'your',
#    'request',
#    'Melle',
#    'Melle',
#    'Oru',
#    'Minnaminunginte',
#    'Nurungu',
#    'Vettam',
#    'has',
#    'been',
#    'set',
#    'as',
#    'your',
#    'callertune',
#    'for',
#    'all',
#    'Callers',
#    'Press',
#    '9',
#    'to',
#    'copy',
#    'your',
#    'friends',
#    'Callertune']},
#  {'type': 'ham',
#   'text': ['wow',
#    'Youre',
#    'right',
#    'I',
#    'didnt',
#    'mean',
#    'to',
#    'do',
#    'that',
#    'I',
#    'guess',
#    'once',
#    'i',
#    'gave',
#    'up',
#    'on',
#    'boston',
#    'men',
#    'and',
#    'changed',
#    'my',
#    'search',
#    'location',
#    'to',
#    'nyc',
#    'something',
#    'changed',
#    'Cuz',
#    'on',
#    'my',
#    'signin',
#    'page',
#    'it',
#    'still',
#    'says',
#    'boston']},
#  {'type': 'ham',
#   'text': ['Umma',
#    'my',
#    'life',
#    'and',
#    'vava',
#    'umma',
#    'love',
#    'you',
#    'lot',
#    'dear']},
#  {'type': 'ham',
#   'text': ['Thanks',
#    'a',
#    'lot',
#    'for',
#    'your',
#    'wishes',
#    'on',
#    'my',
#    'birthday',
#    'Thanks',
#    'you',
#    'for',
#    'making',
#    'my',
#    'birthday',
#    'truly',
#    'memorable']},
#  {'type': 'ham',
#   'text': ['Aight',
#    'Ill',
#    'hit',
#    'you',
#    'up',
#    'when',
#    'I',
#    'get',
#    'some',
#    'cash']},
#  {'type': 'ham',
#   'text': ['How',
#    'would',
#    'my',
#    'ip',
#    'address',
#    'test',
#    'that',
#    'considering',
#    'my',
#    'computer',
#    'isnt',
#    'a',
#    'minecraft',
#    'server']},
#  {'type': 'ham',
#   'text': ['I',
#    'know',
#    'Grumpy',
#    'old',
#    'people',
#    'My',
#    'mom',
#    'was',
#    'like',
#    'you',
#    'better',
#    'not',
#    'be',
#    'lying',
#    'Then',
#    'again',
#    'I',
#    'am',
#    'always',
#    'the',
#    'one',
#    'to',
#    'play',
#    'jokes']},
#  {'type': 'ham', 'text': ['Dont', 'worry', 'I', 'guess', 'hes', 'busy']},
#  {'type': 'ham',
#   'text': ['What', 'is', 'the', 'plural', 'of', 'the', 'noun', 'research']},
#  {'type': 'ham', 'text': ['Going', 'for', 'dinnermsg', 'you', 'after']},
#  {'type': 'ham',
#   'text': ['Im',
#    'ok',
#    'wif',
#    'it',
#    'cos',
#    'i',
#    'like',
#    '2',
#    'try',
#    'new',
#    'things',
#    'But',
#    'i',
#    'scared',
#    'u',
#    'dun',
#    'like',
#    'mah',
#    'Cos',
#    'u',
#    'said',
#    'not',
#    'too',
#    'loud']},
#  {'type': 'spam',
#   'text': ['GENT',
#    'We',
#    'are',
#    'trying',
#    'to',
#    'contact',
#    'you',
#    'Last',
#    'weekends',
#    'draw',
#    'shows',
#    'that',
#    'you',
#    'won',
#    'a',
#    '£1000',
#    'prize',
#    'GUARANTEED',
#    'Call',
#    '09064012160',
#    'Claim',
#    'Code',
#    'K52',
#    'Valid',
#    '12hrs',
#    'only',
#    '150ppm']},
#  {'type': 'ham',
#   'text': ['Wa',
#    'ur',
#    'openin',
#    'sentence',
#    'very',
#    'formal',
#    'Anyway',
#    'im',
#    'fine',
#    'too',
#    'juz',
#    'tt',
#    'im',
#    'eatin',
#    'too',
#    'much',
#    'n',
#    'puttin',
#    'on',
#    'weightHaha',
#    'So',
#    'anythin',
#    'special',
#    'happened']},
#  {'type': 'ham',
#   'text': ['As',
#    'I',
#    'entered',
#    'my',
#    'cabin',
#    'my',
#    'PA',
#    'said',
#    'Happy',
#    'Bday',
#    'Boss',
#    'I',
#    'felt',
#    'special',
#    'She',
#    'askd',
#    'me',
#    '4',
#    'lunch',
#    'After',
#    'lunch',
#    'she',
#    'invited',
#    'me',
#    'to',
#    'her',
#    'apartment',
#    'We',
#    'went',
#    'there']},
#  {'type': 'spam',
#   'text': ['You',
#    'are',
#    'a',
#    'winner',
#    'U',
#    'have',
#    'been',
#    'specially',
#    'selected',
#    '2',
#    'receive',
#    '£1000',
#    'or',
#    'a',
#    '4',
#    'holiday',
#    'flights',
#    'inc',
#    'speak',
#    'to',
#    'a',
#    'live',
#    'operator',
#    '2',
#    'claim',
#    '0871277810910pmin',
#    '18']},
#  {'type': 'ham',
#   'text': ['Goodo',
#    'Yes',
#    'we',
#    'must',
#    'speak',
#    'friday',
#    'eggpotato',
#    'ratio',
#    'for',
#    'tortilla',
#    'needed']},
#  {'type': 'ham',
#   'text': ['Hmmmy',
#    'uncle',
#    'just',
#    'informed',
#    'me',
#    'that',
#    'hes',
#    'paying',
#    'the',
#    'school',
#    'directly',
#    'So',
#    'pls',
#    'buy',
#    'food']},
#  {'type': 'spam',
#   'text': ['PRIVATE',
#    'Your',
#    '2004',
#    'Account',
#    'Statement',
#    'for',
#    '07742676969',
#    'shows',
#    '786',
#    'unredeemed',
#    'Bonus',
#    'Points',
#    'To',
#    'claim',
#    'call',
#    '08719180248',
#    'Identifier',
#    'Code',
#    '45239',
#    'Expires']},
#  {'type': 'spam',
#   'text': ['URGENT',
#    'Your',
#    'Mobile',
#    'No',
#    'was',
#    'awarded',
#    '£2000',
#    'Bonus',
#    'Caller',
#    'Prize',
#    'on',
#    '5903',
#    'This',
#    'is',
#    'our',
#    'final',
#    'try',
#    'to',
#    'contact',
#    'U',
#    'Call',
#    'from',
#    'Landline',
#    '09064019788',
#    'BOX42WR29C',
#    '150PPM']},
#  {'type': 'ham',
#   'text': ['here',
#    'is',
#    'my',
#    'new',
#    'address',
#    'applespairsall',
#    'that',
#    'malarky']},
#  {'type': 'spam',
#   'text': ['Todays',
#    'Voda',
#    'numbers',
#    'ending',
#    '7548',
#    'are',
#    'selected',
#    'to',
#    'receive',
#    'a',
#    '350',
#    'award',
#    'If',
#    'you',
#    'have',
#    'a',
#    'match',
#    'please',
#    'call',
#    '08712300220',
#    'quoting',
#    'claim',
#    'code',
#    '4041',
#    'standard',
#    'rates',
#    'app']},
#  {'type': 'ham',
#   'text': ['I',
#    'am',
#    'going',
#    'to',
#    'sao',
#    'mu',
#    'today',
#    'Will',
#    'be',
#    'done',
#    'only',
#    'at',
#    '12']},
#  {'type': 'ham',
#   'text': ['Ü', 'predict', 'wat', 'time', 'üll', 'finish', 'buying']},
#  {'type': 'ham', 'text': ['Good', 'stuff', 'will', 'do']},
#  {'type': 'ham',
#   'text': ['Just',
#    'so',
#    'that',
#    'you',
#    'knowyetunde',
#    'hasnt',
#    'sent',
#    'money',
#    'yet',
#    'I',
#    'just',
#    'sent',
#    'her',
#    'a',
#    'text',
#    'not',
#    'to',
#    'bother',
#    'sending',
#    'So',
#    'its',
#    'over',
#    'you',
#    'dont',
#    'have',
#    'to',
#    'involve',
#    'yourself',
#    'in',
#    'anything',
#    'I',
#    'shouldnt',
#    'have',
#    'imposed',
#    'anything',
#    'on',
#    'you',
#    'in',
#    'the',
#    'first',
#    'place',
#    'so',
#    'for',
#    'that',
#    'i',
#    'apologise']},
#  {'type': 'ham', 'text': ['Are', 'you', 'there', 'in', 'room']},
#  {'type': 'ham',
#   'text': ['HEY',
#    'GIRL',
#    'HOW',
#    'R',
#    'U',
#    'HOPE',
#    'U',
#    'R',
#    'WELL',
#    'ME',
#    'AN',
#    'DEL',
#    'R',
#    'BAK',
#    'AGAIN',
#    'LONG',
#    'TIME',
#    'NO',
#    'C',
#    'GIVE',
#    'ME',
#    'A',
#    'CALL',
#    'SUM',
#    'TIME',
#    'FROM',
#    'LUCYxx']},
#  {'type': 'ham', 'text': ['Kkhow', 'much', 'does', 'it', 'cost']},
#  {'type': 'ham', 'text': ['Im', 'home']},
#  {'type': 'ham', 'text': ['Dear', 'will', 'call', 'Tmorrowpls', 'accomodate']},
#  {'type': 'ham', 'text': ['First', 'answer', 'my', 'question']},
#  {'type': 'spam',
#   'text': ['Sunshine',
#    'Quiz',
#    'Wkly',
#    'Q',
#    'Win',
#    'a',
#    'top',
#    'Sony',
#    'DVD',
#    'player',
#    'if',
#    'u',
#    'know',
#    'which',
#    'country',
#    'the',
#    'Algarve',
#    'is',
#    'in',
#    'Txt',
#    'ansr',
#    'to',
#    '82277',
#    '£150',
#    'SPTyrone']},
#  {'type': 'spam',
#   'text': ['Want',
#    '2',
#    'get',
#    'laid',
#    'tonight',
#    'Want',
#    'real',
#    'Dogging',
#    'locations',
#    'sent',
#    'direct',
#    '2',
#    'ur',
#    'mob',
#    'Join',
#    'the',
#    'UKs',
#    'largest',
#    'Dogging',
#    'Network',
#    'bt',
#    'Txting',
#    'GRAVEL',
#    'to',
#    '69888',
#    'Nt',
#    'ec2a',
#    '31pmsg150p']},
#  {'type': 'ham',
#   'text': ['I', 'only', 'haf', 'msn', 'Its', 'yijuehotmailcom']},
#  {'type': 'ham',
#   'text': ['He', 'is', 'there', 'You', 'call', 'and', 'meet', 'him']},
#  {'type': 'ham',
#   'text': ['No',
#    'no',
#    'I',
#    'will',
#    'check',
#    'all',
#    'rooms',
#    'befor',
#    'activities']},
#  {'type': 'spam',
#   'text': ['Youll',
#    'not',
#    'rcv',
#    'any',
#    'more',
#    'msgs',
#    'from',
#    'the',
#    'chat',
#    'svc',
#    'For',
#    'FREE',
#    'Hardcore',
#    'services',
#    'text',
#    'GO',
#    'to',
#    '69988',
#    'If',
#    'u',
#    'get',
#    'nothing',
#    'u',
#    'must',
#    'Age',
#    'Verify',
#    'with',
#    'yr',
#    'network',
#    'try',
#    'again']},
#  {'type': 'ham',
#   'text': ['Got',
#    'c',
#    'I',
#    'lazy',
#    'to',
#    'type',
#    'I',
#    'forgot',
#    'ü',
#    'in',
#    'lect',
#    'I',
#    'saw',
#    'a',
#    'pouch',
#    'but',
#    'like',
#    'not',
#    'v',
#    'nice']},
#  {'type': 'ham',
#   'text': ['K', 'text', 'me', 'when', 'youre', 'on', 'the', 'way']},
#  {'type': 'ham', 'text': ['Sir', 'Waiting', 'for', 'your', 'mail']},
#  {'type': 'ham',
#   'text': ['A',
#    'swt',
#    'thought',
#    'Nver',
#    'get',
#    'tired',
#    'of',
#    'doing',
#    'little',
#    'things',
#    '4',
#    'lovable',
#    'persons',
#    'Cozsomtimes',
#    'those',
#    'little',
#    'things',
#    'occupy',
#    'd',
#    'biggest',
#    'part',
#    'in',
#    'their',
#    'Hearts',
#    'Gud',
#    'ni8']},
#  {'type': 'ham',
#   'text': ['I',
#    'know',
#    'you',
#    'are',
#    'Can',
#    'you',
#    'pls',
#    'open',
#    'the',
#    'back']},
#  {'type': 'ham', 'text': ['Yes', 'see', 'ya', 'not', 'on', 'the', 'dot']},
#  {'type': 'ham',
#   'text': ['Whats',
#    'the',
#    'staff',
#    'name',
#    'who',
#    'is',
#    'taking',
#    'class',
#    'for',
#    'us']},
#  {'type': 'spam',
#   'text': ['FreeMsg',
#    'Why',
#    'havent',
#    'you',
#    'replied',
#    'to',
#    'my',
#    'text',
#    'Im',
#    'Randy',
#    'sexy',
#    'female',
#    'and',
#    'live',
#    'local',
#    'Luv',
#    'to',
#    'hear',
#    'from',
#    'u',
#    'Netcollex',
#    'Ltd',
#    '08700621170150p',
#    'per',
#    'msg',
#    'reply',
#    'Stop',
#    'to',
#    'end']},
#  {'type': 'ham',
#   'text': ['Ummmawill',
#    'call',
#    'after',
#    'check',
#    'inour',
#    'life',
#    'will',
#    'begin',
#    'from',
#    'qatar',
#    'so',
#    'pls',
#    'pray',
#    'very',
#    'hard']},
#  {'type': 'ham', 'text': ['Ki', 'deleted', 'my', 'contact', 'that', 'why']},
#  {'type': 'ham', 'text': ['Sindu', 'got', 'job', 'in', 'birla', 'soft']},
#  {'type': 'ham',
#   'text': ['The',
#    'wine',
#    'is',
#    'flowing',
#    'and',
#    'im',
#    'i',
#    'have',
#    'nevering']},
#  {'type': 'ham',
#   'text': ['Yup',
#    'i',
#    'thk',
#    'cine',
#    'is',
#    'better',
#    'cos',
#    'no',
#    'need',
#    '2',
#    'go',
#    'down',
#    '2',
#    'plaza',
#    'mah']},
#  {'type': 'ham', 'text': ['Ok', 'Ur', 'typical', 'reply']},
#  {'type': 'ham',
#   'text': ['As',
#    'per',
#    'your',
#    'request',
#    'Melle',
#    'Melle',
#    'Oru',
#    'Minnaminunginte',
#    'Nurungu',
#    'Vettam',
#    'has',
#    'been',
#    'set',
#    'as',
#    'your',
#    'callertune',
#    'for',
#    'all',
#    'Callers',
#    'Press',
#    '9',
#    'to',
#    'copy',
#    'your',
#    'friends',
#    'Callertune']},
#  {'type': 'ham',
#   'text': ['You',
#    'are',
#    'everywhere',
#    'dirt',
#    'on',
#    'the',
#    'floor',
#    'the',
#    'windows',
#    'even',
#    'on',
#    'my',
#    'shirt',
#    'And',
#    'sometimes',
#    'when',
#    'i',
#    'open',
#    'my',
#    'mouth',
#    'you',
#    'are',
#    'all',
#    'that',
#    'comes',
#    'flowing',
#    'out',
#    'I',
#    'dream',
#    'of',
#    'my',
#    'world',
#    'without',
#    'you',
#    'then',
#    'half',
#    'my',
#    'chores',
#    'are',
#    'out',
#    'too',
#    'A',
#    'time',
#    'of',
#    'joy',
#    'for',
#    'me',
#    'lots',
#    'of',
#    'tv',
#    'shows',
#    'ill',
#    'see',
#    'But',
#    'i',
#    'guess',
#    'like',
#    'all',
#    'things',
#    'you',
#    'just',
#    'must',
#    'exist',
#    'like',
#    'rain',
#    'hail',
#    'and',
#    'mist',
#    'and',
#    'when',
#    'my',
#    'time',
#    'here',
#    'is',
#    'done',
#    'you',
#    'and',
#    'i',
#    'become',
#    'one']},
#  {'type': 'ham', 'text': ['Aaooooright', 'are', 'you', 'at', 'work']},
#  {'type': 'ham', 'text': ['Im', 'leaving', 'my', 'house', 'now']},
#  {'type': 'ham',
#   'text': ['Hello',
#    'my',
#    'love',
#    'What',
#    'are',
#    'you',
#    'doing',
#    'Did',
#    'you',
#    'get',
#    'to',
#    'that',
#    'interview',
#    'today',
#    'Are',
#    'you',
#    'you',
#    'happy',
#    'Are',
#    'you',
#    'being',
#    'a',
#    'good',
#    'boy',
#    'Do',
#    'you',
#    'think',
#    'of',
#    'meAre',
#    'you',
#    'missing',
#    'me']},
#  {'type': 'spam',
#   'text': ['Customer',
#    'service',
#    'annoncement',
#    'You',
#    'have',
#    'a',
#    'New',
#    'Years',
#    'delivery',
#    'waiting',
#    'for',
#    'you',
#    'Please',
#    'call',
#    '07046744435',
#    'now',
#    'to',
#    'arrange',
#    'delivery']},
#  {'type': 'spam',
#   'text': ['You',
#    'are',
#    'a',
#    'winner',
#    'U',
#    'have',
#    'been',
#    'specially',
#    'selected',
#    '2',
#    'receive',
#    '£1000',
#    'cash',
#    'or',
#    'a',
#    '4',
#    'holiday',
#    'flights',
#    'inc',
#    'speak',
#    'to',
#    'a',
#    'live',
#    'operator',
#    '2',
#    'claim',
#    '0871277810810']},
#  {'type': 'ham',
#   'text': ['Keep',
#    'yourself',
#    'safe',
#    'for',
#    'me',
#    'because',
#    'I',
#    'need',
#    'you',
#    'and',
#    'I',
#    'miss',
#    'you',
#    'already',
#    'and',
#    'I',
#    'envy',
#    'everyone',
#    'that',
#    'sees',
#    'you',
#    'in',
#    'real',
#    'life']},
#  {'type': 'ham',
#   'text': ['New',
#    'car',
#    'and',
#    'house',
#    'for',
#    'my',
#    'parentsi',
#    'have',
#    'only',
#    'new',
#    'job',
#    'in',
#    'hand']},
#  {'type': 'ham',
#   'text': ['Im',
#    'so',
#    'in',
#    'love',
#    'with',
#    'you',
#    'Im',
#    'excited',
#    'each',
#    'day',
#    'i',
#    'spend',
#    'with',
#    'you',
#    'You',
#    'make',
#    'me',
#    'so',
#    'happy']},
#  {'type': 'spam',
#   'text': ['PLS',
#    'STOP',
#    'bootydelious',
#    '32F',
#    'is',
#    'inviting',
#    'you',
#    'to',
#    'be',
#    'her',
#    'friend',
#    'Reply',
#    'YES434',
#    'or',
#    'NO434',
#    'See',
#    'her',
#    'wwwSMSacubootydelious',
#    'STOP',
#    'Send',
#    'STOP',
#    'FRND',
#    'to',
#    '62468']},
#  {'type': 'spam',
#   'text': ['BangBabes',
#    'Ur',
#    'order',
#    'is',
#    'on',
#    'the',
#    'way',
#    'U',
#    'SHOULD',
#    'receive',
#    'a',
#    'Service',
#    'Msg',
#    '2',
#    'download',
#    'UR',
#    'content',
#    'If',
#    'U',
#    'do',
#    'not',
#    'GoTo',
#    'wap',
#    'bangb',
#    'tv',
#    'on',
#    'UR',
#    'mobile',
#    'internetservice',
#    'menu']},
#  {'type': 'ham',
#   'text': ['I',
#    'place',
#    'all',
#    'ur',
#    'points',
#    'on',
#    'e',
#    'cultures',
#    'module',
#    'already']},
#  {'type': 'spam',
#   'text': ['URGENT',
#    'We',
#    'are',
#    'trying',
#    'to',
#    'contact',
#    'you',
#    'Last',
#    'weekends',
#    'draw',
#    'shows',
#    'that',
#    'you',
#    'have',
#    'won',
#    'a',
#    '£900',
#    'prize',
#    'GUARANTEED',
#    'Call',
#    '09061701939',
#    'Claim',
#    'code',
#    'S89',
#    'Valid',
#    '12hrs',
#    'only']},
#  {'type': 'ham',
#   'text': ['Hi',
#    'frnd',
#    'which',
#    'is',
#    'best',
#    'way',
#    'to',
#    'avoid',
#    'missunderstding',
#    'wit',
#    'our',
#    'beloved',
#    'ones']},
#  {'type': 'ham',
#   'text': ['Great',
#    'escape',
#    'I',
#    'fancy',
#    'the',
#    'bridge',
#    'but',
#    'needs',
#    'her',
#    'lager',
#    'See',
#    'you',
#    'tomo']},
#  {'type': 'ham',
#   'text': ['Yes',
#    'it',
#    'completely',
#    'in',
#    'out',
#    'of',
#    'formclark',
#    'also',
#    'utter',
#    'waste']},
#  {'type': 'ham',
#   'text': ['Sir',
#    'I',
#    'need',
#    'AXIS',
#    'BANK',
#    'account',
#    'no',
#    'and',
#    'bank',
#    'address']},
#  {'type': 'ham',
#   'text': ['Hmmm',
#    'Thk',
#    'sure',
#    'got',
#    'time',
#    'to',
#    'hop',
#    'ard',
#    'Ya',
#    'can',
#    'go',
#    '4',
#    'free',
#    'abt',
#    'Muz',
#    'call',
#    'u',
#    'to',
#    'discuss',
#    'liao']},
#  {'type': 'ham', 'text': ['What', 'time', 'you', 'coming', 'down', 'later']},
#  {'type': 'ham',
#   'text': ['Bloody',
#    'hell',
#    'cant',
#    'believe',
#    'you',
#    'forgot',
#    'my',
#    'surname',
#    'Mr',
#    'Ill',
#    'give',
#    'u',
#    'a',
#    'clue',
#    'its',
#    'spanish',
#    'and',
#    'begins',
#    'with',
#    'm']},
#  {'type': 'ham',
#   'text': ['Well',
#    'im',
#    'gonna',
#    'finish',
#    'my',
#    'bath',
#    'now',
#    'Have',
#    'a',
#    'goodfine',
#    'night']},
#  {'type': 'ham',
#   'text': ['Let',
#    'me',
#    'know',
#    'when',
#    'youve',
#    'got',
#    'the',
#    'money',
#    'so',
#    'carlos',
#    'can',
#    'make',
#    'the',
#    'call']},
#  {'type': 'ham', 'text': ['U', 'still', 'going', 'to', 'the', 'mall']},
#  {'type': 'ham',
#   'text': ['Turns',
#    'out',
#    'my',
#    'friends',
#    'are',
#    'staying',
#    'for',
#    'the',
#    'whole',
#    'show',
#    'and',
#    'wont',
#    'be',
#    'back',
#    'til',
#    'ltgt',
#    'so',
#    'feel',
#    'free',
#    'to',
#    'go',
#    'ahead',
#    'and',
#    'smoke',
#    'that',
#    'ltgt',
#    'worth']},
#  {'type': 'ham',
#   'text': ['Text',
#    'her',
#    'If',
#    'she',
#    'doesnt',
#    'reply',
#    'let',
#    'me',
#    'know',
#    'so',
#    'i',
#    'can',
#    'have',
#    'her',
#    'log',
#    'in']},
#  {'type': 'ham',
#   'text': ['Hi',
#    'You',
#    'just',
#    'spoke',
#    'to',
#    'MANEESHA',
#    'V',
#    'Wed',
#    'like',
#    'to',
#    'know',
#    'if',
#    'you',
#    'were',
#    'satisfied',
#    'with',
#    'the',
#    'experience',
#    'Reply',
#    'Toll',
#    'Free',
#    'with',
#    'Yes',
#    'or',
#    'No']},
#  {'type': 'ham',
#   'text': ['You',
#    'lifted',
#    'my',
#    'hopes',
#    'with',
#    'the',
#    'offer',
#    'of',
#    'money',
#    'I',
#    'am',
#    'in',
#    'need',
#    'Especially',
#    'when',
#    'the',
#    'end',
#    'of',
#    'the',
#    'month',
#    'approaches',
#    'and',
#    'it',
#    'hurts',
#    'my',
#    'studying',
#    'Anyways',
#    'have',
#    'a',
#    'gr8',
#    'weekend']},
#  {'type': 'ham', 'text': ['Lol', 'no', 'U', 'can', 'trust', 'me']},
#  {'type': 'ham',
#   'text': ['ok',
#    'I',
#    'am',
#    'a',
#    'gentleman',
#    'and',
#    'will',
#    'treat',
#    'you',
#    'with',
#    'dignity',
#    'and',
#    'respect']},
#  {'type': 'ham', 'text': ['He', 'will', 'you', 'guys', 'close']},
#  {'type': 'ham', 'text': ['Going', 'on', 'nothing', 'greatbye']},
#  {'type': 'ham',
#   'text': ['Hello',
#    'handsome',
#    'Are',
#    'you',
#    'finding',
#    'that',
#    'job',
#    'Not',
#    'being',
#    'lazy',
#    'Working',
#    'towards',
#    'getting',
#    'back',
#    'that',
#    'net',
#    'for',
#    'mummy',
#    'Wheres',
#    'my',
#    'boytoy',
#    'now',
#    'Does',
#    'he',
#    'miss',
#    'me']},
#  {'type': 'ham',
#   'text': ['Haha', 'awesome', 'be', 'there', 'in', 'a', 'minute']},
#  {'type': 'spam',
#   'text': ['Please',
#    'call',
#    'our',
#    'customer',
#    'service',
#    'representative',
#    'on',
#    'FREEPHONE',
#    '0808',
#    '145',
#    '4742',
#    'between',
#    '9am11pm',
#    'as',
#    'you',
#    'have',
#    'WON',
#    'a',
#    'guaranteed',
#    '£1000',
#    'cash',
#    'or',
#    '£5000',
#    'prize']},
#  {'type': 'ham',
#   'text': ['Have',
#    'you',
#    'got',
#    'Xmas',
#    'radio',
#    'times',
#    'If',
#    'not',
#    'i',
#    'will',
#    'get',
#    'it',
#    'now']},
#  {'type': 'ham',
#   'text': ['I',
#    'jus',
#    'reached',
#    'home',
#    'I',
#    'go',
#    'bathe',
#    'first',
#    'But',
#    'my',
#    'sis',
#    'using',
#    'net',
#    'tell',
#    'u',
#    'when',
#    'she',
#    'finishes',
#    'k']},
#  {'type': 'spam',
#   'text': ['Are',
#    'you',
#    'unique',
#    'enough',
#    'Find',
#    'out',
#    'from',
#    '30th',
#    'August',
#    'wwwareyouuniquecouk']},
#  {'type': 'ham',
#   'text': ['Im',
#    'sorry',
#    'Ive',
#    'joined',
#    'the',
#    'league',
#    'of',
#    'people',
#    'that',
#    'dont',
#    'keep',
#    'in',
#    'touch',
#    'You',
#    'mean',
#    'a',
#    'great',
#    'deal',
#    'to',
#    'me',
#    'You',
#    'have',
#    'been',
#    'a',
#    'friend',
#    'at',
#    'all',
#    'times',
#    'even',
#    'at',
#    'great',
#    'personal',
#    'cost',
#    'Do',
#    'have',
#    'a',
#    'great',
#    'week']},
#  {'type': 'ham', 'text': ['Hi', 'finally', 'i', 'completed', 'the', 'course']},
#  {'type': 'ham',
#   'text': ['It',
#    'will',
#    'stop',
#    'on',
#    'itself',
#    'I',
#    'however',
#    'suggest',
#    'she',
#    'stays',
#    'with',
#    'someone',
#    'that',
#    'will',
#    'be',
#    'able',
#    'to',
#    'give',
#    'ors',
#    'for',
#    'every',
#    'stool']},
#  {'type': 'ham',
#   'text': ['How',
#    'are',
#    'you',
#    'doing',
#    'Hope',
#    'youve',
#    'settled',
#    'in',
#    'for',
#    'the',
#    'new',
#    'school',
#    'year',
#    'Just',
#    'wishin',
#    'you',
#    'a',
#    'gr8',
#    'day']},
#  {'type': 'ham', 'text': ['Gud', 'mrng', 'dear', 'hav', 'a', 'nice', 'day']},
#  {'type': 'ham', 'text': ['Did', 'u', 'got', 'that', 'persons', 'story']},
#  {'type': 'ham',
#   'text': ['is',
#    'your',
#    'hamster',
#    'dead',
#    'Hey',
#    'so',
#    'tmr',
#    'i',
#    'meet',
#    'you',
#    'at',
#    '1pm',
#    'orchard',
#    'mrt']},
#  {'type': 'ham',
#   'text': ['Hi',
#    'its',
#    'Kate',
#    'how',
#    'is',
#    'your',
#    'evening',
#    'I',
#    'hope',
#    'i',
#    'can',
#    'see',
#    'you',
#    'tomorrow',
#    'for',
#    'a',
#    'bit',
#    'but',
#    'i',
#    'have',
#    'to',
#    'bloody',
#    'babyjontet',
#    'Txt',
#    'back',
#    'if',
#    'u',
#    'can',
#    'xxx']},
#  {'type': 'ham', 'text': ['Found', 'it', 'ENC', 'ltgt', 'where', 'you', 'at']},
#  {'type': 'ham', 'text': ['I', 'sent', 'you', 'ltgt', 'bucks']},
#  {'type': 'ham',
#   'text': ['Hello',
#    'darlin',
#    'ive',
#    'finished',
#    'college',
#    'now',
#    'so',
#    'txt',
#    'me',
#    'when',
#    'u',
#    'finish',
#    'if',
#    'u',
#    'can',
#    'love',
#    'Kate',
#    'xxx']},
#  {'type': 'ham',
#   'text': ['Your',
#    'account',
#    'has',
#    'been',
#    'refilled',
#    'successfully',
#    'by',
#    'INR',
#    'ltDECIMALgt',
#    'Your',
#    'KeralaCircle',
#    'prepaid',
#    'account',
#    'balance',
#    'is',
#    'Rs',
#    'ltDECIMALgt',
#    'Your',
#    'Transaction',
#    'ID',
#    'is',
#    'KR',
#    'ltgt']},
#  {'type': 'ham', 'text': ['Goodmorning', 'sleeping', 'ga']},
#  {'type': 'ham', 'text': ['U', 'call', 'me', 'alter', 'at', '11', 'ok']},
#  {'type': 'ham',
#   'text': ['Ü',
#    'say',
#    'until',
#    'like',
#    'dat',
#    'i',
#    'dun',
#    'buy',
#    'ericsson',
#    'oso',
#    'cannot',
#    'oredi',
#    'lar']},
#  {'type': 'ham',
#   'text': ['As',
#    'I',
#    'entered',
#    'my',
#    'cabin',
#    'my',
#    'PA',
#    'said',
#    'Happy',
#    'Bday',
#    'Boss',
#    'I',
#    'felt',
#    'special',
#    'She',
#    'askd',
#    'me',
#    '4',
#    'lunch',
#    'After',
#    'lunch',
#    'she',
#    'invited',
#    'me',
#    'to',
#    'her',
#    'apartment',
#    'We',
#    'went',
#    'there']},
#  {'type': 'ham', 'text': ['Aight', 'yo', 'dats', 'straight', 'dogg']},
#  {'type': 'ham',
#   'text': ['You',
#    'please',
#    'give',
#    'us',
#    'connection',
#    'today',
#    'itself',
#    'before',
#    'ltDECIMALgt',
#    'or',
#    'refund',
#    'the',
#    'bill']},
#  {'type': 'ham',
#   'text': ['Both', 'i', 'shoot', 'big', 'loads', 'so', 'get', 'ready']},
#  {'type': 'ham',
#   'text': ['Whats',
#    'up',
#    'bruv',
#    'hope',
#    'you',
#    'had',
#    'a',
#    'great',
#    'break',
#    'Do',
#    'have',
#    'a',
#    'rewarding',
#    'semester']},
#  {'type': 'ham', 'text': ['Home', 'so', 'we', 'can', 'always', 'chat']},
#  {'type': 'ham', 'text': ['Kkgoodstudy', 'well']},
#  {'type': 'ham', 'text': ['Yup', 'How', 'ü', 'noe', 'leh']},
#  {'type': 'ham', 'text': ['Sounds', 'great', 'Are', 'you', 'home', 'now']},
#  {'type': 'ham',
#   'text': ['Finally',
#    'the',
#    'match',
#    'heading',
#    'towards',
#    'draw',
#    'as',
#    'your',
#    'prediction']},
#  {'type': 'ham',
#   'text': ['Tired',
#    'I',
#    'havent',
#    'slept',
#    'well',
#    'the',
#    'past',
#    'few',
#    'nights']},
#  {'type': 'ham',
#   'text': ['Easy', 'ahsen', 'got', 'selected', 'means', 'its', 'good']},
#  {'type': 'ham',
#   'text': ['I', 'have', 'to', 'take', 'exam', 'with', 'march', '3']},
#  {'type': 'ham',
#   'text': ['Yeah',
#    'you',
#    'should',
#    'I',
#    'think',
#    'you',
#    'can',
#    'use',
#    'your',
#    'gt',
#    'atm',
#    'now',
#    'to',
#    'register',
#    'Not',
#    'sure',
#    'but',
#    'if',
#    'theres',
#    'anyway',
#    'i',
#    'can',
#    'help',
#    'let',
#    'me',
#    'know',
#    'But',
#    'when',
#    'you',
#    'do',
#    'be',
#    'sure',
#    'you',
#    'are',
#    'ready']},
#  {'type': 'ham', 'text': ['Ok', 'no', 'prob', 'Take', 'ur', 'time']},
#  {'type': 'ham',
#   'text': ['There',
#    'is',
#    'os',
#    'called',
#    'ubandu',
#    'which',
#    'will',
#    'run',
#    'without',
#    'installing',
#    'in',
#    'hard',
#    'diskyou',
#    'can',
#    'use',
#    'that',
#    'os',
#    'to',
#    'copy',
#    'the',
#    'important',
#    'files',
#    'in',
#    'system',
#    'and',
#    'give',
#    'it',
#    'to',
#    'repair',
#    'shop']},
#  {'type': 'ham', 'text': ['Sorry', 'Ill', 'call', 'later']},
#  {'type': 'ham',
#   'text': ['U',
#    'say',
#    'leh',
#    'Of',
#    'course',
#    'nothing',
#    'happen',
#    'lar',
#    'Not',
#    'say',
#    'v',
#    'romantic',
#    'jus',
#    'a',
#    'bit',
#    'only',
#    'lor',
#    'I',
#    'thk',
#    'e',
#    'nite',
#    'scenery',
#    'not',
#    'so',
#    'nice',
#    'leh']},
#  {'type': 'spam',
#   'text': ['500',
#    'New',
#    'Mobiles',
#    'from',
#    '2004',
#    'MUST',
#    'GO',
#    'Txt',
#    'NOKIA',
#    'to',
#    'No',
#    '89545',
#    'collect',
#    'yours',
#    'todayFrom',
#    'ONLY',
#    '£1',
#    'www4tcbiz',
#    '2optout',
#    '08718726270150gbpmtmsg18']},
#  {'type': 'ham',
#   'text': ['Would',
#    'really',
#    'appreciate',
#    'if',
#    'you',
#    'call',
#    'me',
#    'Just',
#    'need',
#    'someone',
#    'to',
#    'talk',
#    'to']},
#  {'type': 'spam',
#   'text': ['Will',
#    'u',
#    'meet',
#    'ur',
#    'dream',
#    'partner',
#    'soon',
#    'Is',
#    'ur',
#    'career',
#    'off',
#    '2',
#    'a',
#    'flyng',
#    'start',
#    '2',
#    'find',
#    'out',
#    'free',
#    'txt',
#    'HORO',
#    'followed',
#    'by',
#    'ur',
#    'star',
#    'sign',
#    'e',
#    'g',
#    'HORO',
#    'ARIES']},
#  {'type': 'ham', 'text': ['Hey', 'company', 'elama', 'po', 'mudyadhu']},
#  {'type': 'ham',
#   'text': ['Life',
#    'is',
#    'more',
#    'strict',
#    'than',
#    'teacher',
#    'Bcoz',
#    'Teacher',
#    'teaches',
#    'lesson',
#    'amp',
#    'then',
#    'conducts',
#    'exam',
#    'But',
#    'Life',
#    'first',
#    'conducts',
#    'Exam',
#    'amp',
#    'then',
#    'teaches',
#    'Lessons',
#    'Happy',
#    'morning']},
#  {'type': 'ham',
#   'text': ['Dear', 'good', 'morning', 'now', 'only', 'i', 'am', 'up']},
#  {'type': 'ham',
#   'text': ['Get',
#    'down',
#    'in',
#    'gandhipuram',
#    'and',
#    'walk',
#    'to',
#    'cross',
#    'cut',
#    'road',
#    'Right',
#    'side',
#    'ltgt',
#    'street',
#    'road',
#    'and',
#    'turn',
#    'at',
#    'first',
#    'right']},
#  {'type': 'ham',
#   'text': ['Dear', 'we', 'are', 'going', 'to', 'our', 'rubber', 'place']},
#  {'type': 'ham', 'text': ['Sorry', 'battery', 'died', 'yeah', 'Im', 'here']},
#  {'type': 'ham',
#   'text': ['Yeshere',
#    'tv',
#    'is',
#    'always',
#    'available',
#    'in',
#    'work',
#    'place']},
#  {'type': 'spam',
#   'text': ['Text',
#    'meet',
#    'someone',
#    'sexy',
#    'today',
#    'U',
#    'can',
#    'find',
#    'a',
#    'date',
#    'or',
#    'even',
#    'flirt',
#    'its',
#    'up',
#    'to',
#    'U',
#    'Join',
#    '4',
#    'just',
#    '10p',
#    'REPLY',
#    'with',
#    'NAME',
#    'AGE',
#    'eg',
#    'Sam',
#    '25',
#    '18',
#    'msg',
#    'recdthirtyeight',
#    'pence']},
#  {'type': 'ham',
#   'text': ['I',
#    'have',
#    'printed',
#    'it',
#    'oh',
#    'So',
#    'ltgt',
#    'come',
#    'upstairs']},
#  {'type': 'ham',
#   'text': ['Or',
#    'ill',
#    'be',
#    'a',
#    'little',
#    'closer',
#    'like',
#    'at',
#    'the',
#    'bus',
#    'stop',
#    'on',
#    'the',
#    'same',
#    'street']},
#  {'type': 'ham',
#   'text': ['Where', 'are', 'youwhen', 'wil', 'you', 'reach', 'here']},
#  {'type': 'ham',
#   'text': ['New',
#    'Theory',
#    'Argument',
#    'wins',
#    'd',
#    'SITUATION',
#    'but',
#    'loses',
#    'the',
#    'PERSON',
#    'So',
#    'dont',
#    'argue',
#    'with',
#    'ur',
#    'friends',
#    'just',
#    'kick',
#    'them',
#    'amp',
#    'say',
#    'Im',
#    'always',
#    'correct']},
#  {'type': 'spam',
#   'text': ['U',
#    '447801259231',
#    'have',
#    'a',
#    'secret',
# ...
#    'to',
#    'send',
#    'you',
#    'a',
#    'reminder',
#    'today',
#    'Have',
#    'a',
#    'wonderful',
#    'weekend']},
#  {'type': 'ham',
#   'text': ['When',
#    'people',
#    'see',
#    'my',
#    'msgs',
#    'They',
#    'think',
#    'Iam',
#    'addicted',
#    'to',
#    'msging',
#    'They',
#    'are',
#    'wrong',
#    'Bcoz',
#    'They',
#    'dont',
#    'know',
#    'that',
#    'Iam',
#    'addicted',
#    'to',
#    'my',
#    'sweet',
#    'Friends',
#    'BSLVYL']},
#  {'type': 'ham',
#   'text': ['Hey',
#    'you',
#    'gave',
#    'them',
#    'your',
#    'photo',
#    'when',
#    'you',
#    'registered',
#    'for',
#    'driving',
#    'ah',
#    'Tmr',
#    'wanna',
#    'meet',
#    'at',
#    'yck']},
#  {'type': 'ham',
#   'text': ['Dont', 'talk', 'to', 'him', 'ever', 'ok', 'its', 'my', 'word']},
#  {'type': 'ham', 'text': ['When', 'u', 'wana', 'see', 'it', 'then']},
#  {'type': 'ham',
#   'text': ['On',
#    'ma',
#    'way',
#    'to',
#    'school',
#    'Can',
#    'you',
#    'pls',
#    'send',
#    'me',
#    'ashleys',
#    'number']},
#  {'type': 'ham',
#   'text': ['It',
#    'shall',
#    'be',
#    'fine',
#    'I',
#    'have',
#    'avalarr',
#    'now',
#    'Will',
#    'hollalater']},
#  {'type': 'ham',
#   'text': ['She',
#    'went',
#    'to',
#    'attend',
#    'another',
#    'two',
#    'rounds',
#    'todaybut',
#    'still',
#    'didt',
#    'reach',
#    'home']},
#  {'type': 'ham',
#   'text': ['Actually',
#    'i',
#    'deleted',
#    'my',
#    'old',
#    'websitenow',
#    'i',
#    'm',
#    'blogging',
#    'at',
#    'magicalsongsblogspotcom']},
#  {'type': 'ham',
#   'text': ['K', 'wait', 'chikkuil', 'send', 'aftr', 'ltgt', 'mins']},
#  {'type': 'ham',
#   'text': ['But',
#    'Im',
#    'on',
#    'a',
#    'diet',
#    'And',
#    'I',
#    'ate',
#    '1',
#    'too',
#    'many',
#    'slices',
#    'of',
#    'pizza',
#    'yesterday',
#    'Ugh',
#    'Im',
#    'ALWAYS',
#    'on',
#    'a',
#    'diet']},
#  {'type': 'ham',
#   'text': ['Ki', 'will', 'give', 'my', 'kvb', 'acc', 'details']},
#  {'type': 'ham', 'text': ['Oh', 'all', 'have', 'to', 'come', 'ah']},
#  {'type': 'spam',
#   'text': ['money',
#    'you',
#    'r',
#    'a',
#    'lucky',
#    'winner',
#    '2',
#    'claim',
#    'your',
#    'prize',
#    'text',
#    'money',
#    '2',
#    '88600',
#    'over',
#    '£1million',
#    'to',
#    'give',
#    'away',
#    'ppt150x3normal',
#    'text',
#    'rate',
#    'box403',
#    'w1t1jy']},
#  {'type': 'ham',
#   'text': ['Im',
#    'really',
#    'sorry',
#    'i',
#    'wont',
#    'b',
#    'able',
#    '2',
#    'do',
#    'this',
#    'fridayhope',
#    'u',
#    'can',
#    'find',
#    'an',
#    'alternativehope',
#    'yr',
#    'terms',
#    'going',
#    'ok']},
#  {'type': 'ham',
#   'text': ['Congratulations',
#    'ore',
#    'mo',
#    'owo',
#    're',
#    'wa',
#    'Enjoy',
#    'it',
#    'and',
#    'i',
#    'wish',
#    'you',
#    'many',
#    'happy',
#    'moments',
#    'to',
#    'and',
#    'fro',
#    'wherever',
#    'you',
#    'go']},
#  {'type': 'ham',
#   'text': ['So', 'do', 'you', 'have', 'samus', 'shoulders', 'yet']},
#  {'type': 'ham',
#   'text': ['What',
#    'time',
#    'you',
#    'think',
#    'youll',
#    'have',
#    'it',
#    'Need',
#    'to',
#    'know',
#    'when',
#    'I',
#    'should',
#    'be',
#    'near',
#    'campus']},
#  {'type': 'spam',
#   'text': ['Dear',
#    'Matthew',
#    'please',
#    'call',
#    '09063440451',
#    'from',
#    'a',
#    'landline',
#    'your',
#    'complimentary',
#    '4Lux',
#    'Tenerife',
#    'holiday',
#    'or',
#    '£1000',
#    'CASH',
#    'await',
#    'collection',
#    'ppm150',
#    'SAE',
#    'TCs',
#    'Box334',
#    'SK38XH']},
#  {'type': 'ham', 'text': ['Then', 'dun', 'wear', 'jeans', 'lor']},
#  {'type': 'ham',
#   'text': ['Since',
#    'when',
#    'which',
#    'side',
#    'any',
#    'fever',
#    'any',
#    'vomitin']},
#  {'type': 'ham', 'text': ['Kkare', 'you', 'in', 'college']},
#  {'type': 'spam',
#   'text': ['Urgent',
#    'call',
#    '09061749602',
#    'from',
#    'Landline',
#    'Your',
#    'complimentary',
#    '4',
#    'Tenerife',
#    'Holiday',
#    'or',
#    '£10000',
#    'cash',
#    'await',
#    'collection',
#    'SAE',
#    'TCs',
#    'BOX',
#    '528',
#    'HP20',
#    '1YF',
#    '150ppm',
#    '18']},
#  {'type': 'ham',
#   'text': ['Better',
#    'Made',
#    'up',
#    'for',
#    'Friday',
#    'and',
#    'stuffed',
#    'myself',
#    'like',
#    'a',
#    'pig',
#    'yesterday',
#    'Now',
#    'I',
#    'feel',
#    'bleh',
#    'But',
#    'at',
#    'least',
#    'its',
#    'not',
#    'writhing',
#    'pain',
#    'kind',
#    'of',
#    'bleh']},
#  {'type': 'ham',
#   'text': ['No',
#    'we',
#    'sell',
#    'it',
#    'all',
#    'so',
#    'well',
#    'have',
#    'tons',
#    'if',
#    'coins',
#    'Then',
#    'sell',
#    'our',
#    'coins',
#    'to',
#    'someone',
#    'thru',
#    'paypal',
#    'Voila',
#    'Money',
#    'back',
#    'in',
#    'life',
#    'pockets']},
#  {'type': 'ham',
#   'text': ['Theyre',
#    'doing',
#    'it',
#    'to',
#    'lots',
#    'of',
#    'places',
#    'Only',
#    'hospitals',
#    'and',
#    'medical',
#    'places',
#    'are',
#    'safe']},
#  {'type': 'spam',
#   'text': ['How',
#    'about',
#    'getting',
#    'in',
#    'touch',
#    'with',
#    'folks',
#    'waiting',
#    'for',
#    'company',
#    'Just',
#    'txt',
#    'back',
#    'your',
#    'NAME',
#    'and',
#    'AGE',
#    'to',
#    'opt',
#    'in',
#    'Enjoy',
#    'the',
#    'community',
#    '150pSMS']},
#  {'type': 'ham',
#   'text': ['And',
#    'also',
#    'Ive',
#    'sorta',
#    'blown',
#    'him',
#    'off',
#    'a',
#    'couple',
#    'times',
#    'recently',
#    'so',
#    'id',
#    'rather',
#    'not',
#    'text',
#    'him',
#    'out',
#    'of',
#    'the',
#    'blue',
#    'looking',
#    'for',
#    'weed']},
#  {'type': 'ham',
#   'text': ['I',
#    'sent',
#    'my',
#    'scores',
#    'to',
#    'sophas',
#    'and',
#    'i',
#    'had',
#    'to',
#    'do',
#    'secondary',
#    'application',
#    'for',
#    'a',
#    'few',
#    'schools',
#    'I',
#    'think',
#    'if',
#    'you',
#    'are',
#    'thinking',
#    'of',
#    'applying',
#    'do',
#    'a',
#    'research',
#    'on',
#    'cost',
#    'also',
#    'Contact',
#    'joke',
#    'ogunrinde',
#    'her',
#    'school',
#    'is',
#    'one',
#    'me',
#    'the',
#    'less',
#    'expensive',
#    'ones']},
#  {'type': 'ham',
#   'text': ['I',
#    'cant',
#    'wait',
#    'to',
#    'see',
#    'you',
#    'How',
#    'were',
#    'the',
#    'photos',
#    'were',
#    'useful']},
#  {'type': 'spam',
#   'text': ['Ur',
#    'cashbalance',
#    'is',
#    'currently',
#    '500',
#    'pounds',
#    'to',
#    'maximize',
#    'ur',
#    'cashin',
#    'now',
#    'send',
#    'GO',
#    'to',
#    '86688',
#    'only',
#    '150pmsg',
#    'CC',
#    '08718720201',
#    'PO',
#    'BOX',
#    '11414',
#    'TCRW1']},
#  {'type': 'ham',
#   'text': ['Hey',
#    'i',
#    'booked',
#    'the',
#    'kb',
#    'on',
#    'sat',
#    'already',
#    'what',
#    'other',
#    'lessons',
#    'are',
#    'we',
#    'going',
#    'for',
#    'ah',
#    'Keep',
#    'your',
#    'sat',
#    'night',
#    'free',
#    'we',
#    'need',
#    'to',
#    'meet',
#    'and',
#    'confirm',
#    'our',
#    'lodging']},
#  {'type': 'ham', 'text': ['Chk', 'in', 'ur', 'belovd', 'ms', 'dict']},
#  {'type': 'ham',
#   'text': ['Is', 'that', 'what', 'time', 'you', 'want', 'me', 'to', 'come']},
#  {'type': 'ham',
#   'text': ['Awesome', 'lemme', 'know', 'whenever', 'youre', 'around']},
#  {'type': 'ham', 'text': ['Shb', 'b', 'ok', 'lor', 'Thanx']},
#  {'type': 'ham',
#   'text': ['Beautiful',
#    'Truth',
#    'against',
#    'Gravity',
#    'Read',
#    'carefully',
#    'Our',
#    'heart',
#    'feels',
#    'light',
#    'when',
#    'someone',
#    'is',
#    'in',
#    'it',
#    'But',
#    'it',
#    'feels',
#    'very',
#    'heavy',
#    'when',
#    'someone',
#    'leaves',
#    'it',
#    'GOOD',
#    'NIGHT']},
#  {'type': 'ham',
#   'text': ['Also',
#    'remember',
#    'to',
#    'get',
#    'dobbys',
#    'bowl',
#    'from',
#    'your',
#    'car']},
#  {'type': 'spam',
#   'text': ['Filthy', 'stories', 'and', 'GIRLS', 'waiting', 'for', 'your']},
#  {'type': 'ham',
#   'text': ['Sorry',
#    'i',
#    'now',
#    'then',
#    'c',
#    'ur',
#    'msg',
#    'Yar',
#    'lor',
#    'so',
#    'poor',
#    'thing',
#    'But',
#    'only',
#    '4',
#    'one',
#    'night',
#    'Tmr',
#    'ull',
#    'have',
#    'a',
#    'brand',
#    'new',
#    'room',
#    '2',
#    'sleep',
#    'in']},
#  {'type': 'ham',
#   'text': ['Love',
#    'isnt',
#    'a',
#    'decision',
#    'its',
#    'a',
#    'feeling',
#    'If',
#    'we',
#    'could',
#    'decide',
#    'who',
#    'to',
#    'love',
#    'then',
#    'life',
#    'would',
#    'be',
#    'much',
#    'simpler',
#    'but',
#    'then',
#    'less',
#    'magical']},
#  {'type': 'ham', 'text': ['Welp', 'apparently', 'he', 'retired']},
#  {'type': 'ham',
#   'text': ['My',
#    'sort',
#    'code',
#    'is',
#    'and',
#    'acc',
#    'no',
#    'is',
#    'The',
#    'bank',
#    'is',
#    'natwest',
#    'Can',
#    'you',
#    'reply',
#    'to',
#    'confirm',
#    'ive',
#    'sent',
#    'this',
#    'to',
#    'the',
#    'right',
#    'person']},
#  {'type': 'ham', 'text': ['Where']},
#  {'type': 'ham',
#   'text': ['U', 'sure', 'u', 'cant', 'take', 'any', 'sick', 'time']},
#  {'type': 'spam',
#   'text': ['URGENT',
#    'We',
#    'are',
#    'trying',
#    'to',
#    'contact',
#    'U',
#    'Todays',
#    'draw',
#    'shows',
#    'that',
#    'you',
#    'have',
#    'won',
#    'a',
#    '£800',
#    'prize',
#    'GUARANTEED',
#    'Call',
#    '09050001808',
#    'from',
#    'land',
#    'line',
#    'Claim',
#    'M95',
#    'Valid12hrs',
#    'only']},
#  {'type': 'ham',
#   'text': ['Watching',
#    'cartoon',
#    'listening',
#    'music',
#    'amp',
#    'at',
#    'eve',
#    'had',
#    'to',
#    'go',
#    'temple',
#    'amp',
#    'church',
#    'What',
#    'about',
#    'u']},
#  {'type': 'ham',
#   'text': ['Yo',
#    'chad',
#    'which',
#    'gymnastics',
#    'class',
#    'do',
#    'you',
#    'wanna',
#    'take',
#    'The',
#    'site',
#    'says',
#    'Christians',
#    'class',
#    'is',
#    'full']},
#  {'type': 'ham', 'text': ['Are', 'you', 'this', 'much', 'buzy']},
#  {'type': 'ham',
#   'text': ['Or',
#    'better',
#    'still',
#    'can',
#    'you',
#    'catch',
#    'her',
#    'and',
#    'let',
#    'ask',
#    'her',
#    'if',
#    'she',
#    'can',
#    'sell',
#    'ltgt',
#    'for',
#    'me']},
#  {'type': 'ham',
#   'text': ['I',
#    'am',
#    'not',
#    'sure',
#    'about',
#    'night',
#    'menu',
#    'I',
#    'know',
#    'only',
#    'about',
#    'noon',
#    'menu']},
#  {'type': 'ham',
#   'text': ['What',
#    'do',
#    'u',
#    'want',
#    'when',
#    'i',
#    'come',
#    'backa',
#    'beautiful',
#    'necklace',
#    'as',
#    'a',
#    'token',
#    'of',
#    'my',
#    'heart',
#    'for',
#    'youthats',
#    'what',
#    'i',
#    'will',
#    'give',
#    'but',
#    'ONLY',
#    'to',
#    'MY',
#    'WIFE',
#    'OF',
#    'MY',
#    'LIKINGBE',
#    'THAT',
#    'AND',
#    'SEENO',
#    'ONE',
#    'can',
#    'give',
#    'you',
#    'thatdont',
#    'call',
#    'mei',
#    'will',
#    'wait',
#    'till',
#    'i',
#    'come']},
#  {'type': 'ham',
#   'text': ['Are', 'you', 'willing', 'to', 'go', 'for', 'aptitude', 'class']},
#  {'type': 'ham',
#   'text': ['It',
#    'wont',
#    'b',
#    'until',
#    '215',
#    'as',
#    'trying',
#    '2',
#    'sort',
#    'house',
#    'out',
#    'is',
#    'that',
#    'ok']},
#  {'type': 'ham',
#   'text': ['Yar',
#    'lor',
#    'he',
#    'wan',
#    '2',
#    'go',
#    'c',
#    'horse',
#    'racing',
#    'today',
#    'mah',
#    'so',
#    'eat',
#    'earlier',
#    'lor',
#    'I',
#    'ate',
#    'chicken',
#    'rice',
#    'U']},
#  {'type': 'ham', 'text': ['Haha', 'awesome', 'omw', 'back', 'now', 'then']},
#  {'type': 'ham',
#   'text': ['Yup', 'i', 'thk', 'so', 'until', 'e', 'shop', 'closes', 'lor']},
#  {'type': 'ham', 'text': ['what', 'is', 'your', 'account', 'number']},
#  {'type': 'ham', 'text': ['Eh', 'u', 'send', 'wrongly', 'lar']},
#  {'type': 'ham',
#   'text': ['Hey',
#    'no',
#    'I',
#    'ad',
#    'a',
#    'crap',
#    'nite',
#    'was',
#    'borin',
#    'without',
#    'ya',
#    '2',
#    'boggy',
#    'with',
#    'me',
#    'u',
#    'boring',
#    'biatch',
#    'Thanx',
#    'but',
#    'u',
#    'wait',
#    'til',
#    'nxt',
#    'time',
#    'il',
#    'ave',
#    'ya']},
#  {'type': 'ham', 'text': ['Ok', 'i', 'shall', 'talk', 'to', 'him']},
#  {'type': 'ham',
#   'text': ['Dont',
#    'hesitate',
#    'You',
#    'know',
#    'this',
#    'is',
#    'the',
#    'second',
#    'time',
#    'she',
#    'has',
#    'had',
#    'weakness',
#    'like',
#    'that',
#    'So',
#    'keep',
#    'i',
#    'notebook',
#    'of',
#    'what',
#    'she',
#    'eat',
#    'and',
#    'did',
#    'the',
#    'day',
#    'before',
#    'or',
#    'if',
#    'anything',
#    'changed',
#    'the',
#    'day',
#    'before',
#    'so',
#    'that',
#    'we',
#    'can',
#    'be',
#    'sure',
#    'its',
#    'nothing']},
#  {'type': 'ham',
#   'text': ['Hey',
#    'you',
#    'can',
#    'pay',
#    'With',
#    'salary',
#    'de',
#    'Only',
#    'ltgt']},
#  {'type': 'ham',
#   'text': ['Another',
#    'month',
#    'I',
#    'need',
#    'chocolate',
#    'weed',
#    'and',
#    'alcohol']},
#  {'type': 'ham',
#   'text': ['If',
#    'he',
#    'started',
#    'searching',
#    'he',
#    'will',
#    'get',
#    'job',
#    'in',
#    'few',
#    'dayshe',
#    'have',
#    'great',
#    'potential',
#    'and',
#    'talent']},
#  {'type': 'ham',
#   'text': ['Reckon',
#    'need',
#    'to',
#    'be',
#    'in',
#    'town',
#    'by',
#    'eightish',
#    'to',
#    'walk',
#    'from',
#    'carpark']},
#  {'type': 'spam',
#   'text': ['Congrats',
#    '2',
#    'mobile',
#    '3G',
#    'Videophones',
#    'R',
#    'yours',
#    'call',
#    '09063458130',
#    'now',
#    'videochat',
#    'wid',
#    'your',
#    'mates',
#    'play',
#    'java',
#    'games',
#    'Dload',
#    'polyPH',
#    'music',
#    'noline',
#    'rentl']},
#  {'type': 'ham',
#   'text': ['LOOK',
#    'AT',
#    'THE',
#    'FUCKIN',
#    'TIME',
#    'WHAT',
#    'THE',
#    'FUCK',
#    'YOU',
#    'THINK',
#    'IS',
#    'UP']},
#  {'type': 'ham', 'text': ['Yo', 'guess', 'what', 'I', 'just', 'dropped']},
#  {'type': 'ham',
#   'text': ['Carlos',
#    'says',
#    'hell',
#    'be',
#    'at',
#    'mu',
#    'in',
#    'ltgt',
#    'minutes']},
#  {'type': 'ham',
#   'text': ['Im',
#    'in',
#    'office',
#    'now',
#    'I',
#    'will',
#    'call',
#    'you',
#    'ltgt',
#    'min']},
#  {'type': 'ham',
#   'text': ['Geeee',
#    'I',
#    'miss',
#    'you',
#    'already',
#    'you',
#    'know',
#    'Your',
#    'all',
#    'I',
#    'can',
#    'think',
#    'about',
#    'Fuck',
#    'I',
#    'cant',
#    'wait',
#    'till',
#    'next',
#    'year',
#    'when',
#    'we',
#    'will',
#    'be',
#    'together',
#    'loving',
#    'kiss']},
#  {'type': 'ham',
#   'text': ['Yun',
#    'ahthe',
#    'ubi',
#    'one',
#    'say',
#    'if',
#    'ü',
#    'wan',
#    'call',
#    'by',
#    'tomorrowcall',
#    '67441233',
#    'look',
#    'for',
#    'ireneere',
#    'only',
#    'got',
#    'bus822656166382',
#    'Ubi',
#    'cresubi',
#    'tech',
#    'park6ph',
#    'for',
#    '1st',
#    '5wkg',
#    'daysèn']},
#  {'type': 'ham',
#   'text': ['Ugh',
#    'Gotta',
#    'drive',
#    'back',
#    'to',
#    'sd',
#    'from',
#    'la',
#    'My',
#    'butt',
#    'is',
#    'sore']},
#  {'type': 'ham', 'text': ['26th', 'OF', 'JULY']},
#  {'type': 'ham',
#   'text': ['Hi',
#    'im',
#    'having',
#    'the',
#    'most',
#    'relaxing',
#    'time',
#    'ever',
#    'we',
#    'have',
#    'to',
#    'get',
#    'up',
#    'at',
#    '7am',
#    'every',
#    'day',
#    'was',
#    'the',
#    'party',
#    'good',
#    'the',
#    'other',
#    'night',
#    'I',
#    'get',
#    'home',
#    'tomorrow',
#    'at',
#    '5ish']},
#  {'type': 'ham',
#   'text': ['Up',
#    'to',
#    'ü',
#    'Ü',
#    'wan',
#    'come',
#    'then',
#    'come',
#    'lor',
#    'But',
#    'i',
#    'din',
#    'c',
#    'any',
#    'stripes',
#    'skirt']},
#  {'type': 'ham',
#   'text': ['The',
#    'Xmas',
#    'story',
#    'is',
#    'peace',
#    'The',
#    'Xmas',
#    'msg',
#    'is',
#    'love',
#    'The',
#    'Xmas',
#    'miracle',
#    'is',
#    'jesus',
#    'Hav',
#    'a',
#    'blessed',
#    'month',
#    'ahead',
#    'amp',
#    'wish',
#    'U',
#    'Merry',
#    'Xmas']},
#  {'type': 'ham', 'text': ['I', 'cant', 'I', 'dont', 'have', 'her', 'number']},
#  {'type': 'ham',
#   'text': ['Change', 'again', 'Its', 'e', 'one', 'next', 'to', 'escalator']},
#  {'type': 'ham',
#   'text': ['Yetunde',
#    'im',
#    'in',
#    'class',
#    'can',
#    'you',
#    'not',
#    'run',
#    'water',
#    'on',
#    'it',
#    'to',
#    'make',
#    'it',
#    'ok',
#    'Pls',
#    'now']},
#  {'type': 'ham',
#   'text': ['Not',
#    'a',
#    'lot',
#    'has',
#    'happened',
#    'here',
#    'Feels',
#    'very',
#    'quiet',
#    'Beth',
#    'is',
#    'at',
#    'her',
#    'aunts',
#    'and',
#    'charlie',
#    'is',
#    'working',
#    'lots',
#    'Just',
#    'me',
#    'and',
#    'helen',
#    'in',
#    'at',
#    'the',
#    'mo',
#    'How',
#    'have',
#    'you',
#    'been']},
#  {'type': 'ham',
#   'text': ['Then',
#    'ü',
#    'wait',
#    '4',
#    'me',
#    'at',
#    'bus',
#    'stop',
#    'aft',
#    'ur',
#    'lect',
#    'lar',
#    'If',
#    'i',
#    'dun',
#    'c',
#    'ü',
#    'then',
#    'i',
#    'go',
#    'get',
#    'my',
#    'car',
#    'then',
#    'come',
#    'back',
#    'n',
#    'pick',
#    'ü']},
#  ...]

# %%
#spam dictionary
trainingDicSpam = {}
for i in dicSet:
    if i["type"] == "spam":
        for j in i["text"]:
            if j.lower() not in trainingDicSpam:
                trainingDicSpam[j.lower()] = 1
            else:
                trainingDicSpam[j.lower()] += 1

# %%
#not spam dictionary
trainingDicNotSpam = {}
for i in dicSet:
    if i["type"] == "ham":
        for j in i["text"]:
            if j.lower() not in trainingDicNotSpam:
                trainingDicNotSpam[j.lower()] = 1
            else:
                trainingDicNotSpam[j.lower()] += 1

# %%
trainingDicSpam
# Out:
# {'free': 151,
#  'entry': 21,
#  'in': 54,
#  '2': 128,
#  'a': 259,
#  'wkly': 9,
#  'comp': 7,
#  'to': 498,
#  'win': 46,
#  'fa': 4,
#  'cup': 5,
#  'final': 14,
#  'tkts': 4,
#  '21st': 2,
#  'may': 6,
#  '2005': 3,
#  'text': 83,
#  '87121': 3,
#  'receive': 21,
#  'questionstd': 2,
#  'txt': 116,
#  'ratetcs': 2,
#  'apply': 20,
#  '08452810075over18s': 2,
#  'freemsg': 8,
#  'hey': 5,
#  'there': 9,
#  'darling': 2,
#  'its': 7,
#  'been': 28,
#  '3': 11,
#  'weeks': 8,
#  'now': 138,
#  'and': 100,
#  'no': 41,
#  'word': 17,
#  'back': 19,
#  'id': 1,
#  'like': 9,
#  'some': 5,
#  'fun': 7,
#  'you': 196,
#  'up': 17,
#  'for': 132,
#  'it': 20,
#  'still': 6,
#  'tb': 1,
#  'ok': 4,
#  'xxx': 11,
#  'std': 6,
#  'chgs': 1,
#  'send': 49,
#  '£150': 20,
#  'rcv': 2,
#  'winner': 13,
#  'as': 23,
#  'valued': 5,
#  'network': 16,
#  'customer': 32,
#  'have': 93,
#  'selected': 16,
#  'receivea': 1,
#  '£900': 5,
#  'prize': 65,
#  'reward': 2,
#  'claim': 80,
#  'call': 228,
#  '09061701461': 1,
#  'code': 17,
#  'kl341': 1,
#  'valid': 16,
#  '12': 5,
#  'hours': 2,
#  'only': 55,
#  'had': 8,
#  'your': 170,
#  'mobile': 74,
#  '11': 2,
#  'months': 2,
#  'or': 120,
#  'more': 23,
#  'u': 113,
#  'r': 14,
#  'entitled': 3,
#  'update': 11,
#  'the': 140,
#  'latest': 21,
#  'colour': 9,
#  'mobiles': 7,
#  'with': 71,
#  'camera': 20,
#  'co': 3,
#  'on': 105,
#  '08002986030': 1,
#  'six': 2,
#  'chances': 2,
#  'cash': 43,
#  'from': 89,
#  '100': 9,
#  '20000': 2,
#  'pounds': 12,
#  'csh11': 2,
#  '87575': 3,
#  'cost': 18,
#  '150pday': 2,
#  '6days': 2,
#  '16': 38,
#  'tsandcs': 2,
#  'reply': 67,
#  'hl': 5,
#  '4': 80,
#  'info': 5,
#  'urgent': 44,
#  'won': 52,
#  '1': 22,
#  'week': 36,
#  'membership': 1,
#  'our': 54,
#  '£100000': 1,
#  'jackpot': 1,
#  '81010': 1,
#  'tc': 11,
#  'wwwdbuknet': 1,
#  'lccltd': 1,
#  'pobox': 11,
#  '4403ldnw1a7rw18': 1,
#  'xxxmobilemovieclub': 1,
#  'use': 5,
#  'credit': 6,
#  'click': 4,
#  'wap': 8,
#  'link': 4,
#  'next': 12,
#  'message': 23,
#  'here': 6,
#  'httpwap': 1,
#  'xxxmobilemovieclubcomnqjkgighjjgcbl': 1,
#  'england': 5,
#  'v': 4,
#  'macedonia': 1,
#  'dont': 18,
#  'miss': 7,
#  'goalsteam': 1,
#  'news': 7,
#  'ur': 109,
#  'national': 9,
#  'team': 3,
#  '87077': 5,
#  'eg': 10,
#  'trywales': 1,
#  'scotland': 1,
#  '4txtú120': 1,
#  'poboxox36504w45wq': 1,
#  'thanks': 11,
#  'subscription': 1,
#  'ringtone': 18,
#  'uk': 12,
#  'will': 30,
#  'be': 36,
#  'charged': 9,
#  '£5month': 1,
#  'please': 36,
#  'confirm': 1,
#  'by': 27,
#  'replying': 4,
#  'yes': 10,
#  'if': 19,
#  'not': 22,
#  '07732584351': 1,
#  'rodger': 1,
#  'burns': 1,
#  'msg': 20,
#  'we': 33,
#  'tried': 10,
#  're': 6,
#  'sms': 19,
#  'nokia': 49,
#  'camcorder': 8,
#  '08000930705': 8,
#  'delivery': 14,
#  'tomorrow': 7,
#  'ac': 4,
#  'sptv': 2,
#  'new': 48,
#  'jersey': 1,
#  'devils': 1,
#  'detroit': 1,
#  'red': 1,
#  'wings': 1,
#  'play': 12,
#  'ice': 1,
#  'hockey': 1,
#  'correct': 4,
#  'incorrect': 1,
#  'end': 11,
#  'congrats': 6,
#  'year': 6,
#  'special': 10,
#  'cinema': 3,
#  'pass': 3,
#  'is': 111,
#  'yours': 11,
#  '09061209465': 3,
#  'c': 12,
#  'suprman': 3,
#  'matrix3': 3,
#  'starwars3': 3,
#  'etc': 5,
#  'all': 21,
#  'bx420ip45we': 3,
#  '150pm': 4,
#  'out': 41,
#  'i': 30,
#  'am': 12,
#  'pleased': 3,
#  'advise': 3,
#  'that': 21,
#  'following': 3,
#  'recent': 3,
#  'review': 4,
#  'of': 70,
#  'mob': 19,
#  'are': 58,
#  'awarded': 27,
#  '£1500': 4,
#  'bonus': 18,
#  '09066364589': 2,
#  'complimentary': 8,
#  'trip': 3,
#  'eurodisinc': 1,
#  'trav': 1,
#  'acoentry41': 1,
#  '£1000': 23,
#  'dis': 1,
#  '186£150morefrmmob': 1,
#  'shracomorsglsuplt10': 1,
#  'ls1': 1,
#  '3aj': 1,
#  'did': 2,
#  'hear': 3,
#  'about': 7,
#  'divorce': 1,
#  'barbie': 1,
#  'comes': 2,
#  'kens': 1,
#  'stuff': 1,
#  'service': 39,
#  'representative': 6,
#  '0800': 9,
#  '169': 1,
#  '6031': 1,
#  'between': 6,
#  '10am9pm': 1,
#  'guaranteed': 35,
#  '£5000': 10,
#  'waiting': 12,
#  'collected': 2,
#  'simply': 2,
#  'password': 3,
#  'mix': 3,
#  '85069': 2,
#  'verify': 3,
#  'get': 59,
#  'usher': 2,
#  'britney': 2,
#  'fml': 2,
#  'po': 24,
#  'box': 25,
#  '5249': 2,
#  'mk17': 2,
#  '92h': 2,
#  '450ppw': 2,
#  'gent': 2,
#  'trying': 12,
#  'contact': 39,
#  'last': 9,
#  'weekends': 5,
#  'draw': 29,
#  'shows': 19,
#  '09064012160': 2,
#  'k52': 2,
#  '12hrs': 12,
#  '150ppm': 25,
#  'specially': 6,
#  'holiday': 20,
#  'flights': 5,
#  'inc': 5,
#  'speak': 8,
#  'live': 23,
#  'operator': 11,
#  '0871277810910pmin': 1,
#  '18': 34,
#  'private': 9,
#  '2004': 4,
#  'account': 9,
#  'statement': 7,
#  '07742676969': 2,
#  '786': 2,
#  'unredeemed': 7,
#  'points': 7,
#  '08719180248': 2,
#  'identifier': 7,
#  '45239': 2,
#  'expires': 7,
#  'was': 5,
#  '£2000': 25,
#  'caller': 11,
#  '5903': 1,
#  'this': 56,
#  'try': 5,
#  'landline': 22,
#  '09064019788': 1,
#  'box42wr29c': 1,
#  'todays': 15,
#  'voda': 3,
#  'numbers': 5,
#  'ending': 5,
#  '7548': 1,
#  '350': 2,
#  'award': 17,
#  'match': 4,
#  '08712300220': 3,
#  'quoting': 3,
#  '4041': 1,
#  'standard': 4,
#  'rates': 5,
#  'app': 3,
#  'sunshine': 7,
#  'quiz': 12,
#  'q': 4,
#  'top': 13,
#  'sony': 5,
#  'dvd': 6,
#  'player': 10,
#  'know': 21,
#  'which': 4,
#  'country': 4,
#  'algarve': 2,
#  'ansr': 4,
#  '82277': 4,
#  'sptyrone': 4,
#  'want': 18,
#  'laid': 3,
#  'tonight': 2,
#  'real': 10,
#  'dogging': 11,
#  'locations': 5,
#  'sent': 9,
#  'direct': 8,
#  'join': 13,
#  'uks': 9,
#  'largest': 4,
#  'bt': 4,
#  'txting': 7,
#  'gravel': 1,
#  '69888': 2,
#  'nt': 1,
#  'ec2a': 4,
#  '31pmsg150p': 2,
#  'youll': 1,
#  'any': 14,
#  'msgs': 6,
#  'chat': 34,
#  'svc': 1,
#  'hardcore': 2,
#  'services': 13,
#  'go': 21,
#  '69988': 1,
#  'nothing': 2,
#  'must': 4,
#  'age': 8,
#  'yr': 10,
#  'again': 3,
#  'why': 8,
#  'havent': 1,
#  'replied': 1,
#  'my': 8,
#  'im': 11,
#  'randy': 2,
#  'sexy': 15,
#  'female': 1,
#  'local': 5,
#  'luv': 5,
#  'netcollex': 2,
#  'ltd': 10,
#  '08700621170150p': 1,
#  'per': 35,
#  'stop': 74,
#  'annoncement': 1,
#  'years': 7,
#  '07046744435': 1,
#  'arrange': 2,
#  '0871277810810': 2,
#  'pls': 6,
#  'bootydelious': 1,
#  '32f': 1,
#  'inviting': 1,
#  'her': 3,
#  'friend': 6,
#  'yes434': 1,
#  'no434': 1,
#  'see': 10,
#  'wwwsmsacubootydelious': 1,
#  'frnd': 1,
#  '62468': 2,
#  'bangbabes': 1,
#  'order': 11,
#  'way': 1,
#  'should': 6,
#  'download': 2,
#  'content': 11,
#  'do': 14,
#  'goto': 4,
#  'bangb': 1,
#  'tv': 6,
#  'internetservice': 1,
#  'menu': 1,
#  '09061701939': 1,
#  's89': 1,
#  'freephone': 5,
#  '0808': 2,
#  '145': 2,
#  '4742': 2,
#  '9am11pm': 2,
#  'unique': 1,
#  'enough': 2,
#  'find': 19,
#  '30th': 1,
#  'august': 2,
#  'wwwareyouuniquecouk': 1,
#  '500': 19,
#  '89545': 2,
#  'collect': 15,
#  'todayfrom': 2,
#  '£1': 2,
#  'www4tcbiz': 2,
#  '2optout': 3,
#  '08718726270150gbpmtmsg18': 2,
#  'meet': 6,
#  'dream': 3,
#  'partner': 5,
#  'soon': 2,
#  'career': 1,
#  'off': 2,
#  'flyng': 1,
#  'start': 4,
#  'horo': 2,
#  'followed': 3,
#  'star': 2,
#  'sign': 2,
#  'e': 6,
#  'g': 5,
#  'aries': 1,
#  'someone': 11,
#  'today': 9,
#  'can': 23,
#  'date': 7,
#  'even': 4,
#  'flirt': 4,
#  'just': 59,
#  '10p': 10,
#  'name': 8,
#  'sam': 3,
#  '25': 3,
#  'recdthirtyeight': 1,
#  'pence': 2,
#  '447801259231': 1,
#  'secret': 7,
#  'admirer': 7,
#  'who': 36,
#  'looking': 6,
#  'make': 8,
#  'ufind': 5,
#  'they': 12,
#  'rreveal': 5,
#  'thinks': 7,
#  'so': 20,
#  'specialcall': 5,
#  '09058094597': 1,
#  'congratulations': 12,
#  'cd': 5,
#  'vouchers': 15,
#  '125gift': 2,
#  'music': 13,
#  '87066': 9,
#  'tncs': 5,
#  'wwwldewcom1win150ppmx3age16': 3,
#  'offer': 19,
#  'video': 18,
#  'handset': 2,
#  '750': 10,
#  'anytime': 8,
#  'networks': 2,
#  'mins': 18,
#  'unlimited': 6,
#  'really': 1,
#  'horny': 4,
#  'me': 23,
#  'naked': 1,
#  'hot': 11,
#  '69698': 2,
#  'at': 20,
#  'unsubscribe': 13,
#  'has': 20,
#  'changed': 1,
#  'credits': 7,
#  'club4mobilescom': 1,
#  'choose': 7,
#  'club': 15,
#  '87070': 1,
#  '150pwk': 2,
#  'club4': 1,
#  'box1146': 1,
#  'mk45': 2,
#  '2wt': 2,
#  'singles': 5,
#  'chart': 1,
#  'each': 7,
#  'quality': 1,
#  'charge': 6,
#  'hmv': 7,
#  'genuine': 2,
#  'answer': 7,
#  'easy': 7,
#  'questions': 5,
#  '86688': 16,
#  'infowww100percentrealcom': 2,
#  'tmobile': 1,
#  'phone': 33,
#  'upgrade': 3,
#  'pay': 1,
#  'sim': 3,
#  'card': 3,
#  'loyalty': 7,
#  '0845': 2,
#  '021': 1,
#  '3680offer': 1,
#  'ends': 3,
#  '28thfebtcs': 1,
#  'blind': 2,
#  '4u': 3,
#  'rodds1': 1,
#  '21m': 1,
#  'aberdeen': 1,
#  'united': 1,
#  'kingdom': 1,
#  'check': 2,
#  'him': 1,
#  'httpimg': 1,
#  'acwicmb3cktz8r74': 1,
#  'dates': 2,
#  'hide': 1,
#  'themob': 3,
#  'newest': 3,
#  'selection': 3,
#  'games': 9,
#  'tones': 20,
#  'gossip': 1,
#  'babes': 2,
#  'sport': 4,
#  'keep': 4,
#  'fit': 1,
#  'funky': 1,
#  '82468': 2,
#  'think': 2,
#  'smart': 1,
#  '£200': 7,
#  'weekly': 20,
#  '85222': 1,
#  'nowtcs': 1,
#  'winnersclub': 1,
#  '84': 1,
#  'm26': 2,
#  '3uz': 2,
#  'gbp150week': 1,
#  'december': 3,
#  '11mths': 6,
#  '08002986906': 2,
#  'germany': 1,
#  'minute': 4,
#  'fixed': 1,
#  'line': 24,
#  'via': 1,
#  'access': 4,
#  'number': 17,
#  '0844': 1,
#  '861': 1,
#  '85': 2,
#  'prepayment': 1,
#  'valentines': 3,
#  'day': 10,
#  'over': 12,
#  'take': 11,
#  'lifetime': 2,
#  '83600': 4,
#  '150pmsg': 15,
#  'rcvd': 6,
#  'custcare08718720201': 2,
#  'fancy': 8,
#  'shag': 1,
#  'dointerested': 1,
#  'sextextukcom': 1,
#  'xxuk': 1,
#  'suzy': 1,
#  '69876': 1,
#  'txts': 9,
#  '150': 11,
#  'website': 1,
#  'x': 10,
#  'cashbalance': 6,
#  'currently': 8,
#  'maximize': 6,
#  'cashin': 6,
#  'cc': 5,
#  '08708800282': 1,
#  'hgsuite3422lands': 7,
#  'roww1j6hl': 3,
#  'updatenow': 2,
#  'xmas': 10,
#  'motorola': 8,
#  'sonyericsson': 5,
#  'bluetooth': 6,
#  'double': 10,
#  '1000': 6,
#  'orange': 17,
#  'mobileupd8': 11,
#  '08000839402': 11,
#  'call2optoutf4q': 1,
#  'discount': 9,
#  'rp176781': 1,
#  'further': 3,
#  'messages': 10,
#  'wwwregalportfoliocouk': 1,
#  '08717205546': 1,
#  'reference': 3,
#  't91': 1,
#  'gbp': 1,
#  'calling': 3,
#  '09057039994': 1,
#  '6months': 1,
#  'available': 2,
#  'phones': 7,
#  'call2optoutn9dx': 1,
#  '4mths': 3,
#  'half': 7,
#  'price': 10,
#  'rental': 6,
#  'mobilesdirect': 3,
#  '08000938767': 3,
#  'or2stoptxt': 3,
#  'first': 5,
#  '87131': 3,
#  'poly': 11,
#  'true': 2,
#  'tone': 34,
#  'help': 15,
#  '2814032': 1,
#  'after': 3,
#  '1st': 19,
#  '3x£150pw': 1,
#  'e£nd': 1,
#  'dating': 12,
#  '09064012103': 1,
#  'box334sk38ch': 1,
#  'into': 5,
#  '£250': 11,
#  'competition': 3,
#  '80086': 2,
#  'wwwtxttowincouk': 2,
#  'logo': 3,
#  'lover': 2,
#  'names': 2,
#  'joined': 2,
#  'heart': 2,
#  'love': 9,
#  'name1': 2,
#  'name2': 2,
#  'mobno': 2,
#  'adam': 2,
#  'eve': 3,
#  '07123456789': 2,
#  'yahoo': 2,
#  'pobox36504w45wq': 5,
#  'txtno': 2,
#  'ads': 2,
#  '150p': 18,
#  'contacted': 4,
#  'entered': 6,
#  'because': 2,
#  '09111032124': 1,
#  'pobox12n146tf150p': 1,
#  '09058094455': 1,
#  'land': 15,
#  '3030': 4,
#  '3650': 1,
#  '09066382422': 1,
#  'calls': 10,
#  'ave': 1,
#  '3mins': 2,
#  'vary': 5,
#  'close': 2,
#  '300603': 1,
#  'post': 2,
#  'bcm4284': 1,
#  'ldn': 8,
#  'wc1n3xx': 3,
#  'loan': 3,
#  'purpose': 3,
#  '£500': 16,
#  '£75000': 3,
#  'homeowners': 3,
#  'tenants': 3,
#  'welcome': 6,
#  'previously': 3,
#  'refused': 3,
#  '1956669': 3,
#  'upgrdcentre': 1,
#  '0207': 2,
#  '153': 2,
#  '9153': 1,
#  '26th': 1,
#  'july': 1,
#  'tcs': 21,
#  'optout': 7,
#  'okmail': 1,
#  'dear': 12,
#  'dave': 2,
#  'notice': 3,
#  'tenerife': 7,
#  '5000': 3,
#  '09061743806': 2,
#  'sae': 12,
#  'box326': 2,
#  'cw25wx': 4,
#  'moan': 1,
#  '69888nyt': 1,
#  'activate': 5,
#  'terms': 6,
#  'conditions': 3,
#  'visit': 5,
#  'www07781482378com': 2,
#  '123': 3,
#  '£1450': 3,
#  '09050002311': 2,
#  'b4280703': 2,
#  'tcsstop': 3,
#  '08718727868': 2,
#  '40gb': 5,
#  'ipod': 8,
#  'mp3': 3,
#  '83355': 2,
#  'ibhltd': 2,
#  'ldnw15h': 2,
#  '150pmtmsgrcvd18': 2,
#  'boltblue': 1,
#  'mono': 2,
#  'poly3': 1,
#  'cha': 2,
#  'slide': 1,
#  'yeah': 1,
#  'slow': 1,
#  'jamz': 1,
#  '6': 4,
#  'toxic': 1,
#  '8': 1,
#  'come': 2,
#  'topped': 1,
#  'httpwwwbubbletextcom': 1,
#  'renewal': 1,
#  'pin': 1,
#  'tgxxrz': 1,
#  '020903': 1,
#  '2nd': 13,
#  'attempt': 15,
#  '08718729755': 1,
#  'box95qu': 2,
#  'worth': 10,
#  '85023': 7,
#  'savamob': 10,
#  'member': 4,
#  'offers': 8,
#  't': 10,
#  'cs': 10,
#  '08717898035': 3,
#  '£300': 7,
#  'sub': 7,
#  'unsub': 5,
#  'recieve': 1,
#  'within': 4,
#  '24hrs': 2,
#  'channel': 1,
#  'teletext': 1,
#  'pg': 1,
#  '2003': 5,
#  '07815296484': 1,
#  '800': 6,
#  '08718738001': 1,
#  '41782': 1,
#  '181104': 1,
#  'wwwapplausestorecom': 1,
#  'monthlysubscription50pmsg': 1,
#  'max6month': 1,
#  'tcsc': 1,
#  'web': 2,
#  'age16': 3,
#  '2stop': 1,
#  '2000': 3,
#  'call09050000327': 2,
#  'us': 5,
#  'ring': 2,
#  'claims': 1,
#  '09050005321': 1,
#  'textand': 1,
#  '08002988890': 1,
#  'chance': 22,
#  'shopping': 5,
#  'spree': 5,
#  'shop': 6,
#  '80878': 1,
#  'tscs': 15,
#  'wwwtxt2shopcom': 1,
#  'custcare': 6,
#  '08715705022': 2,
#  '1x150pwk': 4,
#  'pound': 4,
#  '08712402050': 1,
#  'before': 4,
#  'lines': 1,
#  '10ppm': 1,
#  'ag': 1,
#  'promo': 1,
#  '07753741225': 1,
#  's': 5,
#  'm': 6,
#  '08715203677': 1,
#  '42478': 1,
#  '241004': 1,
#  'an': 13,
#  'important': 5,
#  'announcement': 4,
#  '542': 3,
#  '0825': 1,
#  'xclusiveclubsaisai': 1,
#  '2morow': 1,
#  '285': 1,
#  'soiree': 1,
#  'speciale': 1,
#  'zouk': 1,
#  'nichols': 1,
#  'parisfree': 1,
#  'roses': 1,
#  'ladies': 2,
#  '0794674629107880867867': 1,
#  '22': 2,
#  'days': 8,
#  'kick': 2,
#  'euro2004': 5,
#  'kept': 3,
#  'results': 3,
#  'daily': 3,
#  'removed': 1,
#  '83222': 3,
#  'textbuddy': 2,
#  'guys': 5,
#  'area': 8,
#  '25p': 7,
#  'search': 2,
#  'postcode': 2,
#  'gaytextbuddycom': 2,
#  'one': 7,
#  '89693': 2,
#  'vodafone': 3,
#  '4882': 1,
#  '£350': 5,
#  'matches': 7,
#  '09064019014': 1,
#  'voucher': 13,
#  'holder': 4,
#  'pc': 4,
#  'httpwwwetlpcoukexpressoffer': 2,
#  'apply2': 1,
#  'texts': 12,
#  '80062': 5,
#  '08715203694': 1,
#  '40533': 1,
#  '311004': 1,
#  'rstm': 1,
#  'sw7': 1,
#  '3ss': 1,
#  '88800': 1,
#  '89034': 1,
#  'premium': 1,
#  '08718711108': 1,
#  'sun0819': 1,
#  'posts': 1,
#  'helloyou': 1,
#  'seem': 1,
#  'cool': 1,
#  'wanted': 1,
#  'say': 1,
#  'hi': 12,
#  'gr8': 5,
#  '20': 3,
#  'every': 26,
#  'wk': 16,
#  'opt': 11,
#  '08452810071': 1,
#  'sue': 2,
#  'old': 2,
#  'work': 3,
#  'lapdancer': 1,
#  'sex': 6,
#  'bedroom': 1,
#  '89555': 3,
#  'textoperator': 3,
#  'g2': 1,
#  '1da': 1,
#  '150ppmsg': 1,
#  'forwarded': 4,
#  '448712404000please': 1,
#  '08712404000': 1,
#  'immediately': 4,
#  'fantastic': 3,
#  'ngage': 1,
#  'game': 3,
#  'deck': 1,
#  'wwwcnupdatescomnewsletter': 1,
#  'alerts': 1,
#  '08714712388': 1,
#  '10am7pm': 3,
#  '449071512431': 1,
#  'uu': 2,
#  '£1250': 2,
#  '09071512433': 2,
#  'b4': 5,
#  '050703': 2,
#  'tcsbcm4235wc1n3xx': 2,
#  'callcost': 2,
#  'mobilesvary': 2,
#  'max£7': 2,
#  '50': 3,
#  '08714712394': 1,
#  'email': 2,
#  'alertfrom': 1,
#  'jeri': 1,
#  'stewartsize': 1,
#  '2kbsubject': 1,
#  'lowcost': 1,
#  'prescripiton': 1,
#  'drvgsto': 1,
#  'listen': 2,
#  'offerthe': 2,
#  'nokia6650': 2,
#  '£10': 5,
#  'txtauction': 3,
#  '81151': 2,
#  '4tctxt': 2,
#  '150pmtmsg': 2,
#  'subscribed': 2,
#  'best': 5,
#  '£3': 4,
#  '10': 4,
#  'until': 5,
#  '82324': 1,
#  'helpline': 2,
#  '08706091795': 2,
#  'realize': 1,
#  '40': 2,
#  'well': 5,
#  'thousands': 1,
#  'running': 1,
#  'around': 2,
#  'tattoos': 1,
#  'premier': 2,
#  'romantic': 1,
#  'paris': 3,
#  'nights': 1,
#  '£79': 1,
#  'book': 3,
#  '08704439680tscs': 1,
#  'unclaimed': 1,
#  '09066368327': 1,
#  'closingdate040902': 1,
#  'claimcode': 1,
#  'm39m51': 1,
#  '£150pmmorefrommobile2bremovedmobypobox734ls27yf': 1,
#  'city': 3,
#  'break': 3,
#  'could': 5,
#  'summer': 4,
#  'store': 7,
#  '88039': 2,
#  'skilgme': 2,
#  'tscs087147403231winawkage16': 2,
#  '£150perwksub': 2,
#  '0578': 2,
#  'ever': 2,
#  'thought': 1,
#  'living': 1,
#  'good': 10,
#  ...}

# %%
trainingDicNotSpam
# Out:
# {'go': 164,
#  'until': 16,
#  'jurong': 1,
#  'point': 11,
#  'crazy': 8,
#  'available': 9,
#  'only': 86,
#  'in': 567,
#  'bugis': 6,
#  'n': 96,
#  'great': 73,
#  'world': 24,
#  'la': 5,
#  'e': 58,
#  'buffet': 2,
#  'cine': 7,
#  'there': 136,
#  'got': 163,
#  'amore': 1,
#  'wat': 69,
#  'ok': 201,
#  'lar': 27,
#  'joking': 2,
#  'wif': 15,
#  'u': 664,
#  'oni': 2,
#  'dun': 37,
#  'say': 64,
#  'so': 275,
#  'early': 28,
#  'hor': 1,
#  'c': 46,
#  'already': 65,
#  'then': 159,
#  'nah': 9,
#  'i': 1526,
#  'dont': 193,
#  'think': 91,
#  'he': 129,
#  'goes': 21,
#  'to': 1086,
#  'usf': 6,
#  'lives': 3,
#  'around': 44,
#  'here': 80,
#  'though': 17,
#  'even': 39,
#  'my': 534,
#  'brother': 9,
#  'is': 523,
#  'not': 288,
#  'like': 163,
#  'speak': 18,
#  'with': 195,
#  'me': 525,
#  'they': 81,
#  'treat': 12,
#  'aids': 1,
#  'patent': 1,
#  'as': 114,
#  'per': 12,
#  'your': 289,
#  'request': 6,
#  'melle': 6,
#  'oru': 4,
#  'minnaminunginte': 3,
#  'nurungu': 3,
#  'vettam': 3,
#  'has': 60,
#  'been': 64,
#  'set': 13,
#  'callertune': 10,
#  'for': 365,
#  'all': 176,
#  'callers': 5,
#  'press': 7,
#  '9': 19,
#  'copy': 7,
#  'friends': 37,
#  'im': 295,
#  'gonna': 34,
#  'be': 240,
#  'home': 103,
#  'soon': 37,
#  'and': 613,
#  'want': 111,
#  'talk': 30,
#  'about': 107,
#  'this': 174,
#  'stuff': 24,
#  'anymore': 8,
#  'tonight': 33,
#  'k': 46,
#  'ive': 51,
#  'cried': 1,
#  'enough': 18,
#  'today': 84,
#  'searching': 4,
#  'the': 789,
#  'right': 67,
#  'words': 15,
#  'thank': 22,
#  'you': 1339,
#  'breather': 1,
#  'promise': 8,
#  'wont': 38,
#  'take': 71,
#  'help': 22,
#  'granted': 1,
#  'will': 227,
#  'fulfil': 1,
#  'have': 323,
#  'wonderful': 11,
#  'a': 747,
#  'blessing': 2,
#  'at': 275,
#  'times': 18,
#  'date': 6,
#  'on': 280,
#  'sunday': 7,
#  'oh': 73,
#  'kim': 1,
#  'watching': 23,
#  'eh': 8,
#  'remember': 23,
#  'how': 175,
#  '2': 203,
#  'spell': 3,
#  'his': 40,
#  'name': 18,
#  'yes': 47,
#  'did': 83,
#  'v': 36,
#  'naughty': 4,
#  'make': 57,
#  'wet': 3,
#  'fine': 30,
#  'if': 242,
#  'that\x92s': 4,
#  'way': 72,
#  'feel': 51,
#  'its': 204,
#  'gota': 1,
#  'b': 38,
#  'that': 346,
#  'seriously': 7,
#  'i‘m': 4,
#  'going': 121,
#  'try': 30,
#  'months': 8,
#  'ha': 10,
#  'ü': 116,
#  'pay': 28,
#  'first': 41,
#  'when': 199,
#  'da': 90,
#  'stock': 2,
#  'comin': 9,
#  'aft': 16,
#  'finish': 28,
#  'lunch': 31,
#  'str': 3,
#  'down': 40,
#  'lor': 106,
#  'ard': 14,
#  '3': 31,
#  'smth': 7,
#  'ur': 166,
#  'ffffffffff': 1,
#  'alright': 18,
#  'no': 200,
#  'can': 259,
#  'meet': 52,
#  'up': 202,
#  'sooner': 3,
#  'just': 204,
#  'forced': 1,
#  'myself': 8,
#  'eat': 27,
#  'slice': 2,
#  'really': 58,
#  'hungry': 8,
#  'tho': 11,
#  'sucks': 4,
#  'mark': 4,
#  'getting': 38,
#  'worried': 8,
#  'knows': 8,
#  'sick': 9,
#  'turn': 2,
#  'pizza': 6,
#  'lol': 52,
#  'always': 45,
#  'convincing': 1,
#  'catch': 8,
#  'bus': 19,
#  'are': 292,
#  'frying': 3,
#  'an': 67,
#  'egg': 1,
#  'tea': 3,
#  'eating': 6,
#  'moms': 8,
#  'left': 22,
#  'over': 42,
#  'dinner': 19,
#  'do': 258,
#  'love': 137,
#  'back': 88,
#  'amp': 63,
#  'were': 57,
#  'packing': 1,
#  'car': 28,
#  'now': 194,
#  'ill': 179,
#  'let': 50,
#  'know': 173,
#  'theres': 19,
#  'room': 27,
#  'ahhh': 1,
#  'work': 67,
#  'vaguely': 1,
#  'what': 168,
#  'does': 25,
#  'it': 421,
#  'wait': 43,
#  'thats': 62,
#  'still': 108,
#  'clear': 3,
#  'sure': 54,
#  'being': 25,
#  'sarcastic': 1,
#  'or': 161,
#  'why': 49,
#  'x': 27,
#  'doesnt': 21,
#  'live': 15,
#  'us': 33,
#  'yeah': 58,
#  'was': 142,
#  'apologetic': 1,
#  'had': 62,
#  'fallen': 1,
#  'out': 156,
#  'she': 93,
#  'actin': 1,
#  'spoilt': 1,
#  'child': 2,
#  'caught': 3,
#  'till': 17,
#  'but': 306,
#  'we': 212,
#  'doing': 57,
#  'too': 75,
#  'badly': 1,
#  'cheers': 4,
#  'tell': 74,
#  'anything': 45,
#  'fear': 3,
#  'of': 367,
#  'fainting': 1,
#  'housework': 1,
#  'quick': 5,
#  'cuppa': 1,
#  'yup': 29,
#  'look': 18,
#  'timings': 1,
#  'msg': 42,
#  'again': 42,
#  'xuhui': 2,
#  'learn': 4,
#  '2nd': 7,
#  'may': 29,
#  'her': 74,
#  'lesson': 12,
#  '8am': 2,
#  'oops': 6,
#  'roommates': 4,
#  'done': 34,
#  'see': 90,
#  'letter': 3,
#  'decide': 8,
#  'hello': 32,
#  'hows': 25,
#  'saturday': 7,
#  'texting': 4,
#  'youd': 5,
#  'decided': 10,
#  'tomo': 13,
#  'trying': 17,
#  'invite': 3,
#  'pls': 60,
#  'ahead': 7,
#  'watts': 1,
#  'wanted': 20,
#  'weekend': 17,
#  'abiola': 10,
#  'forget': 12,
#  'need': 106,
#  'crave': 6,
#  'most': 21,
#  'sweet': 23,
#  'arabian': 1,
#  'steed': 1,
#  'mmmmmm': 1,
#  'yummy': 2,
#  'who': 41,
#  'seeing': 10,
#  'hope': 63,
#  'man': 34,
#  'well': 91,
#  'endowed': 1,
#  'am': 162,
#  'ltgt': 207,
#  'inches': 3,
#  'callsmessagesmissed': 3,
#  'calls': 7,
#  'didnt': 50,
#  'get': 210,
#  'hep': 1,
#  'immunisation': 1,
#  'nigeria': 5,
#  'fair': 2,
#  'hopefully': 4,
#  'tyler': 3,
#  'cant': 77,
#  'could': 38,
#  'maybe': 22,
#  'ask': 57,
#  'bit': 30,
#  'stubborn': 1,
#  'hospital': 4,
#  'kept': 3,
#  'telling': 11,
#  'weak': 4,
#  'sucker': 1,
#  'hospitals': 2,
#  'suckers': 1,
#  'thinked': 1,
#  'time': 133,
#  'saw': 13,
#  'class': 36,
#  'gram': 3,
#  'usually': 5,
#  'runs': 3,
#  'half': 19,
#  'eighth': 1,
#  'smarter': 1,
#  'gets': 8,
#  'almost': 11,
#  'whole': 13,
#  'second': 11,
#  'fyi': 2,
#  'ride': 3,
#  'tomorrow': 58,
#  'morning': 61,
#  'hes': 20,
#  'crashing': 1,
#  'our': 47,
#  'place': 40,
#  'wow': 6,
#  'never': 25,
#  'realized': 1,
#  'embarassed': 4,
#  'by': 91,
#  'accomodations': 1,
#  'thought': 28,
#  'liked': 4,
#  'since': 18,
#  'best': 28,
#  'seemed': 3,
#  'happy': 84,
#  'cave': 1,
#  'sorry': 112,
#  'more': 51,
#  'give': 62,
#  'offered': 1,
#  'embarassing': 1,
#  'mallika': 1,
#  'sherawat': 1,
#  'yesterday': 15,
#  'find': 35,
#  'lturlgt': 3,
#  'call': 163,
#  'later': 82,
#  'meeting': 27,
#  'where': 75,
#  'reached': 5,
#  'yesgauti': 1,
#  'sehwag': 1,
#  'odi': 2,
#  'series': 4,
#  'pick': 48,
#  '1': 38,
#  'burger': 1,
#  'yourself': 16,
#  'move': 9,
#  'pain': 19,
#  'killing': 2,
#  'good': 157,
#  'joke': 4,
#  'girls': 9,
#  'situation': 6,
#  'seekers': 1,
#  'part': 14,
#  'checking': 6,
#  'iq': 3,
#  'took': 17,
#  'forever': 6,
#  'come': 161,
#  'double': 4,
#  'check': 28,
#  'hair': 18,
#  'dresser': 3,
#  'said': 66,
#  'wun': 6,
#  'cut': 10,
#  'short': 7,
#  'nice': 38,
#  'song': 8,
#  'dedicated': 2,
#  'day': 135,
#  'which': 34,
#  'dedicate': 2,
#  'send': 92,
#  'valuable': 3,
#  'frnds': 11,
#  'rply': 4,
#  'plane': 5,
#  'month': 20,
#  'end': 21,
#  'wah': 4,
#  'lucky': 9,
#  'save': 4,
#  'money': 42,
#  'hee': 10,
#  'finished': 16,
#  'hi': 85,
#  'babe': 49,
#  'wanna': 21,
#  'something': 45,
#  'xx': 4,
#  'kkwhere': 2,
#  'youhow': 1,
#  'performed': 1,
#  'waiting': 27,
#  'machan': 2,
#  'once': 28,
#  'free': 39,
#  'cool': 25,
#  'gentleman': 3,
#  'dignity': 3,
#  'respect': 3,
#  'peoples': 1,
#  'very': 52,
#  'much': 75,
#  'shy': 1,
#  'pa': 25,
#  'operate': 1,
#  'after': 59,
#  'same': 32,
#  'looking': 15,
#  'job': 34,
#  'tas': 1,
#  'earn': 1,
#  'ah': 20,
#  'next': 26,
#  'stop': 26,
#  'network': 4,
#  'urgnt': 4,
#  'sms': 10,
#  'real': 16,
#  'yo': 28,
#  'tickets': 5,
#  'one': 108,
#  'jacket': 1,
#  'used': 9,
#  'multis': 1,
#  'started': 9,
#  'requests': 2,
#  'came': 21,
#  'bed': 23,
#  'coins': 4,
#  'factory': 1,
#  'gotta': 9,
#  'cash': 8,
#  'nitros': 1,
#  'ela': 2,
#  'kanoil': 1,
#  'download': 9,
#  'wen': 16,
#  'don‘t': 5,
#  'stand': 4,
#  'close': 11,
#  'you‘ll': 1,
#  'another': 26,
#  'night': 76,
#  'spent': 7,
#  'late': 43,
#  'afternoon': 20,
#  'casualty': 1,
#  'means': 19,
#  'havent': 24,
#  'any': 76,
#  'y': 26,
#  'stuff42moro': 1,
#  'includes': 1,
#  'sheets': 3,
#  'smile': 30,
#  'pleasure': 5,
#  'trouble': 5,
#  'pours': 1,
#  'rain': 8,
#  'sum1': 1,
#  'hurts': 4,
#  'becoz': 3,
#  'someone': 35,
#  'loves': 3,
#  'smiling': 10,
#  'planning': 5,
#  'buy': 42,
#  'lido': 3,
#  '530': 4,
#  'show': 13,
#  'telugu': 1,
#  'moviewat': 1,
#  'abt': 21,
#  'loads': 9,
#  'loans': 1,
#  'wk': 7,
#  'hols': 1,
#  'run': 18,
#  'forgot': 20,
#  'hairdressers': 1,
#  'appointment': 4,
#  'four': 2,
#  'shower': 6,
#  'beforehand': 1,
#  'cause': 14,
#  'prob': 11,
#  'cup': 3,
#  'coffee': 6,
#  'animation': 1,
#  'please': 50,
#  'text': 48,
#  'nothing': 24,
#  'else': 14,
#  'okay': 19,
#  'price': 4,
#  'long': 30,
#  'legal': 2,
#  'them': 58,
#  'ave': 4,
#  'ams': 1,
#  'gone': 9,
#  '4the': 1,
#  'driving': 13,
#  'test': 15,
#  'yet': 39,
#  'youre': 34,
#  'mean': 13,
#  'guess': 25,
#  'gave': 6,
#  'boston': 3,
#  'men': 4,
#  'changed': 5,
#  'search': 13,
#  'location': 2,
#  'nyc': 2,
#  'cuz': 6,
#  'signin': 1,
#  'page': 5,
#  'says': 18,
#  'umma': 6,
#  'life': 51,
#  'vava': 2,
#  'lot': 23,
#  'dear': 69,
#  'thanks': 40,
#  'wishes': 6,
#  'birthday': 25,
#  'making': 21,
#  'truly': 2,
#  'memorable': 1,
#  'aight': 24,
#  'hit': 7,
#  'some': 79,
#  'would': 55,
#  'ip': 1,
#  'address': 10,
#  'considering': 2,
#  'computer': 4,
#  'isnt': 13,
#  'minecraft': 1,
#  'server': 1,
#  'grumpy': 1,
#  'old': 10,
#  'people': 32,
#  'mom': 7,
#  'better': 28,
#  'lying': 1,
#  'play': 12,
#  'jokes': 3,
#  'worry': 20,
#  'busy': 14,
#  'plural': 1,
#  'noun': 2,
#  'research': 4,
#  'dinnermsg': 1,
#  'cos': 47,
#  'new': 45,
#  'things': 33,
#  'scared': 3,
#  'mah': 10,
#  'loud': 2,
#  'wa': 2,
#  'openin': 1,
#  'sentence': 2,
#  'formal': 1,
#  'anyway': 13,
#  'juz': 14,
#  'tt': 3,
#  'eatin': 5,
#  'puttin': 1,
#  'weighthaha': 1,
#  'anythin': 2,
#  'special': 26,
#  'happened': 11,
#  'entered': 5,
#  'cabin': 5,
#  'bday': 11,
#  'boss': 8,
#  'felt': 12,
#  'askd': 11,
#  '4': 114,
#  'invited': 6,
#  'apartment': 8,
#  'went': 48,
#  'goodo': 2,
#  'must': 17,
#  'friday': 11,
#  'eggpotato': 1,
#  'ratio': 1,
#  'tortilla': 2,
#  'needed': 1,
#  'hmmmy': 1,
#  'uncle': 7,
#  'informed': 2,
#  'paying': 6,
#  'school': 14,
#  'directly': 3,
#  'food': 17,
#  'applespairsall': 1,
#  'malarky': 1,
#  'sao': 1,
#  'mu': 12,
#  '12': 3,
#  'predict': 1,
#  'üll': 2,
#  'buying': 4,
#  'knowyetunde': 1,
#  'hasnt': 4,
#  'sent': 45,
#  'bother': 5,
#  'sending': 8,
#  'involve': 1,
#  'shouldnt': 4,
#  'imposed': 1,
#  'apologise': 3,
#  'hey': 69,
#  'girl': 19,
#  'r': 97,
#  'del': 1,
#  'bak': 6,
#  'sum': 2,
#  'from': 106,
#  'lucyxx': 1,
#  'kkhow': 3,
#  'cost': 10,
#  'tmorrowpls': 1,
#  'accomodate': 1,
#  'answer': 11,
#  'question': 14,
#  'haf': 14,
#  'msn': 1,
#  'yijuehotmailcom': 1,
#  'him': 70,
#  'rooms': 1,
#  'befor': 1,
#  'activities': 1,
#  'lazy': 7,
#  'type': 9,
#  'lect': 9,
#  'pouch': 2,
#  'sir': 24,
#  'mail': 21,
#  'swt': 2,
#  'nver': 1,
#  'tired': 9,
#  'little': 18,
#  'lovable': 9,
#  'persons': 6,
#  'cozsomtimes': 1,
#  'those': 20,
#  'occupy': 1,
#  'd': 64,
#  'biggest': 1,
#  'their': 8,
#  'hearts': 1,
#  'gud': 41,
#  'ni8': 7,
#  'open': 9,
#  'ya': 40,
#  'dot': 1,
#  'whats': 23,
#  'staff': 2,
#  'taking': 10,
#  'ummmawill': 1,
#  'inour': 1,
#  'begin': 2,
#  'qatar': 4,
#  'pray': 6,
#  'hard': 9,
#  'ki': 6,
#  'deleted': 3,
#  'contact': 8,
#  'sindu': 1,
#  'birla': 3,
#  'soft': 3,
#  'wine': 7,
#  'flowing': 2,
#  'nevering': 1,
#  'thk': 36,
#  'plaza': 2,
#  'typical': 1,
#  'reply': 33,
#  'everywhere': 1,
#  'dirt': 1,
#  'floor': 3,
#  'windows': 2,
#  'shirt': 3,
#  'sometimes': 8,
#  'mouth': 2,
#  'comes': 15,
#  'dream': 4,
#  'without': 20,
#  'chores': 1,
#  'joy': 3,
#  'lots': 13,
#  'tv': 20,
#  'shows': 5,
#  'exist': 1,
#  'hail': 1,
#  'mist': 1,
#  'become': 5,
#  'aaooooright': 1,
#  'leaving': 12,
#  'house': 25,
#  'interview': 4,
#  'boy': 18,
#  'meare': 1,
#  'missing': 20,
#  'keep': 40,
#  'safe': 8,
#  'because': 25,
#  'miss': 55,
#  'envy': 1,
#  'everyone': 13,
#  'sees': 1,
#  'parentsi': 1,
#  'hand': 11,
#  'excited': 1,
#  'each': 3,
#  'spend': 8,
#  'points': 3,
#  'cultures': 1,
#  'module': 1,
#  'frnd': 7,
#  'avoid': 2,
#  'missunderstding': 1,
#  'wit': 7,
#  'beloved': 1,
#  'ones': 5,
#  'escape': 3,
#  'fancy': 3,
#  'bridge': 1,
#  'needs': 10,
#  'lager': 1,
#  'completely': 5,
#  'formclark': 2,
#  'also': 49,
#  'utter': 2,
#  'waste': 5,
#  'axis': 1,
#  'bank': 9,
#  'account': 17,
#  'hmmm': 8,
#  'hop': 7,
#  'muz': 6,
#  'discuss': 3,
#  'liao': 23,
#  'coming': 31,
#  'bloody': 2,
#  'hell': 9,
#  'believe': 10,
#  'surname': 1,
#  'mr': 6,
#  'clue': 1,
#  'spanish': 1,
#  'begins': 1,
#  'm': 7,
#  'bath': 10,
#  'goodfine': 1,
#  'youve': 8,
#  'carlos': 12,
#  'mall': 1,
#  'turns': 5,
#  'staying': 5,
#  'til': 17,
#  'smoke': 16,
#  'worth': 4,
#  'log': 7,
#  'spoke': 5,
#  'maneesha': 3,
#  'wed': 7,
#  'satisfied': 3,
#  'experience': 6,
#  'toll': 3,
#  'lifted': 1,
#  'hopes': 1,
#  'offer': 5,
#  'especially': 4,
#  'approaches': 1,
#  'studying': 5,
#  'anyways': 4,
#  'gr8': 9,
#  'trust': 7,
#  'guys': 24,
#  'greatbye': 1,
#  'handsome': 1,
#  'finding': 1,
#  'working': 22,
#  'towards': 6,
#  'net': 6,
#  'mummy': 2,
#  'wheres': 6,
#  'boytoy': 11,
#  'haha': 39,
#  'awesome': 15,
#  'minute': 8,
#  'xmas': 13,
#  'radio': 2,
#  'jus': 26,
#  'bathe': 8,
#  'sis': 13,
#  'using': 4,
#  'finishes': 3,
#  'joined': 4,
#  'league': 1,
#  'touch': 11,
#  'deal': 6,
#  'friend': 22,
#  'personal': 3,
#  'week': 42,
#  'finally': 9,
#  'completed': 2,
#  'course': 7,
#  'itself': 9,
#  'however': 6,
#  'suggest': 3,
#  'stays': 2,
#  'able': 17,
#  'ors': 1,
#  'every': 30,
#  'stool': 1,
#  'settled': 4,
#  'year': 32,
#  'wishin': 2,
#  'mrng': 11,
#  'hav': 20,
#  'story': 15,
#  'hamster': 1,
#  'dead': 6,
#  'tmr': 21,
#  '1pm': 1,
#  'orchard': 7,
#  'mrt': 5,
#  'kate': 6,
#  'evening': 20,
#  'babyjontet': 1,
#  'txt': 6,
#  'xxx': 16,
#  'found': 14,
#  'enc': 1,
#  'bucks': 4,
#  'darlin': 11,
#  'college': 11,
#  'refilled': 2,
#  'successfully': 3,
#  'inr': 2,
#  'ltdecimalgt': 20,
#  'keralacircle': 2,
#  'prepaid': 2,
#  'balance': 4,
#  'rs': 6,
#  'transaction': 5,
#  'id': 20,
#  'kr': 2,
#  'goodmorning': 13,
#  'sleeping': 15,
#  'ga': 1,
#  'alter': 1,
#  '11': 4,
#  'dat': 25,
#  'ericsson': 1,
#  'oso': 17,
#  'cannot': 4,
#  'oredi': 11,
#  'dats': 3,
#  'straight': 4,
#  'dogg': 1,
#  'connection': 2,
#  'before': 37,
#  'refund': 1,
#  'bill': 6,
#  'both': 12,
#  'shoot': 4,
#  'big': 24,
#  'ready': 25,
#  'bruv': 1,
#  'break': 11,
#  'rewarding': 1,
#  'semester': 7,
#  'chat': 9,
#  'kkgoodstudy': 1,
#  'noe': 14,
#  'leh': 17,
#  'sounds': 10,
#  'match': 3,
#  'heading': 2,
#  'draw': 5,
#  'prediction': 1,
#  'slept': 3,
#  'past': 6,
#  'few': 32,
#  'nights': 2,
#  'easy': 11,
#  'ahsen': 2,
#  'selected': 3,
#  'exam': 7,
#  'march': 10,
#  'should': 62,
#  'use': 23,
#  'gt': 5,
#  'atm': 1,
#  'register': 1,
#  'os': 2,
#  'called': 22,
#  'ubandu': 1,
#  'installing': 1,
#  'diskyou': 1,
#  'important': 7,
#  'files': 4,
#  'system': 4,
#  'repair': 1,
#  'shop': 10,
#  'happen': 16,
#  'romantic': 2,
#  'nite': 10,
#  'scenery': 1,
#  'appreciate': 4,
#  'company': 10,
#  'elama': 1,
#  'po': 2,
#  'mudyadhu': 1,
#  'strict': 1,
#  'than': 25,
#  'teacher': 3,
#  'bcoz': 10,
#  'teaches': 4,
#  'conducts': 2,
#  'lessons': 7,
#  'gandhipuram': 1,
#  'walk': 11,
#  'cross': 1,
#  'road': 6,
#  'side': 8,
#  'street': 4,
#  'rubber': 1,
#  'battery': 5,
#  'died': 5,
#  'yeshere': 2,
#  'printed': 2,
#  'upstairs': 2,
#  'closer': 3,
#  'youwhen': 1,
#  'wil': 10,
#  'reach': 20,
#  'theory': 3,
#  'argument': 4,
#  ...}

# %% [markdown]
# ## Calculating Probability

# %%
numSpamNotSpam = dict(trainingSet["type"].value_counts())
PSpam = numSpamNotSpam["spam"] / len(trainingSet)
PSpam
# Out:
# 0.13307692307692306

# %%
numSpamNotSpam = dict(trainingSet["type"].value_counts())
pNotSpam = numSpamNotSpam["ham"] / len(trainingSet)
pNotSpam
# Out:
# 0.8669230769230769

# %%
totalSpam = 0
for i in trainingDicSpam.keys():
    totalSpam += trainingDicSpam[i]

# %%
totalNotSpam = 0
for i in trainingDicNotSpam.keys():
    totalNotSpam += trainingDicNotSpam[i]

# %%
def pTextSpam(tokens):
    totalSpam = 0
    for i in trainingDicSpam.keys():
        totalSpam += trainingDicSpam[i]
    pTextSpam = 1
    for i in tokens:
        if i.lower() in trainingDicSpam:
            pTextSpam *= pTokenSpamNotSpam(trainingDicSpam[i.lower()], totalSpam, len(tokens))
        else:
            pTextSpam *= pTokenSpamNotSpam(0, totalSpam, len(tokens))
    return pTextSpam

# %%
def pTextNotSpam(tokens):
    totalNotSpam = 0
    for i in trainingDicNotSpam.keys():
        totalNotSpam += trainingDicNotSpam[i]
    pTextNotSpam = 1
    for i in tokens:
        if i.lower() in trainingDicNotSpam:
            pTextNotSpam *= pTokenSpamNotSpam(trainingDicNotSpam[i.lower()], totalNotSpam, len(tokens))
        else:
            pTextNotSpam *= pTokenSpamNotSpam(0, totalNotSpam, len(tokens))
    return pTextNotSpam

# %%
def pTokenSpamNotSpam(number, total, length):
    return (number+1)/(total+length)

# %% [markdown]
# ## Evaluation

# %%
def evaluate(text):
    text = text.translate(str.maketrans('', '', string.punctuation)).split()
    pSpamText = pSpam * pTextSpam(text)
    pNotSpamText = pNotSpam * pTextNotSpam(text)
    if pSpamText > pNotSpamText:
        return "spam"
    else:
        return "not spam"

# %%
evaluate("1000")
# Out:
# 'spam'

# %% [markdown]
# ## Validate the Classifier

# %%
valSet = validationSet.to_dict(orient="records")
total = len(valSet)
T = 0
F = 0
for i in tqdm(valSet):
    if i["type"].lower() == "ham":
        type = "not spam"
    else:
        type = "spam"
    if evaluation.evaluate(i["text"]) == type:
        T += 1
    else:
        F += 1
    accuracy = T/total*100
    failing = F/total*100
    print(f"accuracy = {accuracy}%\nfailing rate = {failing}%")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 5
#       3 T = 0
#       4 F = 0
# ----> 5 for i in tqdm(valSet):
#       6     if i["type"].lower() == "ham":
#       7         type = "not spam"
#
# TypeError: 'module' object is not callable

# %%
# Out:
# [{'type': 'ham',
#   'text': "Ü mean it's confirmed... I tot they juz say oni... Ok then... "},
#  {'type': 'ham', 'text': 'Okie'},
#  {'type': 'ham', 'text': 'That depends. How would you like to be treated? :)'},
#  {'type': 'ham', 'text': 'Right on brah, see you later'},
#  {'type': 'ham',
#   'text': 'Waiting in e car 4 my mum lor. U leh? Reach home already?'},
#  {'type': 'spam',
#   'text': 'Your 2004 account for 07XXXXXXXXX shows 786 unredeemed points. To claim call 08719181259 Identifier code: XXXXX Expires 26.03.05'},
#  {'type': 'spam',
#   'text': 'Do you want a new video handset? 750 anytime any network mins? Half Price Line Rental? Camcorder? Reply or call 08000930705 for delivery tomorrow'},
#  {'type': 'ham', 'text': 'Went fast asleep dear.take care.'},
#  {'type': 'ham', 'text': 'No that just means you have a fat head'},
#  {'type': 'ham',
#   'text': "Sounds like a plan! Cardiff is still here and still cold! I'm sitting on the radiator!"},
#  {'type': 'ham', 'text': 'Serious? What like proper tongued her'},
#  {'type': 'ham',
#   'text': 'She.s good. She was wondering if you wont say hi but she.s smiling now. So how are you coping with the long distance'},
#  {'type': 'ham',
#   'text': "How i noe... She's in da car now... Later then c lar... I'm wearing shorts..."},
#  {'type': 'spam',
#   'text': 'You have an important customer service announcement. Call FREEPHONE 0800 542 0825 now!'},
#  {'type': 'ham', 'text': 'Yeah whatever lol'},
#  {'type': 'ham',
#   'text': 'Today is ACCEPT DAY..U Accept me as? Brother Sister Lover Dear1 Best1 Clos1 Lvblefrnd Jstfrnd Cutefrnd Lifpartnr Belovd Swtheart Bstfrnd No rply means enemy'},
#  {'type': 'ham', 'text': 'Ard 530 lor. I ok then message ü lor.'},
#  {'type': 'ham', 'text': 'Ok. C u then.'},
#  {'type': 'ham',
#   'text': 'Eh ur laptop got no stock lei... He say mon muz come again to take a look c got a not...'},
#  {'type': 'ham',
#   'text': 'No need to ke qi... Ü too bored izzit y suddenly thk of this...'},
#  {'type': 'ham',
#   'text': "I wish! I don't think its gonna snow that much. But it will be more than those flurries we usually get that melt before they hit the ground. Eek! We haven't had snow since &lt;#&gt; before I was even born!"},
#  {'type': 'spam',
#   'text': 'FREE>Ringtone! Reply REAL or POLY eg REAL1 1. PushButton 2. DontCha 3. BabyGoodbye 4. GoldDigger 5. WeBeBurnin 1st tone FREE and 6 more when u join for £3/wk'},
#  {'type': 'ham',
#   'text': 'Do 1 thing! Change that sentence into: "Because i want 2 concentrate in my educational career im leaving here.."'},
#  {'type': 'ham',
#   'text': 'Oh really? perform, write a paper, go to a movie AND be home by midnight, huh?'},
#  {'type': 'ham',
#   'text': 'Okay lor... Will they still let us go a not ah? Coz they will not know until later. We drop our cards into the box right?'},
#  {'type': 'ham', 'text': 'How? Izzit still raining?'},
#  {'type': 'ham', 'text': "As if i wasn't having enough trouble sleeping."},
#  {'type': 'ham', 'text': 'I havent add ü yet right.. '},
#  {'type': 'ham',
#   'text': "Lol ... I really need to remember to eat when I'm drinking but I do appreciate you keeping me company that night babe *smiles*"},
#  {'type': 'ham', 'text': 'Babe ? I lost you ... Will you try rebooting ?'},
#  {'type': 'ham', 'text': 'Yes. Nigh you cant aha.'},
#  {'type': 'ham',
#   'text': "I thk ü gotta go home by urself. Cos i'll b going out shopping 4 my frens present. "},
#  {'type': 'ham',
#   'text': "Nooooooo I'm gonna be bored to death all day. Cable and internet outage."},
#  {'type': 'ham', 'text': 'Sos! Any amount i can get pls.'},
#  {'type': 'ham', 'text': 'Playin space poker, u?'},
#  {'type': 'ham', 'text': 'How come guoyang go n tell her? Then u told her?'},
#  {'type': 'ham', 'text': 'You need to get up. Now.'},
#  {'type': 'ham', 'text': 'They r giving a second chance to rahul dengra.'},
#  {'type': 'ham',
#   'text': 'Yeah, in fact he just asked if we needed anything like an hour ago. When and how much?'},
#  {'type': 'ham',
#   'text': 'WHEN THE FIRST STRIKE IS A RED ONE. THE BIRD + ANTELOPE BEGIN TOPLAY IN THE FIELDOF SELFINDEPENDENCE BELIEVE THIS + THE FLOWER OF CONTENTION WILL GROW.RANDOM!'},
#  {'type': 'ham', 'text': 'Y ü wan to go there? C doctor?'},
#  {'type': 'ham', 'text': 'Does daddy have a bb now.'},
#  {'type': 'spam',
#   'text': 'Free Msg: get Gnarls Barkleys "Crazy" ringtone TOTALLY FREE just reply GO to this message right now!'},
#  {'type': 'ham', 'text': "She's borderline but yeah whatever."},
#  {'type': 'ham',
#   'text': 'I got a call from a landline number. . . I am asked to come to anna nagar . . . I will go in the afternoon'},
#  {'type': 'ham', 'text': 'Until 545 lor... Ya, can go 4 dinner together...'},
#  {'type': 'ham',
#   'text': 'I will be gentle princess! We will make sweet gentle love...'},
#  {'type': 'ham',
#   'text': 'How u doin baby girl ?? hope u are okay every time I call ure phone is off! I miss u get in touch'},
#  {'type': 'ham', 'text': 'Sorry, went to bed early, nightnight'},
#  {'type': 'ham',
#   'text': "I like to think there's always the possibility of being in a pub later."},
#  {'type': 'ham',
#   'text': 'HMM yeah if your not too grooved out! And im looking forward to my pound special :)'},
#  {'type': 'ham',
#   'text': 'I got to video tape pple type in message lor. U so free wan 2 help me? Hee... Cos i noe u wan 2 watch infernal affairs so ask u along. Asking shuhui oso.'},
#  {'type': 'ham', 'text': 'Hi dude hw r u da realy mising u today'},
#  {'type': 'ham',
#   'text': 'Me hungry buy some food good lei... But mum n yun dun wan juz buy a little bit... '},
#  {'type': 'spam',
#   'text': "Refused a loan? Secured or Unsecured? Can't get credit? Call free now 0800 195 6669 or text back 'help' & we will!"},
#  {'type': 'ham',
#   'text': "I probably won't eat at all today. I think I'm gonna pop. How was your weekend? Did u miss me?"},
#  {'type': 'ham',
#   'text': 'I knew it... U slept v late yest? Wake up so late...'},
#  {'type': 'ham',
#   'text': 'Haha... dont be angry with yourself... Take it as a practice for the real thing. =) '},
#  {'type': 'ham', 'text': 'Where is that one day training:-)'},
#  {'type': 'ham', 'text': 'So i could kiss and feel you next to me...'},
#  {'type': 'ham', 'text': 'Have a nice day my dear.'},
#  {'type': 'ham',
#   'text': "I sent lanre fakeye's Eckankar details to the mail box"},
#  {'type': 'ham', 'text': 'Your dad is back in ph?'},
#  {'type': 'spam',
#   'text': 'You have been specially selected to receive a "3000 award! Call 08712402050 BEFORE the lines close. Cost 10ppm. 16+. T&Cs apply. AG Promo'},
#  {'type': 'ham', 'text': 'If you ask her or she say any please message.'},
#  {'type': 'ham', 'text': 'If e timing can, then i go w u lor...'},
#  {'type': 'ham', 'text': 'Love you aathi..love u lot..'},
#  {'type': 'ham', 'text': 'I was just callin to say hi. Take care bruv!'},
#  {'type': 'spam',
#   'text': 'YOU HAVE WON! As a valued Vodafone customer our computer has picked YOU to win a £150 prize. To collect is easy. Just call 09061743386'},
#  {'type': 'ham',
#   'text': 'Did u turn on the heater? The heater was on and set to &lt;#&gt; degrees.'},
#  {'type': 'ham',
#   'text': "Thanks for your message. I really appreciate your sacrifice. I'm not sure of the process of direct pay but will find out on my way back from the test tomorrow. I'm in class now. Do have a wonderful day."},
#  {'type': 'ham',
#   'text': "That's the trouble with classes that go well - you're due a dodgey one … Expecting mine tomo! See you for recovery, same time, same place "},
#  {'type': 'spam',
#   'text': 'Free video camera phones with Half Price line rental for 12 mths and 500 cross ntwk mins 100 txts. Call MobileUpd8 08001950382 or Call2OptOut/674&'},
#  {'type': 'ham', 'text': 'WOT U UP 2 J?'},
#  {'type': 'ham', 'text': 'Night night, see you tomorrow'},
#  {'type': 'ham',
#   'text': 'Roger that. We‘re probably going to rem in about 20'},
#  {'type': 'ham',
#   'text': 'do u think that any girl will propose u today by seing ur bloody funky shit fucking face...............asssssholeeee................'},
#  {'type': 'ham', 'text': 'I wish u were here. I feel so alone'},
#  {'type': 'spam',
#   'text': 'Great NEW Offer - DOUBLE Mins & DOUBLE Txt on best Orange tariffs AND get latest camera phones 4 FREE! Call MobileUpd8 free on 08000839402 NOW! or 2stoptxt T&Cs'},
#  {'type': 'ham',
#   'text': 'Reason is if the team budget is available at last they buy the unsold players for at base rate..'},
#  {'type': 'ham',
#   'text': 'CERI U REBEL! SWEET DREAMZ ME LITTLE BUDDY!! C YA 2MORO! WHO NEEDS BLOKES'},
#  {'type': 'spam', 'text': 'ringtoneking 84484'},
#  {'type': 'ham',
#   'text': 'Huh i cant thk of more oredi how many pages do we have?'},
#  {'type': 'ham',
#   'text': 'His frens go then he in lor. Not alone wif my mum n sis lor.'},
#  {'type': 'ham',
#   'text': 'Nationwide auto centre (or something like that) on Newport road. I liked them there'},
#  {'type': 'ham',
#   'text': 'Hey, I missed you tm of last night as my phone was on the charge ... *smiles* ... I am meeting a friend shortly'},
#  {'type': 'ham', 'text': 'Whatever, juliana. Do whatever you want.'},
#  {'type': 'ham',
#   'text': "Friendship is not a game to play, It is not a word to say, It doesn\\'t start on March and ends on May, It is tomorrow, yesterday, today and e"},
#  {'type': 'spam',
#   'text': 'Ringtone Club: Gr8 new polys direct to your mobile every week !'},
#  {'type': 'ham',
#   'text': 'Hello. Sort of out in town already. That . So dont rush home, I am eating nachos. Will let you know eta.'},
#  {'type': 'ham',
#   'text': 'Ok lor. Anyway i thk we cant get tickets now cos like quite late already. U wan 2 go look 4 ur frens a not? Darren is wif them now...'},
#  {'type': 'spam',
#   'text': '(Bank of Granite issues Strong-Buy) EXPLOSIVE PICK FOR OUR MEMBERS *****UP OVER 300% *********** Nasdaq Symbol CDGT That is a $5.00 per..'},
#  {'type': 'ham', 'text': 'I am on the way to ur home'},
#  {'type': 'ham',
#   'text': "Dizzamn, aight I'll ask my suitemates when I get back"},
#  {'type': 'ham',
#   'text': 'Nimbomsons. Yep phone knows that one. Obviously, cos thats a real word'},
#  {'type': 'ham',
#   'text': 'I love to cuddle! I want to hold you in my strong arms right now...'},
#  {'type': 'ham', 'text': 'R u in this continent?'},
#  {'type': 'ham',
#   'text': "We'll you pay over like  &lt;#&gt; yrs so its not too difficult"},
#  {'type': 'spam',
#   'text': 'Bored housewives! Chat n date now! 0871750.77.11! BT-national rate 10p/min only from landlines!'},
#  {'type': 'spam',
#   'text': 'We tried to call you re your reply to our sms for a video mobile 750 mins UNLIMITED TEXT free camcorder Reply or call now 08000930705 Del Thurs'},
#  {'type': 'ham', 'text': 'K...k...when will you give treat?'},
#  {'type': 'spam',
#   'text': 'This is the 2nd time we have tried to contact u. U have won the £400 prize. 2 claim is easy, just call 087104711148 NOW! Only 10p per minute. BT-national-rate'},
#  {'type': 'ham',
#   'text': "He's just gonna worry for nothing. And he won't give you money its no use."},
#  {'type': 'ham',
#   'text': 'Did you get any gift? This year i didnt get anything. So bad'},
#  {'type': 'ham',
#   'text': 'somewhere out there beneath the pale moon light someone think in of u some where out there where dreams come true... goodnite &amp; sweet dreams'},
#  {'type': 'ham',
#   'text': "Well there's a pattern emerging of my friends telling me to drive up and come smoke with them and then telling me that I'm a weed fiend/make them smoke too much/impede their doing other things so you see how I'm hesitant"},
#  {'type': 'ham',
#   'text': ', ow u dey.i paid 60,400thousad.i told  u would call . '},
#  {'type': 'ham',
#   'text': 'IM FINE BABES AINT BEEN UP 2 MUCH THO! SAW SCARY MOVIE YEST ITS QUITE FUNNY! WANT 2MRW AFTERNOON? AT TOWN OR MALL OR SUMTHIN?xx'},
#  {'type': 'ham', 'text': "I'm reaching home in 5 min."},
#  {'type': 'ham',
#   'text': "Forgot you were working today! Wanna chat, but things are ok so drop me a text when you're free / bored etc and i'll ring. Hope all is well, nose essay and all xx"},
#  {'type': 'ham',
#   'text': 'Ha... Then we must walk to everywhere... Cannot take tram. My cousin said can walk to vic market from our hotel '},
#  {'type': 'spam',
#   'text': 'Wan2 win a Meet+Greet with Westlife 4 U or a m8? They are currently on what tour? 1)Unbreakable, 2)Untamed, 3)Unkempt. Text 1,2 or 3 to 83049. Cost 50p +std text'},
#  {'type': 'spam',
#   'text': 'Please call our customer service representative on FREEPHONE 0808 145 4742 between 9am-11pm as you have WON a guaranteed £1000 cash or £5000 prize!'},
#  {'type': 'ham', 'text': 'Discussed with your mother ah?'},
#  {'type': 'ham', 'text': 'Ok.'},
#  {'type': 'ham',
#   'text': "Sorry, I can't text &amp; drive coherently, see you in twenty"},
#  {'type': 'spam',
#   'text': "You will be receiving this week's Triple Echo ringtone shortly. Enjoy it!"},
#  {'type': 'ham', 'text': 'In which place i can get rooms cheap:-)'},
#  {'type': 'ham',
#   'text': "Eek that's a lot of time especially since American Pie is like 8 minutes long. I can't stop singing it."},
#  {'type': 'ham', 'text': 'GRAN ONLYFOUND OUT AFEW DAYS AGO.CUSOON HONI'},
#  {'type': 'spam',
#   'text': "U've been selected to stay in 1 of 250 top British hotels - FOR NOTHING! Holiday valued at £350! Dial 08712300220 to claim - National Rate Call. Bx526, SW73SS"},
#  {'type': 'ham', 'text': 'University of southern california.'},
#  {'type': 'ham', 'text': 'We have to pick rayan macleran there.'},
#  {'type': 'ham',
#   'text': 'U gd lor go shopping i got stuff to do. U wan 2 watch infernal affairs a not? Come lar...'},
#  {'type': 'ham', 'text': 'Well. Balls. Time to make calls'},
#  {'type': 'ham', 'text': 'Wat time ü wan today?'},
#  {'type': 'ham', 'text': ' &lt;#&gt;  in mca. But not conform.'},
#  {'type': 'ham', 'text': "Oh ok.. Wat's ur email?"},
#  {'type': 'ham', 'text': 'Yes, princess. Are you going to make me moan?'},
#  {'type': 'ham', 'text': "Lol its ok I didn't remember til last nite"},
#  {'type': 'ham', 'text': '[…] anyway, many good evenings to u! s'},
#  {'type': 'ham', 'text': "Cool, I'll text you in a few"},
#  {'type': 'ham',
#   'text': "Sorry vikky, i'm Watching olave mandara movie kano in trishul theatre wit my frnds.."},
#  {'type': 'ham',
#   'text': "I'm very happy for you babe ! Woo hoo party on dude!"},
#  {'type': 'ham',
#   'text': 'I am taking you for italian food. How about a pretty dress with no panties? :)'},
#  {'type': 'ham',
#   'text': 'Wot u up 2? Thout u were gonna call me!! Txt bak luv K'},
#  {'type': 'spam',
#   'text': 'YOU ARE CHOSEN TO RECEIVE A £350 AWARD! Pls call claim number 09066364311 to collect your award which you are selected to receive as a valued mobile customer.'},
#  {'type': 'ham', 'text': 'How are you holding up?'},
#  {'type': 'ham',
#   'text': 'Dont flatter yourself... Tell that man of mine two pints of carlin in ten minutes please.... '},
#  {'type': 'ham', 'text': 'Hope you are not scared!'},
#  {'type': 'ham',
#   'text': 'I cant pick the phone right now. Pls send a message'},
#  {'type': 'ham', 'text': "I'm at home n ready..."},
#  {'type': 'spam',
#   'text': 'Please call our customer service representative on FREEPHONE 0808 145 4742 between 9am-11pm as you have WON a guaranteed £1000 cash or £5000 prize!'},
#  {'type': 'ham', 'text': 'What time do u get out?'},
#  {'type': 'ham',
#   'text': 'I am literally in bed and have been up for like  &lt;#&gt;  hours'},
#  {'type': 'ham', 'text': 'Yes, my reg is  Ciao!'},
#  {'type': 'ham', 'text': 'If You mean the website. Yes.'},
#  {'type': 'spam', 'text': 'Win a £1000 cash prize or a prize worth £5000'},
#  {'type': 'spam',
#   'text': 'Thanks for your ringtone order, reference number X49.Your mobile will be charged 4.50. Should your tone not arrive please call customer services 09065989182'},
#  {'type': 'ham',
#   'text': 'Lol or I could just starve and lose a pound by the end of the day.'},
#  {'type': 'ham', 'text': "Yeah that's the impression I got"},
#  {'type': 'ham', 'text': 'Ok ok take care. I can understand.'},
#  {'type': 'ham',
#   'text': 'Motivate Behind every darkness, there is a shining light waiting for you to find it... Behind every best friend, there is always trust and love... BSLVYL'},
#  {'type': 'ham', 'text': 'Ya ok, then had dinner?'},
#  {'type': 'ham', 'text': 'I was slept that time.you there?'},
#  {'type': 'ham',
#   'text': 'dont make ne plans for nxt wknd coz she wants us to come down then ok'},
#  {'type': 'ham',
#   'text': "When is school starting. Where will you stay. What's the weather like. And the food. Do you have a social support system like friends in the school. All these things are important."},
#  {'type': 'ham',
#   'text': "Ha ha nan yalrigu heltini..Iyo kothi chikku, u shared many things wit me..so far i didn't told any body and even uttered a word abt u.. If ur trusting me so much how can i tell these to others.. Plz nxt time dont use those words to me..ok, chikku:-);-)B-)"},
#  {'type': 'ham', 'text': "Noice. Text me when you're here"},
#  {'type': 'ham',
#   'text': "Hi di is yijue we're meeting at 7 pm at esaplanade tonight."},
#  {'type': 'spam',
#   'text': 'Moby Pub Quiz.Win a £100 High Street prize if u know who the new Duchess of Cornwall will be? Txt her first name to 82277.unsub STOP £1.50 008704050406 SP'},
#  {'type': 'spam',
#   'text': 'This weeks SavaMob member offers are now accessible. Just call 08709501522 for details! SavaMob, POBOX 139, LA3 2WU. Only £1.50/week. SavaMob - offers mobile!'},
#  {'type': 'ham',
#   'text': "Aight I've been set free, think you could text me blake's address? It occurs to me I'm not quite as sure what I'm doing as I thought I was"},
#  {'type': 'ham',
#   'text': 'Hi dear we saw dear. We both are happy. Where you my battery is low'},
#  {'type': 'ham', 'text': "How are you. Its been ages. How's abj"},
#  {'type': 'ham',
#   'text': 'Prof: you have passed in all the papers in this sem congrats . . . . Student: Enna kalaachutaarama..!! Prof:???? Gud mrng!'},
#  {'type': 'ham', 'text': "Dont kick coco when he's down"},
#  {'type': 'ham',
#   'text': "Fyi I'm gonna call you sporadically starting at like  &lt;#&gt;  bc we are not not doin this shit"},
#  {'type': 'spam',
#   'text': 'You are being contacted by our Dating Service by someone you know! To find out who it is, call from your mobile or landline 09064017305 PoBox75LDNS7 '},
#  {'type': 'spam',
#   'text': 'TBS/PERSOLVO. been chasing us since Sept for£38 definitely not paying now thanks to your information. We will ignore them. Kath. Manchester.'},
#  {'type': 'ham',
#   'text': 'Hope you\x92re not having too much fun without me!! see u tomorrow love jess x'},
#  {'type': 'ham',
#   'text': 'Ok i wont call or disturb any one. I know all are avoiding me. I am a burden for all'},
#  {'type': 'ham',
#   'text': "I've reached home n i bathe liao... U can call me now..."},
#  {'type': 'spam',
#   'text': 'Loans for any purpose even if you have Bad Credit! Tenants Welcome. Call NoWorriesLoans.com on 08717111821'},
#  {'type': 'ham', 'text': 'Was the actual exam harder than NBME'},
#  {'type': 'ham',
#   'text': 'A lot of this sickness thing going round. Take it easy. Hope u feel better soon. Lol'},
#  {'type': 'ham',
#   'text': 'God picked up a flower and dippeditinaDEW, lovingly touched itwhichturnedinto u, and the he gifted tomeandsaid,THIS FRIEND IS 4U'},
#  {'type': 'spam',
#   'text': '87077: Kick off a new season with 2wks FREE goals & news to ur mobile! Txt ur club name to 87077 eg VILLA to 87077'},
#  {'type': 'ham',
#   'text': 'Hey sathya till now we dint meet not even a single time then how can i saw the situation sathya.'},
#  {'type': 'ham', 'text': 'Gam gone after outstanding innings.'},
#  {'type': 'ham', 'text': 'O i played smash bros  &lt;#&gt;  religiously.'},
#  {'type': 'ham',
#   'text': 'Sir, good morning. Hope you had a good weekend. I called to let you know that i was able to raise  &lt;#&gt;  from my dad. He however said he would make the rest available by mid feb. This amount is still quite short and i was hoping you would help. Do have a good day. Abiola'},
#  {'type': 'ham', 'text': 'Hurry home. Soup is DONE!'},
#  {'type': 'ham', 'text': 'No no. I will check all rooms befor activities'},
#  {'type': 'ham',
#   'text': 'Good afternoon, my love. It was good to see your words on YM and get your tm. Very smart move, my slave ... *smiles* ... I drink my coffee and await you.'},
#  {'type': 'ham',
#   'text': "Quite ok but a bit ex... U better go eat smth now else i'll feel guilty..."},
#  {'type': 'spam',
#   'text': 'Orange brings you ringtones from all time Chart Heroes, with a free hit each week! Go to Ringtones & Pics on wap. To stop receiving these tips reply STOP.'},
#  {'type': 'ham', 'text': "Lemme know when you're here"},
#  {'type': 'spam',
#   'text': 'PRIVATE! Your 2003 Account Statement for 07973788240 shows 800 un-redeemed S. I. M. points. Call 08715203649 Identifier Code: 40533 Expires 31/10/04'},
#  {'type': 'ham',
#   'text': 'He needs to stop going to bed and make with the fucking dealing'},
#  {'type': 'ham',
#   'text': 'How are you, my Love ? Are you with your brother ? Time to talk english with him ? *grins* Say : Hey Muhommad, Penny says hello from across the sea'},
#  {'type': 'spam',
#   'text': 'We tried to call you re your reply to our sms for a video mobile 750 mins UNLIMITED TEXT + free camcorder Reply of call 08000930705 Now'},
#  {'type': 'ham',
#   'text': 'Hey doc pls I want to get nice t shirt for my hubby nice fiting ones my budget is  &lt;#&gt; k help pls I will load d card abi hw,keep me posted luv. 2 mj'},
#  {'type': 'ham',
#   'text': "I remain unconvinced that this isn't an elaborate test of my willpower"},
#  {'type': 'ham',
#   'text': 'Life is nothing wen v get everything. But "life is everything wen v miss something ". Real value of people wil be realized only in their absence.... gud mrng'},
#  {'type': 'ham', 'text': 'how are you? I miss you!'},
#  {'type': 'ham',
#   'text': "I ain't answerin no phone at what is actually a pretty reasonable hour but I'm sleepy"},
#  {'type': 'ham', 'text': 'Hey , is * rite u put »10 evey mnth is that all?'},
#  {'type': 'ham', 'text': 'i am going to bed now prin'},
#  {'type': 'ham', 'text': 'I think just yourself …Thanks and see you tomo'},
#  {'type': 'ham', 'text': 'If u dun drive then how i go 2 sch.'},
#  {'type': 'ham', 'text': 'I not at home now lei...'},
#  {'type': 'spam',
#   'text': "GSOH? Good with SPAM the ladies?U could b a male gigolo? 2 join the uk's fastest growing mens club reply ONCALL. mjzgroup. 08714342399.2stop reply STOP. msg@£1.50rcvd"},
#  {'type': 'ham', 'text': 'Ok then i will come to ur home after half an hour'},
#  {'type': 'spam',
#   'text': 'U have a secret admirer who is looking 2 make contact with U-find out who they R*reveal who thinks UR so special-call on 09058094599'},
#  {'type': 'ham', 'text': 'Do u hav any frnd by name ashwini in ur college?'},
#  {'type': 'ham',
#   'text': 'Jus finish my lunch on my way home lor... I tot u dun wan 2 stay in sch today...'},
#  {'type': 'ham', 'text': 'K then 2marrow are you coming to class.'},
#  {'type': 'spam',
#   'text': 'HOT LIVE FANTASIES call now 08707500020 Just 20p per min NTT Ltd, PO Box 1327 Croydon CR9 5WB 0870 is a national rate call'},
#  {'type': 'ham', 'text': 'Pls send me your address sir.'},
#  {'type': 'ham', 'text': 'I want to lick your pussy now...'},
#  {'type': 'ham',
#   'text': "Yo, you gonna still be in stock tomorrow/today? I'm trying to get a dubsack"},
#  {'type': 'spam',
#   'text': 'URGENT! Your Mobile number has been awarded a <UKP>2000 prize GUARANTEED. Call 09061790125 from landline. Claim 3030. Valid 12hrs only 150ppm'},
#  {'type': 'ham', 'text': "I'll see, but prolly yeah"},
#  {'type': 'ham',
#   'text': "Thought we could go out for dinner. I'll treat you! Seem ok?"},
#  {'type': 'ham',
#   'text': "Where are you ? What do you do ? How can you stand to be away from me ? Doesn't your heart ache without me ? Don't you wonder of me ? Don't you crave me ?"},
#  {'type': 'ham',
#   'text': "Sorry. You never hear unless you book it. One was kinda a joke--thet were really looking for skinny white girls. The other was one line--you can only do so much on camera with that. Something like that they're casting on the look."},
#  {'type': 'ham', 'text': 'What you doing?how are you?'},
#  {'type': 'ham',
#   'text': 'Sure thing big man. i have hockey elections at 6, shouldn‘t go on longer than an hour though'},
#  {'type': 'ham',
#   'text': 'Watch lor. I saw a few swatch one i thk quite ok. Ard 116 but i need 2nd opinion leh...'},
#  {'type': 'ham',
#   'text': 'Hiya do u like the hlday pics looked horrible in them so took mo out! Hows the camp Amrca thing? Speak soon Serena:)'},
#  {'type': 'ham',
#   'text': 'Babe! How goes that day ? What are you up to ? I miss you already, my Love ... * loving kiss* ... I hope everything goes well.'},
#  {'type': 'ham', 'text': "Yunny... I'm goin to be late"},
#  {'type': 'ham',
#   'text': "Doc prescribed me morphine cause the other pain meds aren't enough. Waiting for my mom to bring it. That med should kick in fast so I'm gonna try to be on later"},
#  {'type': 'ham',
#   'text': 'Cool, want me to go to kappa or should I meet you outside mu'},
#  {'type': 'ham',
#   'text': 'Hey sexy buns ! Have I told you ? I adore you, loverboy. I hope you remember to thank your sister in law for those meatballs *grins* ... i love you, babe'},
#  {'type': 'ham',
#   'text': 'May b approve panalam...but it should have more posts..'},
#  {'type': 'spam',
#   'text': 'SPJanuary Male Sale! Hot Gay chat now cheaper, call 08709222922. National rate from 1.5p/min cheap to 7.8p/min peak! To stop texts call 08712460324 (10p/min)'},
#  {'type': 'ham', 'text': "Sorry, I'll call later"},
#  {'type': 'ham', 'text': 'I dont thnk its a wrong calling between us'},
#  {'type': 'ham', 'text': "Me i'm not workin. Once i get job..."},
#  {'type': 'ham', 'text': "And by when you're done I mean now"},
#  {'type': 'ham',
#   'text': "Its Ur luck to Love someone. Its Ur fortune to Love the one who Loves U. But, its a miracle to Love a person who can't Love anyone except U... Gud nyt..."},
#  {'type': 'ham',
#   'text': 'Hi baby ive just got back from work and i was wanting to see u allday! I hope i didnt piss u off on the phone today. If u are up give me a call xxx'},
#  {'type': 'spam',
#   'text': "FreeMsg Today's the day if you are ready! I'm horny & live in your town. I love sex fun & games! Netcollex Ltd 08700621170150p per msg reply Stop to end"},
#  {'type': 'ham',
#   'text': 'Is it your yahoo boys that bring in the perf? Or legal.'},
#  {'type': 'ham',
#   'text': 'No need to say anything to me. I know i am an outsider'},
#  {'type': 'ham', 'text': 'have you ever had one foot before?'},
#  {'type': 'ham', 'text': 'Just got to  &lt;#&gt;'},
#  {'type': 'ham',
#   'text': 'Good! No, don‘t need any receipts—well done! (…) Yes, please tell . What‘s her number, i could ring her'},
#  {'type': 'ham',
#   'text': 'Ever green quote ever told by Jerry in cartoon "A Person Who Irritates u Always Is the one Who Loves u Vry Much But Fails to Express It...!..!! :-) :-) gud nyt'},
#  {'type': 'ham',
#   'text': 'Leave it wif me lar... Ü wan to carry meh so heavy... Is da num 98321561 familiar to ü?'},
#  {'type': 'ham',
#   'text': 'Beautiful truth : Expression of the face could Be seen by everyone... But the depression of heart Could be understood only By the Loved ones.. Gud Ni8;-)'},
#  {'type': 'ham',
#   'text': 'Infact happy new year. How are you where are you when are we seeing'},
#  {'type': 'spam',
#   'text': 'In The Simpsons Movie released in July 2007 name the band that died at the start of the film? A-Green Day, B-Blue Day, C-Red Day. (Send A, B or C)'},
#  {'type': 'ham', 'text': "That's a shame! Maybe cld meet for few hrs tomo?"},
#  {'type': 'ham',
#   'text': 'Lol I would but despite these cramps I like being a girl.'},
#  {'type': 'ham',
#   'text': 'I can\x92t wait for cornwall. Hope tonight isn\x92t too bad as well but it\x92s rock night shite. Anyway i\x92m going for a kip now have a good night. Speak to you soon.'},
#  {'type': 'ham',
#   'text': "Pls help me tell sura that i'm expecting a battery from hont. And that if should pls send me a message about how to download movies. Thanks"},
#  {'type': 'spam',
#   'text': "Please call Amanda with regard to renewing or upgrading your current T-Mobile handset free of charge. Offer ends today. Tel 0845 021 3680 subject to T's and C's"},
#  {'type': 'ham',
#   'text': "Haven't found a way to get another app for your phone, eh ? Will you go to the net cafe ? Did you take that job? Geeee I need you babe. I crave to see you ..."},
#  {'type': 'ham',
#   'text': 'I only work from mon to thurs but Sat i cant leh... Booked liao... Which other day u free?'},
#  {'type': 'ham', 'text': 'Ü comin to fetch us oredi...'},
#  {'type': 'ham', 'text': "What's nannys address?"},
#  {'type': 'spam',
#   'text': 'URGENT!! Your 4* Costa Del Sol Holiday or £5000 await collection. Call 09050090044 Now toClaim. SAE, TC s, POBox334, Stockport, SK38xh, Cost£1.50/pm, Max10mins'},
#  {'type': 'ham', 'text': 'Haf u eaten? Wat time u wan me 2 come?'},
#  {'type': 'spam',
#   'text': 'Want a new Video Phone? 750 anytime any network mins? Half price line rental free text for 3 months? Reply or call 08000930705 for free delivery'},
#  {'type': 'ham',
#   'text': 'Yo, call me when you get the chance, a friend of mine wanted me to ask you about a big order'},
#  {'type': 'ham',
#   'text': 'This single single answers are we fighting? Plus i said am broke and you didnt reply'},
#  {'type': 'ham',
#   'text': 'It certainly puts things into perspective when something like this happens'},
#  {'type': 'ham', 'text': 'Now got tv 2 watch meh? U no work today?'},
#  {'type': 'ham',
#   'text': 'i felt so...not any conveying reason.. Ese he... What about me?'},
#  {'type': 'spam',
#   'text': 'Had your mobile 11 months or more? U R entitled to Update to the latest colour mobiles with camera for Free! Call The Mobile Update Co FREE on 08002986030'},
#  {'type': 'ham',
#   'text': "How's it going? Got any exciting karaoke type activities planned? I'm debating whether to play football this eve. Feeling lazy though."},
#  {'type': 'ham', 'text': 'I told that am coming on wednesday.'},
#  {'type': 'ham', 'text': 'Its ok, called mom instead have fun'},
#  {'type': 'spam',
#   'text': 'Dear Voucher Holder, To claim this weeks offer, at your PC please go to http://www.wtlp.co.uk/text. Ts&Cs apply.'},
#  {'type': 'ham',
#   'text': "Well if I'm that desperate I'll just call armand again"},
#  {'type': 'ham', 'text': 'Are you at work right now ?'},
#  {'type': 'spam',
#   'text': 'Congrats! Nokia 3650 video camera phone is your Call 09066382422 Calls cost 150ppm Ave call 3mins vary from mobiles 16+ Close 300603 post BCM4284 Ldn WC1N3XX'},
#  {'type': 'ham',
#   'text': "Haven't heard anything and he's not answering my texts so I'm guessing he flaked. That said the jb is fantastic"},
#  {'type': 'ham',
#   'text': "Mmmmmm ... I love you,so much, Ahmad ... I can't wait for this year to begin as every second takes me closer to being at your side. Happy New Year, my love!!"},
#  {'type': 'ham',
#   'text': "Pls what's the full name of joke's school cos fees in university of florida seem to actually be  &lt;#&gt; k. Pls holla back"},
#  {'type': 'ham', 'text': "Sorry, I'll call later"},
#  {'type': 'ham',
#   'text': "Ok... But they said i've got wisdom teeth hidden inside n mayb need 2 remove."},
#  {'type': 'ham', 'text': 'And pls pls drink plenty plenty water'},
#  {'type': 'ham',
#   'text': "How are you doing. How's the queen. Are you going for the royal wedding"},
#  {'type': 'ham',
#   'text': "He's in lag. That's just the sad part but we keep in touch thanks to skype"},
#  {'type': 'ham', 'text': 'Ok lor then we go tog lor...'},
#  {'type': 'ham', 'text': 'Two teams waiting for some players'},
#  {'type': 'ham', 'text': 'Can ü send me a copy of da report?'},
#  {'type': 'ham',
#   'text': 'swhrt how u dey,hope ur ok, tot about u 2day.love n miss.take care.'},
#  {'type': 'ham', 'text': 'Ok da, i already planned. I wil pick you.'},
#  {'type': 'spam',
#   'text': 'Urgent! Please call 0906346330. Your ABTA complimentary 4* Spanish Holiday or £10,000 cash await collection SAE T&Cs BOX 47 PO19 2EZ 150ppm 18+'},
#  {'type': 'ham', 'text': "Sorry, I'll call later in meeting"},
#  {'type': 'ham',
#   'text': "I just really need shit before tomorrow and I know you won't be awake before like 6"},
#  {'type': 'ham', 'text': "I'm good. Have you registered to vote?"},
#  {'type': 'ham',
#   'text': "Hmm ok, i'll stay for like an hour cos my eye is really sore!"},
#  {'type': 'ham', 'text': 'Dear got bus directly to calicut'},
#  {'type': 'ham',
#   'text': 'Mm umma ask vava also to come tell him can play later together'},
#  {'type': 'ham',
#   'text': 'Well the general price is  &lt;#&gt; /oz, let me know if/when/how much you want'},
#  {'type': 'ham', 'text': "Sorry, I'll call later"},
#  {'type': 'ham',
#   'text': 'Each Moment in a day,has its own value-Morning brings hope,afternoon brings faith,Evening brings luv,Night brings rest,Wish u find them all today.Good Morning'},
#  {'type': 'ham', 'text': '&lt;#&gt;  w jetton ave if you forgot'},
#  {'type': 'ham', 'text': "Ok i'm coming home now."},
#  {'type': 'ham', 'text': 'Can not use foreign stamps in this country.'},
#  {'type': 'spam',
#   'text': 'Double mins and txts 4 6months FREE Bluetooth on Orange. Available on Sony, Nokia Motorola phones. Call MobileUpd8 on 08000839402 or call2optout/N9DX'},
#  {'type': 'ham',
#   'text': "Sorry, it's a lot of friend-of-a-friend stuff, I'm just now about to talk to the actual guy who wants to buy"},
#  {'type': 'spam',
#   'text': 'FREE for 1st week! No1 Nokia tone 4 ur mob every week just txt NOKIA to 8007 Get txting and tell ur mates www.getzed.co.uk POBox 36504 W45WQ norm150p/tone 16+'},
#  {'type': 'spam',
#   'text': 'Want to funk up ur fone with a weekly new tone reply TONES2U 2 this text. www.ringtones.co.uk, the original n best. Tones 3GBP network operator rates apply'},
#  {'type': 'spam',
#   'text': 'cmon babe, make me horny, *turn* me on! Txt me your fantasy now babe -) Im hot, sticky and need you now. All replies cost £1.50. 2 cancel send STOP'},
#  {'type': 'ham', 'text': 'I will come tomorrow di'},
#  {'type': 'ham',
#   'text': 'Wylie update: my weed dealer carlos went to freedom and had a class with lunsford'},
#  {'type': 'ham',
#   'text': 'Are you happy baby ? Are you alright ? Did you take that job ? I hope your fine. I send you a kiss to make you smile from across the sea ... *kiss* *kiss*'},
#  {'type': 'ham',
#   'text': 'C movie is juz last minute decision mah. Juz watch 2 lar but i tot ü not interested.'},
#  {'type': 'ham',
#   'text': 'How are you enjoying this semester? Take care brother.'},
#  {'type': 'spam',
#   'text': "IMPORTANT INFORMATION 4 ORANGE USER 0796XXXXXX. TODAY IS UR LUCKY DAY!2 FIND OUT WHY LOG ONTO http://www.urawinner.com THERE'S A FANTASTIC PRIZEAWAITING YOU!"},
#  {'type': 'ham', 'text': "Get the door, I'm here"},
#  {'type': 'ham', 'text': 'Lets use it next week, princess :)'},
#  {'type': 'ham',
#   'text': 'Or i go home first lar ü wait 4 me lor.. I put down my stuff first..'},
#  {'type': 'ham',
#   'text': 'I want kfc its Tuesday. Only buy 2 meals ONLY 2. No gravy. Only 2 Mark. 2!'},
#  {'type': 'ham',
#   'text': 'No da:)he is stupid da..always sending like this:)don believe any of those message.pandy is a mental:)'},
#  {'type': 'ham', 'text': 'Oi when you gonna ring'},
#  {'type': 'spam',
#   'text': 'Missed call alert. These numbers called but left no message. 07008009200'},
#  {'type': 'ham', 'text': 'I attended but nothing is there.'},
#  {'type': 'ham',
#   'text': 'Ard 530 like dat lor. We juz meet in mrt station then ü dun haf to come out.'},
#  {'type': 'ham', 'text': 'No dear i was sleeping :-P'},
#  {'type': 'ham', 'text': 'Er mw im filled tuth is aight'},
#  {'type': 'ham',
#   'text': 'Will be office around 4 pm. Now i am going hospital.'},
#  {'type': 'ham',
#   'text': "Actually i'm waiting for 2 weeks when they start putting ad."},
#  {'type': 'ham', 'text': 'Anything lor if they all go then i go lor...'},
#  {'type': 'ham',
#   'text': 'U free on sat rite? U wan 2 watch infernal affairs wif me n darren n mayb xy?'},
#  {'type': 'ham',
#   'text': "Plz note: if anyone calling from a mobile Co. &amp; asks u to type # &lt;#&gt;  or # &lt;#&gt; . Do not do so. Disconnect the call,coz it iz an attempt of 'terrorist' to make use of the sim card no. Itz confirmd by nokia n motorola n has been verified by CNN IBN."},
#  {'type': 'ham',
#   'text': "Yo you around? A friend of mine's lookin to pick up later tonight"},
#  {'type': 'ham', 'text': 'Stupid auto correct on my phone'},
#  {'type': 'ham',
#   'text': 'Double eviction this week - Spiral and Michael and good riddance to them!'},
#  {'type': 'ham',
#   'text': 'The world suffers a lot... Not because of the violence of bad people. But because of the silence of good people!, Gud night....'},
#  {'type': 'ham',
#   'text': 'Ok thats cool. Its , just off either raglan rd or edward rd. Behind the cricket ground. Gimme ring when ur closeby see you tuesday.'},
#  {'type': 'ham', 'text': 'Buy one egg for me da..please:)'},
#  {'type': 'ham', 'text': 'Have you started in skye'},
#  {'type': 'ham',
#   'text': 'Have you bookedthe hut? And also your time off? How are you by the way?'},
#  {'type': 'ham', 'text': 'And several to you sir.'},
#  {'type': 'ham',
#   'text': 'U really pig leh sleep so much. My dad wake me up at 10 smth 2 eat lunch today.'},
#  {'type': 'ham', 'text': "I'm at home. Please call"},
#  {'type': 'ham',
#   'text': "My love ... I hope your not doing anything drastic. Don't you dare sell your pc or your phone ..."},
#  {'type': 'ham',
#   'text': 'Now only i reached home. . . I am very tired now. . I will come tomorro'},
#  {'type': 'spam',
#   'text': 'FREEMSG: Our records indicate you may be entitled to 3750 pounds for the Accident you had. To claim for free reply with YES to this msg. To opt out text STOP'},
#  {'type': 'spam',
#   'text': 'U can WIN £100 of Music Gift Vouchers every week starting NOW Txt the word DRAW to 87066 TsCs www.Idew.com SkillGame, 1Winaweek, age16. 150ppermessSubscription'},
#  {'type': 'ham', 'text': 'Life style garments account no please.'},
#  {'type': 'ham', 'text': 'Lol wtf random. Btw is that your lunch break'},
#  {'type': 'ham',
#   'text': 'Sez, hows u & de arab boy? Hope u r all good give my love 2 evry1 love ya eshxxxxxxxxxxx'},
#  {'type': 'ham',
#   'text': "The LAY MAN! Just to let you know you are missed and thought off. Do have a great day. And if you can send me bimbo and ugo's numbers, ill appreciate. Safe"},
#  {'type': 'ham', 'text': 'Detroit. The home of snow. Enjoy it.'},
#  {'type': 'spam',
#   'text': 'Show ur colours! Euro 2004 2-4-1 Offer! Get an England Flag & 3Lions tone on ur phone! Click on the following service message for info!'},
#  {'type': 'ham', 'text': 'Okie...'},
#  {'type': 'ham',
#   'text': "Aight, I'm chillin in a friend's room so text me when you're on the way"},
#  {'type': 'ham', 'text': 'Is toshiba portege m100 gd?'},
#  {'type': 'ham', 'text': 'Well welp is sort of a semiobscure internet thing'},
#  {'type': 'spam',
#   'text': 'Text PASS to 69669 to collect your polyphonic ringtones. Normal gprs charges apply only. Enjoy your tones'},
#  {'type': 'spam',
#   'text': 'accordingly. I repeat, just text the word ok on your mobile phone and send'},
#  {'type': 'ham', 'text': 'Loosu go to hospital. De dont let it careless.'},
#  {'type': 'ham', 'text': 'How much for an eighth?'},
#  {'type': 'ham',
#   'text': "Omg Joanna is freaking me out. She's looked thru all my friends to find photos of me. And then she's asking about stuff on my MySpace which I haven't even logged on in like a year. :/"},
#  {'type': 'ham',
#   'text': "Send ur birthdate with month and year, I will tel u ur LIFE PARTNER'S name. and the method of calculation. Reply must."},
#  {'type': 'ham',
#   'text': 'Juz now havent woke up so a bit blur blur... Can? Dad went out liao... I cant cum now oso...'},
#  {'type': 'ham', 'text': 'How about clothes, jewelry, and trips?'},
#  {'type': 'spam',
#   'text': 'Block Breaker now comes in deluxe format with new features and great graphics from T-Mobile. Buy for just £5 by replying GET BBDELUXE and take the challenge'},
#  {'type': 'ham',
#   'text': "Aah! A cuddle would be lush! I'd need lots of tea and soup before any kind of fumbling!"},
#  {'type': 'spam',
#   'text': "important information 4 orange user . today is your lucky day!2find out why log onto http://www.urawinner.com THERE'S A FANTASTIC SURPRISE AWAITING YOU!"},
#  {'type': 'ham', 'text': 'I am late. I will be there at'},
#  {'type': 'ham',
#   'text': "Sad story of a Man - Last week was my b'day. My Wife did'nt wish me. My Parents forgot n so did my Kids . I went to work. Even my Colleagues did not wish."},
#  {'type': 'ham', 'text': 'Are you plans with your family set in stone ?'},
#  {'type': 'ham', 'text': 'Pls dont forget to study'},
#  {'type': 'ham',
#   'text': "You'll never believe this but i have actually got off at taunton. Wow"},
#  {'type': 'ham',
#   'text': 'Den only weekdays got special price... Haiz... Cant eat liao... Cut nails oso muz wait until i finish drivin wat, lunch still muz eat wat... '},
#  {'type': 'ham',
#   'text': "She just broke down a list of reasons why nobody's in town and I can't tell if she's being sarcastic or just faggy"},
#  {'type': 'ham',
#   'text': ' &lt;DECIMAL&gt; m but its not a common car here so its better to buy from china or asia. Or if i find it less expensive. I.ll holla'},
#  {'type': 'ham',
#   'text': 'The greatest test of courage on earth is to bear defeat without losing heart....gn tc'},
#  {'type': 'ham',
#   'text': 'SORRY IM STIL FUCKED AFTER LAST NITE WENT TOBED AT 430 GOT UP 4 WORK AT 630'},
#  {'type': 'ham', 'text': 'Hey so whats the plan this sat? '},
#  {'type': 'ham', 'text': 'Beauty sleep can help ur pimples too.'},
#  {'type': 'ham',
#   'text': 'Great. Hope you are using your connections from mode men also cos you can never know why old friends can lead you to today'},
#  {'type': 'spam',
#   'text': 'Natalja (25/F) is inviting you to be her friend. Reply YES-440 or NO-440 See her: www.SMS.ac/u/nat27081980 STOP? Send STOP FRND to 62468'},
#  {'type': 'ham', 'text': 'Where to get those?'},
#  {'type': 'ham',
#   'text': 'Kind of. Just missed train cos of asthma attack, nxt one in half hr so driving in. not sure where to park.'},
#  {'type': 'ham',
#   'text': 'Ball is moving a lot.will spin in last :)so very difficult to bat:)'},
#  {'type': 'ham',
#   'text': 'Haiyoh... Maybe your hamster was jealous of million'},
#  {'type': 'ham', 'text': "Can you please send me my aunty's number"},
#  {'type': 'ham', 'text': "I'm glad. You are following your dreams."},
#  {'type': 'ham', 'text': "I've reached home finally..."},
#  {'type': 'spam',
#   'text': 'URGENT. Important information for 02 user. Today is your lucky day! 2 find out why , log onto http://www.urawinner.com there is a fantastic surprise awaiting you !'},
#  {'type': 'spam',
#   'text': 'WINNER!! As a valued network customer you have been selected to receivea £900 prize reward! To claim call 09061701461. Claim code KL341. Valid 12 hours only.'},
#  {'type': 'ham',
#   'text': 'Wn u r hurt by d prsn who s close 2 u, do fight wit dem. Coz somtimes dis fight saves a relation bt being quiet leaves nothin in a relation.. Gud eveB-)'},
#  {'type': 'ham', 'text': 'U can call now...'},
#  {'type': 'ham',
#   'text': "Science tells that chocolate will melt under the sunlight. Please don't walk under the sunlight. BCoz,I don't want to loss a sweet friend."},
#  {'type': 'ham',
#   'text': 'Yes. I come to nyc for audiitions and am trying to relocate.'},
#  {'type': 'ham', 'text': 'I pocked you up there before'},
#  {'type': 'ham',
#   'text': "Congrats. That's great. I wanted to tell you not to tell me your score cos it might make me relax. But its motivating me so thanks for sharing"},
#  {'type': 'ham',
#   'text': 'I wud never mind if u dont miss me or if u dont need me.. But u wil really hurt me wen u need me &amp; u dont tell me......... Take care:-)'},
#  {'type': 'ham',
#   'text': 'Hey mr whats the name of that bill brison book the one about language and words '},
#  {'type': 'ham', 'text': 'Okay, good, no problem, and thanx!'},
#  {'type': 'ham',
#   'text': "For you information, IKEA is spelled with all caps. That is not yelling. when you thought i had left you, you were sitting on the bed among the mess when i came in. i said we were going after you got home from class. please don't try and bullshit me. It makes me want to listen to you less."},
#  {'type': 'ham', 'text': "Call me when u're done..."},
#  {'type': 'ham', 'text': 'G.W.R'},
#  {'type': 'ham',
#   'text': 'You best watch what you say cause I get drunk as a motherfucker'},
#  {'type': 'spam',
#   'text': 'Kit Strip - you have been billed 150p. Netcollex Ltd. PO Box 1013 IG11 OJA'},
#  {'type': 'spam',
#   'text': 'HMV BONUS SPECIAL 500 pounds of genuine HMV vouchers to be won. Just answer 4 easy questions. Play Now! Send HMV to 86688 More info:www.100percent-real.com'},
#  {'type': 'spam',
#   'text': 'Please CALL 08712402578 immediately as there is an urgent message waiting for you'},
#  {'type': 'spam',
#   'text': 'thesmszone.com lets you send free anonymous and masked messages..im sending this message from there..do you see the potential for abuse???'},
#  {'type': 'spam',
#   'text': 'WELL DONE! Your 4* Costa Del Sol Holiday or £5000 await collection. Call 09050090044 Now toClaim. SAE, TCs, POBox334, Stockport, SK38xh, Cost£1.50/pm, Max10mins'},
#  {'type': 'ham',
#   'text': 'Hurt me... Tease me... Make me cry... But in the end of my life when i die plz keep one rose on my grave and say STUPID I MISS U.. HAVE A NICE DAY BSLVYL'},
#  {'type': 'ham',
#   'text': 'Erm... Woodland avenue somewhere. Do you get the parish magazine, his telephone number will be in there.'},
#  {'type': 'ham',
#   'text': 'Are there TA jobs available? Let me know please cos i really need to start working'},
#  {'type': 'ham',
#   'text': 'Aiyar hard 2 type. U later free then tell me then i call n scold n tell u.'},
#  {'type': 'ham', 'text': "Yup i'm free..."},
#  {'type': 'ham',
#   'text': 'Good good, billy mates all gone. Just been jogging, again! Did enjoy concert?'},
#  {'type': 'ham', 'text': 'Yo come over carlos will be here soon'},
#  {'type': 'ham',
#   'text': 'Awww dat is sweet! We can think of something to do he he! Have a nice time tonight ill probably txt u later cos im lonely :( xxx.'},
#  {'type': 'ham',
#   'text': 'I guess it is useless calling u 4 something important.'},
#  {'type': 'ham',
#   'text': 'Ha ha - had popped down to the loo when you hello-ed me. Hello!'},
#  {'type': 'ham',
#   'text': 'He dint tell anything. He is angry on me that why you told to abi.'},
#  {'type': 'spam',
#   'text': 'Someone U know has asked our dating service 2 contact you! Cant Guess who? CALL 09058091854 NOW all will be revealed. PO BOX385 M6 6WU'},
#  {'type': 'ham',
#   'text': "It so happens that there r 2waxsto do wat you want. She can come and ill get her medical insurance. And she'll be able to deliver and have basic care. I'm currently shopping for the right medical insurance for her. So just give me til friday morning. Thats when i.ll see the major person that can guide me to the right insurance."},
#  {'type': 'ham', 'text': 'I keep ten rs in my shelf:) buy two egg.'},
#  {'type': 'ham',
#   'text': "I wasn't well babe, i have swollen glands at my throat ... What did you end up doing ?"},
#  {'type': 'ham',
#   'text': "Is ur changes 2 da report big? Cos i've already made changes 2 da previous report."},
#  {'type': 'ham', 'text': 'Captain is in our room:)'},
#  {'type': 'ham',
#   'text': "I can't speak, bcaz mobile have problem. I can listen you but you cann't listen my voice. So i calls you later."},
#  {'type': 'ham',
#   'text': 'HIYA STU WOT U UP 2.IM IN SO MUCH TRUBLE AT HOME AT MOMENT EVONE HATES ME EVEN U! WOT THE HELL AV I DONE NOW? Y WONT U JUST TELL ME TEXT BCK PLEASE LUV DAN '},
#  {'type': 'ham', 'text': 'S...i will take mokka players only:)'},
#  {'type': 'ham', 'text': 'Are you still playing with gautham?'},
#  {'type': 'ham',
#   'text': 'Hey mr  and I are going to the sea view and having a couple of gays I mean games! Give me a bell when ya finish '},
#  {'type': 'ham',
#   'text': "K, jason says he's gonna be around so I'll be up there around  &lt;#&gt;"},
#  {'type': 'ham',
#   'text': 'Sorry . I will be able to get to you. See you in the morning.'},
#  {'type': 'ham', 'text': 'Aight well keep me informed'},
# ...
#  {'type': 'ham',
#   'text': "hey, looks like I was wrong and one of the kappa guys numbers is still on my phone, if you want I can text him and see if he's around"},
#  {'type': 'spam',
#   'text': 'URGENT! Your Mobile number has been awarded with a £2000 prize GUARANTEED. Call 09061790121 from land line. Claim 3030. Valid 12hrs only 150ppm'},
#  {'type': 'spam',
#   'text': 'Thanks 4 your continued support Your question this week will enter u in2 our draw 4 £100 cash. Name the NEW US President? txt ans to 80082'},
#  {'type': 'ham',
#   'text': "I'm home. Doc gave me pain meds says everything is fine."},
#  {'type': 'ham',
#   'text': "It's é only $140 ard...É rest all ard $180 at least...Which is é price 4 é 2 bedrm ($900)"},
#  {'type': 'ham', 'text': 'Me too! Have a lovely night xxx'},
#  {'type': 'ham', 'text': 'Prepare to be pleasured :)'},
#  {'type': 'ham',
#   'text': 'Hi.:)technical support.providing assistance to us customer through call and email:)'},
#  {'type': 'ham',
#   'text': 'if you text on your way to cup stop that should work. And that should be BUS'},
#  {'type': 'ham', 'text': 'Whens your radio show?'},
#  {'type': 'spam',
#   'text': 'Your unique user ID is 1172. For removal send STOP to 87239 customer services 08708034412'},
#  {'type': 'ham', 'text': "I'm not sure if its still available though"},
#  {'type': 'ham',
#   'text': 'watever reLation u built up in dis world only thing which remains atlast iz lonlines with lotz n lot memories! feeling..'},
#  {'type': 'ham',
#   'text': 'CHEERS LOU! YEAH WAS A GOODNITE SHAME U NEVA CAME! C YA GAILxx'},
#  {'type': 'ham', 'text': 'Hi..i got the money da:)'},
#  {'type': 'ham',
#   'text': 'Hi, Mobile no.  &lt;#&gt;  has added you in their contact list on www.fullonsms.com It s a great place to send free sms to people For more visit fullonsms.com'},
#  {'type': 'ham', 'text': 'Ok then u tell me wat time u coming later lor.'},
#  {'type': 'ham',
#   'text': "U repeat e instructions again. Wat's e road name of ur house?"},
#  {'type': 'ham',
#   'text': 'So many people seems to be special at first sight, But only very few will remain special to you till your last sight.. Maintain them till life ends.. Sh!jas'},
#  {'type': 'ham',
#   'text': 'Quite lor. But dun tell him wait he get complacent...'},
#  {'type': 'ham',
#   'text': 'Sorry completely forgot * will pop em round this week if your still here?'},
#  {'type': 'ham',
#   'text': 'U R THE MOST BEAUTIFUL GIRL IVE EVER SEEN. U R MY BABY COME AND C ME IN THE COMMON ROOM'},
#  {'type': 'ham',
#   'text': 'O we cant see if we can join denis and mina? Or does denis want alone time'},
#  {'type': 'ham',
#   'text': 'Sen told that he is going to join his uncle finance in cbe'},
#  {'type': 'ham',
#   'text': 'Yup... Hey then one day on fri we can ask miwa and jiayin take leave go karaoke '},
#  {'type': 'ham', 'text': 'Call me, i am senthil from hsbc.'},
#  {'type': 'ham',
#   'text': 'Especially since i talk about boston all up in my personal statement, lol! I woulda changed that if i had realized it said nyc! It says boston now.'},
#  {'type': 'ham',
#   'text': 'Indeed and by the way it was either or - not both !'},
#  {'type': 'spam',
#   'text': 'Urgent -call 09066649731from Landline. Your complimentary 4* Ibiza Holiday or £10,000 cash await collection SAE T&Cs PO BOX 434 SK3 8WP 150ppm 18+'},
#  {'type': 'ham', 'text': 'Holy living christ what is taking you so long'},
#  {'type': 'ham', 'text': 'Ü thk of wat to eat tonight.'},
#  {'type': 'ham',
#   'text': "Thanx. Yup we coming back on sun. Finish dinner going back 2 hotel now. Time flies, we're tog 4 exactly a mth today. Hope we'll haf many more mths to come..."},
#  {'type': 'ham',
#   'text': "We're on the opposite side from where we dropped you off"},
#  {'type': 'ham',
#   'text': "Yup. Izzit still raining heavily cos i'm in e mrt i can't c outside."},
#  {'type': 'ham', 'text': 'Send me your resume:-)'},
#  {'type': 'ham', 'text': 'Gd luck 4 ur exams :-)'},
#  {'type': 'ham',
#   'text': "Or u ask they all if next sat can a not. If all of them can make it then i'm ok lor."},
#  {'type': 'ham', 'text': 'Sorry that was my uncle. I.ll keep in touch'},
#  {'type': 'ham',
#   'text': 'Saw Guys and Dolls last night with Patrick Swayze it was great'},
#  {'type': 'spam',
#   'text': 'URGENT This is our 2nd attempt to contact U. Your £900 prize from YESTERDAY is still awaiting collection. To claim CALL NOW 09061702893'},
#  {'type': 'spam',
#   'text': 'Santa calling! Would your little ones like a call from Santa Xmas Eve? Call 09077818151 to book you time. Calls1.50ppm last 3mins 30s T&C www.santacalling.com'},
#  {'type': 'ham', 'text': "Just come home. I don't want u to be miserable"},
#  {'type': 'ham', 'text': 'I dont know why she.s not getting your messages'},
#  {'type': 'ham',
#   'text': "its cool but tyler had to take off so we're gonna buy for him and drop it off at his place later tonight. Our total order is a quarter, you got enough?"},
#  {'type': 'ham',
#   'text': "The guy at the car shop who was flirting with me got my phone number from the paperwork and called and texted me. I'm nervous because of course now he may have my address. Should i call his boss and tell him, knowing this may get him fired?"},
#  {'type': 'ham', 'text': 'Reverse is cheating. That is not mathematics.'},
#  {'type': 'ham', 'text': 'How do you plan to manage that'},
#  {'type': 'ham',
#   'text': 'Er, hello, things didn‘t quite go to plan – is limping slowly home followed by aa and with exhaust hanging off'},
#  {'type': 'ham', 'text': 'Sorry for the delay. Yes masters'},
#  {'type': 'ham', 'text': 'Call me when u finish then i come n pick u.'},
#  {'type': 'spam',
#   'text': 'PRIVATE! Your 2004 Account Statement for 078498****7 shows 786 unredeemed Bonus Points. To claim call 08719180219 Identifier Code: 45239 Expires 06.05.05'},
#  {'type': 'ham',
#   'text': "What's up my own oga. Left my phone at home and just saw ur messages. Hope you are good. Have a great weekend."},
#  {'type': 'ham',
#   'text': "Don't worry though, I understand how important it is that I be put in my place with a poorly thought out punishment in the face of the worst thing that has ever happened to me. Brb gonna go kill myself"},
#  {'type': 'ham',
#   'text': 'Honey, can you pls find out how much they sell Predicte in Nigeria. And how many times can it be used. Its very important to have a reply before monday'},
#  {'type': 'ham',
#   'text': "E admin building there? I might b slightly earlier... I'll call u when i'm reaching..."},
#  {'type': 'ham', 'text': "fyi I'm at usf now, swing by the room whenever"},
#  {'type': 'ham', 'text': 'i can call in  &lt;#&gt;  min if thats ok'},
#  {'type': 'ham',
#   'text': 'Ummmmmaah Many many happy returns of d day my dear sweet heart.. HAPPY BIRTHDAY dear'},
#  {'type': 'ham', 'text': 'Ü no home work to do meh... '},
#  {'type': 'ham',
#   'text': 'Anything is valuable in only 2 situations: First- Before getting it... Second- After loosing it...'},
#  {'type': 'ham',
#   'text': 'Me too. Mark is taking forever to pick up my prescription and the pain is coming back.'},
#  {'type': 'ham', 'text': "How's ur paper?"},
#  {'type': 'ham', 'text': 'Got smaller capacity one? Quite ex...'},
#  {'type': 'spam',
#   'text': 'Check Out Choose Your Babe Videos @ sms.shsex.netUN fgkslpoPW fgkslpo'},
#  {'type': 'ham', 'text': 'Im good! I have been thinking about you...'},
#  {'type': 'spam',
#   'text': 'u r a winner U ave been specially selected 2 receive £1000 cash or a 4* holiday (flights inc) speak to a live operator 2 claim 0871277810710p/min (18 )'},
#  {'type': 'ham', 'text': ':-) :-)'},
#  {'type': 'ham',
#   'text': 'Not thought bout it... || Drink in tap & spile at seven. || Is that pub on gas st off broad st by canal. || Ok?'},
#  {'type': 'ham', 'text': 'I am going to sleep. I am tired of travel.'},
#  {'type': 'ham', 'text': 'Haha, just what I was thinkin'},
#  {'type': 'ham',
#   'text': "Yup but it's not giving me problems now so mayb i'll jus leave it..."},
#  {'type': 'ham',
#   'text': 'Lol no. Just trying to make your day a little more interesting'},
#  {'type': 'ham',
#   'text': 'How long before you get reply, just defer admission til next semester'},
#  {'type': 'ham',
#   'text': 'The word "Checkmate" in chess comes from the Persian phrase "Shah Maat" which means; "the king is dead.." Goodmorning.. Have a good day..:)'},
#  {'type': 'ham', 'text': 'Po de :-):):-):-):-). No need job aha.'},
#  {'type': 'ham', 'text': 'Rats. Hey did u ever vote for the next themes?'},
#  {'type': 'spam',
#   'text': 'New Mobiles from 2004, MUST GO! Txt: NOKIA to No: 89545 & collect yours today! From ONLY £1. www.4-tc.biz 2optout 087187262701.50gbp/mtmsg18 TXTAUCTION.'},
#  {'type': 'ham', 'text': 'I hope your pee burns tonite.'},
#  {'type': 'ham',
#   'text': 'OH RITE. WELL IM WITH MY BEST MATE PETE, WHO I WENT OUT WITH 4 A WEEK+ NOW WERE 2GEVA AGAIN. ITS BEEN LONGER THAN A WEEK.'},
#  {'type': 'ham', 'text': "Yay can't wait to party together!"},
#  {'type': 'ham', 'text': '....photoshop makes my computer shut down.'},
#  {'type': 'ham',
#   'text': 'All boys made fun of me today. Ok i have no problem. I just sent one message just for fun'},
#  {'type': 'ham',
#   'text': "That's one of the issues but california is okay. No snow so its manageable"},
#  {'type': 'spam',
#   'text': 'PRIVATE! Your 2003 Account Statement for shows 800 un-redeemed S. I. M. points. Call 08715203652 Identifier Code: 42810 Expires 29/10/0'},
#  {'type': 'ham',
#   'text': 'Hmmm.... Mayb can try e shoppin area one, but forgot e name of hotel...'},
#  {'type': 'ham', 'text': 'Awesome, that gonna be soon or later tonight?'},
#  {'type': 'ham', 'text': 'I need details about that online job.'},
#  {'type': 'spam',
#   'text': 'YOU HAVE WON! As a valued Vodafone customer our computer has picked YOU to win a £150 prize. To collect is easy. Just call 09061743386 '},
#  {'type': 'ham', 'text': 'Missing you too.pray inshah allah'},
#  {'type': 'ham',
#   'text': 'Pls help me tell Ashley that i cant find her number oh'},
#  {'type': 'ham',
#   'text': 'I am in escape theatre now. . Going to watch KAVALAN in a few minutes'},
#  {'type': 'ham', 'text': 'S.this will increase the chance of winning.'},
#  {'type': 'ham',
#   'text': 'either way works for me. I am  &lt;#&gt;  years old. Hope that doesnt bother you.'},
#  {'type': 'ham',
#   'text': 'Maybe you should find something else to do instead???'},
#  {'type': 'ham',
#   'text': 'Gain the rights of a wife.dont demand it.i am trying as husband too.Lets see'},
#  {'type': 'ham', 'text': 'I liked your new house'},
#  {'type': 'ham', 'text': "I'm fine. Hope you are also"},
#  {'type': 'ham',
#   'text': 'Also north carolina and texas atm, you would just go to the gre site and pay for the test results to be sent.'},
#  {'type': 'ham', 'text': 'Same to u...'},
#  {'type': 'ham', 'text': 'yes baby! I need to stretch open your pussy!'},
#  {'type': 'ham',
#   'text': 'Thanks  and ! Or bomb and date as my phone wanted to say! '},
#  {'type': 'ham', 'text': 'Ok...'},
#  {'type': 'ham',
#   'text': "Hey, a guy I know is breathing down my neck to get him some bud, anyway you'd be able to get a half track to usf tonight?"},
#  {'type': 'ham',
#   'text': 'Response is one of d powerful weapon 2 occupy a place in others \'HEART\'... So, always give response 2 who cares 4 U"... Gud night..swt dreams..take care'},
#  {'type': 'ham', 'text': 'Nokia phone is lovly..'},
#  {'type': 'spam',
#   'text': '**FREE MESSAGE**Thanks for using the Auction Subscription Service. 18 . 150p/MSGRCVD 2 Skip an Auction txt OUT. 2 Unsubscribe txt STOP CustomerCare 08718726270'},
#  {'type': 'spam',
#   'text': 'Bored housewives! Chat n date now! 0871750.77.11! BT-national rate 10p/min only from landlines!'},
#  {'type': 'ham',
#   'text': 'Sorry da..today i wont come to play..i have driving clas..'},
#  {'type': 'ham', 'text': "I'm really sorry I lit your hair on fire"},
#  {'type': 'ham',
#   'text': 'Oh! Shit, I thought that was your trip! Loooooool ... That just makes SO much more sense now ... *grins* and the sofa reference was ... The "sleep on a couch" link you sent me ... Wasn\'t that how you went on your trip ? Oh ... And didn\'t your babe go with you for that celebration with your rents?'},
#  {'type': 'ham', 'text': 'Okey dokey swashbuckling stuff what oh.'},
#  {'type': 'ham',
#   'text': 'Watching cartoon, listening music &amp; at eve had to go temple &amp; church.. What about u?'},
#  {'type': 'ham',
#   'text': '1. Tension face 2. Smiling face 3. Waste face 4. Innocent face 5.Terror face 6.Cruel face 7.Romantic face 8.Lovable face 9.decent face  &lt;#&gt; .joker face.'},
#  {'type': 'ham',
#   'text': "Dip's cell dead. So i m coming with him. U better respond else we shall come back."},
#  {'type': 'ham', 'text': 'Well. You know what i mean. Texting'},
#  {'type': 'ham',
#   'text': 'Hi dis is yijue i would be happy to work wif ü all for gek1510...'},
#  {'type': 'ham', 'text': 'Lol! Oops sorry! Have fun. '},
#  {'type': 'ham', 'text': 'Wat happened to the cruise thing'},
#  {'type': 'ham',
#   'text': 'I know dat feelin had it with Pete! Wuld get with em , nuther place nuther time mayb?'},
#  {'type': 'spam',
#   'text': 'lyricalladie(21/F) is inviting you to be her friend. Reply YES-910 or NO-910. See her: www.SMS.ac/u/hmmross STOP? Send STOP FRND to 62468'},
#  {'type': 'ham',
#   'text': "The world's most happiest frnds never have the same characters... Dey just have the best understanding of their differences..."},
#  {'type': 'spam',
#   'text': 'No 1 POLYPHONIC tone 4 ur mob every week! Just txt PT2 to 87575. 1st Tone FREE ! so get txtin now and tell ur friends. 150p/tone. 16 reply HL 4info'},
#  {'type': 'ham',
#   'text': 'Yeah just open chat and click friend lists. Then make the list. Easy as pie'},
#  {'type': 'ham',
#   'text': "alright tyler's got a minor crisis and has to be home sooner than he thought so be here asap"},
#  {'type': 'ham', 'text': 'When/where do I pick you up'},
#  {'type': 'ham', 'text': 'As usual u can call me ard 10 smth.'},
#  {'type': 'ham',
#   'text': "New Theory: Argument wins d SITUATION, but loses the PERSON. So dont argue with ur friends just.. . . . kick them &amp; say, I'm always correct.!"},
#  {'type': 'ham',
#   'text': 'For many things its an antibiotic and it can be used for chest abdomen and gynae infections even bone infections.'},
#  {'type': 'ham', 'text': "Poor girl can't go one day lmao"},
#  {'type': 'ham', 'text': 'Or just do that 6times'},
#  {'type': 'spam',
#   'text': 'Todays Vodafone numbers ending with 4882 are selected to a receive a £350 award. If your number matches call 09064019014 to receive your £350 award.'},
#  {'type': 'ham',
#   'text': 'You have to pls make a note of all she.s exposed to. Also find out from her school if anyone else was vomiting. Is there a dog or cat in the house? Let me know later.'},
#  {'type': 'ham',
#   'text': 'Japanese Proverb: If one Can do it, U too Can do it, If none Can do it,U must do it Indian version: If one Can do it, LET HIM DO it.. If none Can do it,LEAVE it!! And finally Kerala version: If one can do it, Stop him doing it.. If none can do it, Make a strike against it ...'},
#  {'type': 'ham',
#   'text': 'Sounds like there could be a lot of time spent in that chastity device boy ... *grins* ... Or take your beatings like a good dog. Going to lounge in a nice long bath now ?'},
#  {'type': 'ham',
#   'text': 'Its worse if if uses half way then stops. Its better for him to complete it.'},
#  {'type': 'ham',
#   'text': "Miserable. They don't tell u that the side effects of birth control are massive gut wrenching cramps for the first 2 months. I didn't sleep at all last night."},
#  {'type': 'ham', 'text': 'Send me the new number'},
#  {'type': 'ham', 'text': 'Convey my regards to him'},
#  {'type': 'spam',
#   'text': 'Want the latest Video handset? 750 anytime any network mins? Half price line rental? Reply or call 08000930705 for delivery tomorrow'},
#  {'type': 'ham', 'text': '2 and half years i missed your friendship:-)'},
#  {'type': 'ham',
#   'text': 'I cant pick the phone right now. Pls send a message'},
#  {'type': 'ham', 'text': "Oh for fuck's sake she's in like tallahassee"},
#  ...]
